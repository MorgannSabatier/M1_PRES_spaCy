# %% [markdown]
# # AVANT PROPOS
#
# Avant de commencer, on installe Spacy la librairie via pip par exemple.
#
# Spacy propose de nombreux modèles en différentes langues qui nous permettront de travailler sur nos corpus. Vous pourrez trouver les modèles [ici](https://spacy.io/usage/models).
#
# Spacy a l'avantage de proposer une multitude d'outils utile pour le traitement automatique de la langue, assez performant et en plus flexible.
#
# Ce Notebook a pour but de présenter quelques fonctionnalités simples puis de complexifier nos chaînes de traitement afin de démontrer de la puissance de Spacy
#
# ### Import et modèles
#
# Spacy propose une multitude de langues (60 au total), dans un premier temps, nous utiliserons le modèle [_"en_core_web_sm"_](https://spacy.io/models/en) pour l'anglais
#
# `English pipeline optimized for CPU. Components: tok2vec, tagger, parser, senter, ner, attribute_ruler, lemmatizer.`

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ### Pré-traitement de nos textes
#
# Nous travaillons sur un extrait de _Great Expectations_ par __Charles Dickens__.
#
# #### Etape 0. Ouverture fichier
#
# On affiche les tokens, grace à \*.token. Ici, le doc (```dickens_doc```) est tokénizé comme on peut le voir ici.
# Cependant, la tokenization est "personnalisable", nous verrons ça après.

# %%
path = 'dickensExtrait.txt'
dickens_text = open(path).read()
dickens_doc = nlp(dickens_text)

print("Les 10 premiers tokens :\n", dickens_doc[0:10], "\n\n")

print("Liste des tokens détectés :\n")

cpt = 0
for token in dickens_doc:
    print(token.text)
    cpt+=1
    if cpt == 10:
        break
# Out:
# Les 10 premiers tokens :
#  A window was raised, and a clear voice demanded
#
#
# Liste des tokens détectés :
#
# A
# window
# was
# raised
# ,
# and
# a
# clear
# voice
# demanded

# %% [markdown]
# Les tokens ont de multiples attributs permettant
# * de renvoyer vrai ou faux à des assertions (is_space, ispunct, is_alpha etc)
# * d\'agir sur le token d'une quelconque manière (set_extension qui ajoute une extension et sa valeur à un Token)
# * de renvoyer des informations pertinentes sur le token tels que ses voisins (token.nbor), des informations sur la hiérarchie syntaxique élaborée sous forme d'arbre (Token.children)
#
# [Pour plus d'informations](https://spacy.io/api/token#attributes)

# %%
print("Tok\t IdTok\t Alpha?\t Ponct?\t Esp?\t Forme\t Stopword?")
print("-"*60)
for token in dickens_doc:
     print ("{}\t {}\t {}\t {}\t {}\t {}\t {}\t"
            .format(token, token.idx, token.is_alpha, token.is_punct, 
            token.is_space, token.shape_, token.is_stop))
# Out:
# Tok	 IdTok	 Alpha?	 Ponct?	 Esp?	 Forme	 Stopword?
# ------------------------------------------------------------
# A	 0	 True	 False	 False	 X	 True
# window	 2	 True	 False	 False	 xxxx	 False
# was	 9	 True	 False	 False	 xxx	 True
# raised	 13	 True	 False	 False	 xxxx	 False
# ,	 19	 False	 True	 False	 ,	 False
# and	 21	 True	 False	 False	 xxx	 True
# a	 25	 True	 False	 False	 x	 True
# clear	 27	 True	 False	 False	 xxxx	 False
# voice	 33	 True	 False	 False	 xxxx	 False
# demanded	 39	 True	 False	 False	 xxxx	 False
# "	 48	 False	 True	 False	 "	 False
# What	 49	 True	 False	 False	 Xxxx	 True
# name	 54	 True	 False	 False	 xxxx	 True
# ?	 58	 False	 True	 False	 ?	 False
# "	 59	 False	 True	 False	 "	 False
# To	 61	 True	 False	 False	 Xx	 True
# which	 64	 True	 False	 False	 xxxx	 True
# my	 70	 True	 False	 False	 xx	 True
# conductor	 73	 True	 False	 False	 xxxx	 False
# replied	 83	 True	 False	 False	 xxxx	 False
# ,	 90	 False	 True	 False	 ,	 False
#
# 	 91	 False	 False	 True
# 	 False
# "	 92	 False	 True	 False	 "	 False
# Pumblechook	 93	 True	 False	 False	 Xxxxx	 False
# .	 104	 False	 True	 False	 .	 False
# "	 105	 False	 True	 False	 "	 False
# The	 107	 True	 False	 False	 Xxx	 True
# voice	 111	 True	 False	 False	 xxxx	 False
# returned	 117	 True	 False	 False	 xxxx	 False
# ,	 125	 False	 True	 False	 ,	 False
# "	 127	 False	 True	 False	 "	 False
# Quite	 128	 True	 False	 False	 Xxxxx	 True
# right	 134	 True	 False	 False	 xxxx	 False
# ,	 139	 False	 True	 False	 ,	 False
# "	 140	 False	 True	 False	 "	 False
# and	 142	 True	 False	 False	 xxx	 True
# the	 146	 True	 False	 False	 xxx	 True
# window	 150	 True	 False	 False	 xxxx	 False
# was	 157	 True	 False	 False	 xxx	 True
# shut	 161	 True	 False	 False	 xxxx	 False
# again	 166	 True	 False	 False	 xxxx	 True
# ,	 171	 False	 True	 False	 ,	 False
# and	 173	 True	 False	 False	 xxx	 True
# a	 177	 True	 False	 False	 x	 True
# young	 179	 True	 False	 False	 xxxx	 False
# lady	 185	 True	 False	 False	 xxxx	 False
#
# 	 189	 False	 False	 True
# 	 False
# came	 190	 True	 False	 False	 xxxx	 False
# across	 195	 True	 False	 False	 xxxx	 True
# the	 202	 True	 False	 False	 xxx	 True
# court	 206	 True	 False	 False	 xxxx	 False
# -	 211	 False	 True	 False	 -	 False
# yard	 212	 True	 False	 False	 xxxx	 False
# ,	 216	 False	 True	 False	 ,	 False
# with	 218	 True	 False	 False	 xxxx	 True
# keys	 223	 True	 False	 False	 xxxx	 False
# in	 228	 True	 False	 False	 xx	 True
# her	 231	 True	 False	 False	 xxx	 True
# hand	 235	 True	 False	 False	 xxxx	 False
# .	 239	 False	 True	 False	 .	 False
#
# 	 240	 False	 False	 True
# 	 False
# "	 241	 False	 True	 False	 "	 False
# This	 242	 True	 False	 False	 Xxxx	 True
# ,	 246	 False	 True	 False	 ,	 False
# "	 247	 False	 True	 False	 "	 False
# said	 249	 True	 False	 False	 xxxx	 False
# Mr.	 254	 False	 False	 False	 Xx.	 False
# Pumblechook	 258	 True	 False	 False	 Xxxxx	 False
# ,	 269	 False	 True	 False	 ,	 False
# "	 271	 False	 True	 False	 "	 False
# is	 272	 True	 False	 False	 xx	 True
# Pip	 275	 True	 False	 False	 Xxx	 False
# .	 278	 False	 True	 False	 .	 False
# "	 279	 False	 True	 False	 "	 False
#
# 	 280	 False	 False	 True
# 	 False
# "	 281	 False	 True	 False	 "	 False
# This	 282	 True	 False	 False	 Xxxx	 True
# is	 287	 True	 False	 False	 xx	 True
# Pip	 290	 True	 False	 False	 Xxx	 False
# ,	 293	 False	 True	 False	 ,	 False
# is	 295	 True	 False	 False	 xx	 True
# it	 298	 True	 False	 False	 xx	 True
# ?	 300	 False	 True	 False	 ?	 False
# "	 301	 False	 True	 False	 "	 False
# returned	 303	 True	 False	 False	 xxxx	 False
# the	 312	 True	 False	 False	 xxx	 True
# young	 316	 True	 False	 False	 xxxx	 False
# lady	 322	 True	 False	 False	 xxxx	 False
# ,	 326	 False	 True	 False	 ,	 False
# who	 328	 True	 False	 False	 xxx	 True
# was	 332	 True	 False	 False	 xxx	 True
# very	 336	 True	 False	 False	 xxxx	 True
# pretty	 341	 True	 False	 False	 xxxx	 False
# and	 348	 True	 False	 False	 xxx	 True
# seemed	 352	 True	 False	 False	 xxxx	 True
# very	 359	 True	 False	 False	 xxxx	 True
# proud	 364	 True	 False	 False	 xxxx	 False
# ;	 369	 False	 True	 False	 ;	 False
# "	 371	 False	 True	 False	 "	 False
# come	 372	 True	 False	 False	 xxxx	 False
# in	 377	 True	 False	 False	 xx	 True
# ,	 379	 False	 True	 False	 ,	 False
# Pip	 381	 True	 False	 False	 Xxx	 False
# .	 384	 False	 True	 False	 .	 False
# "	 385	 False	 True	 False	 "	 False
#
# 	 386	 False	 False	 True
# 	 False
# Mr.	 387	 False	 False	 False	 Xx.	 False
# Pumblechook	 391	 True	 False	 False	 Xxxxx	 False
# was	 403	 True	 False	 False	 xxx	 True
# coming	 407	 True	 False	 False	 xxxx	 False
# in	 414	 True	 False	 False	 xx	 True
# also	 417	 True	 False	 False	 xxxx	 True
# ,	 421	 False	 True	 False	 ,	 False
# when	 423	 True	 False	 False	 xxxx	 True
# she	 428	 True	 False	 False	 xxx	 True
# stopped	 432	 True	 False	 False	 xxxx	 False
# him	 440	 True	 False	 False	 xxx	 True
# with	 444	 True	 False	 False	 xxxx	 True
# the	 449	 True	 False	 False	 xxx	 True
# gate	 453	 True	 False	 False	 xxxx	 False
# .	 457	 False	 True	 False	 .	 False
#
# 	 458	 False	 False	 True
# 	 False
# "	 459	 False	 True	 False	 "	 False
# Oh	 460	 True	 False	 False	 Xx	 False
# !	 462	 False	 True	 False	 !	 False
# "	 463	 False	 True	 False	 "	 False
# she	 465	 True	 False	 False	 xxx	 True
# said	 469	 True	 False	 False	 xxxx	 False
# .	 473	 False	 True	 False	 .	 False
# "	 475	 False	 True	 False	 "	 False
# Did	 476	 True	 False	 False	 Xxx	 True
# you	 480	 True	 False	 False	 xxx	 True
# wish	 484	 True	 False	 False	 xxxx	 False
# to	 489	 True	 False	 False	 xx	 True
# see	 492	 True	 False	 False	 xxx	 True
# Miss	 496	 True	 False	 False	 Xxxx	 False
# Havisham	 501	 True	 False	 False	 Xxxxx	 False
# ?	 509	 False	 True	 False	 ?	 False
# "	 510	 False	 True	 False	 "	 False
#
# 	 511	 False	 False	 True
# 	 False
# "	 512	 False	 True	 False	 "	 False
# If	 513	 True	 False	 False	 Xx	 True
# Miss	 516	 True	 False	 False	 Xxxx	 False
# Havisham	 521	 True	 False	 False	 Xxxxx	 False
# wished	 530	 True	 False	 False	 xxxx	 False
# to	 537	 True	 False	 False	 xx	 True
# see	 540	 True	 False	 False	 xxx	 True
# me	 544	 True	 False	 False	 xx	 True
# ,	 546	 False	 True	 False	 ,	 False
# "	 547	 False	 True	 False	 "	 False
# returned	 549	 True	 False	 False	 xxxx	 False
# Mr.	 558	 False	 False	 False	 Xx.	 False
# Pumblechook	 562	 True	 False	 False	 Xxxxx	 False
# ,	 573	 False	 True	 False	 ,	 False
# discomfited	 575	 True	 False	 False	 xxxx	 False
# .	 586	 False	 True	 False	 .	 False
#
# 	 587	 False	 False	 True
# 	 False
# "	 588	 False	 True	 False	 "	 False
# Ah	 589	 True	 False	 False	 Xx	 False
# !	 591	 False	 True	 False	 !	 False
# "	 592	 False	 True	 False	 "	 False
# said	 594	 True	 False	 False	 xxxx	 False
# the	 599	 True	 False	 False	 xxx	 True
# girl	 603	 True	 False	 False	 xxxx	 False
# ;	 607	 False	 True	 False	 ;	 False
# "	 609	 False	 True	 False	 "	 False
# but	 610	 True	 False	 False	 xxx	 True
# you	 614	 True	 False	 False	 xxx	 True
# see	 618	 True	 False	 False	 xxx	 True
# she	 622	 True	 False	 False	 xxx	 True
# do	 626	 True	 False	 False	 xx	 True
# n't	 628	 False	 False	 False	 x'x	 True
# .	 631	 False	 True	 False	 .	 False
# "	 632	 False	 True	 False	 "	 False
#
# 	 633	 False	 False	 True
# 	 False
# She	 634	 True	 False	 False	 Xxx	 True
# said	 638	 True	 False	 False	 xxxx	 False
# it	 643	 True	 False	 False	 xx	 True
# so	 646	 True	 False	 False	 xx	 True
# finally	 649	 True	 False	 False	 xxxx	 False
# ,	 656	 False	 True	 False	 ,	 False
# and	 658	 True	 False	 False	 xxx	 True
# in	 662	 True	 False	 False	 xx	 True
# such	 665	 True	 False	 False	 xxxx	 True
# an	 670	 True	 False	 False	 xx	 True
# undiscussible	 673	 True	 False	 False	 xxxx	 False
# way	 687	 True	 False	 False	 xxx	 False
# ,	 690	 False	 True	 False	 ,	 False
# that	 692	 True	 False	 False	 xxxx	 True
# Mr.	 697	 False	 False	 False	 Xx.	 False
# Pumblechook	 701	 True	 False	 False	 Xxxxx	 False
# ,	 712	 False	 True	 False	 ,	 False
# though	 714	 True	 False	 False	 xxxx	 True
# in	 721	 True	 False	 False	 xx	 True
# a	 724	 True	 False	 False	 x	 True
# condition	 726	 True	 False	 False	 xxxx	 False
# of	 736	 True	 False	 False	 xx	 True
#
# 	 738	 False	 False	 True
# 	 False
# ruffled	 739	 True	 False	 False	 xxxx	 False
# dignity	 747	 True	 False	 False	 xxxx	 False
# ,	 754	 False	 True	 False	 ,	 False
# could	 756	 True	 False	 False	 xxxx	 True
# not	 762	 True	 False	 False	 xxx	 True
# protest	 766	 True	 False	 False	 xxxx	 False
# .	 773	 False	 True	 False	 .	 False
# But	 775	 True	 False	 False	 Xxx	 True
# he	 779	 True	 False	 False	 xx	 True
# eyed	 782	 True	 False	 False	 xxxx	 False
# me	 787	 True	 False	 False	 xx	 True
# severely	 790	 True	 False	 False	 xxxx	 False
# -	 799	 False	 True	 False	 -	 False
# as	 801	 True	 False	 False	 xx	 True
# if	 804	 True	 False	 False	 xx	 True
# I	 807	 True	 False	 False	 X	 True
# had	 809	 True	 False	 False	 xxx	 True
# done	 813	 True	 False	 False	 xxxx	 True
# anything	 818	 True	 False	 False	 xxxx	 True
# to	 827	 True	 False	 False	 xx	 True
# him	 830	 True	 False	 False	 xxx	 True
# !	 833	 False	 True	 False	 !	 False
# -	 835	 False	 True	 False	 -	 False
# and	 837	 True	 False	 False	 xxx	 True
#
# 	 840	 False	 False	 True
# 	 False
# departed	 841	 True	 False	 False	 xxxx	 False
# with	 850	 True	 False	 False	 xxxx	 True
# the	 855	 True	 False	 False	 xxx	 True
# words	 859	 True	 False	 False	 xxxx	 False
# reproachfully	 865	 True	 False	 False	 xxxx	 False
# delivered	 879	 True	 False	 False	 xxxx	 False
# :	 888	 False	 True	 False	 :	 False
# "	 890	 False	 True	 False	 "	 False
# Boy	 891	 True	 False	 False	 Xxx	 False
# !	 894	 False	 True	 False	 !	 False
# Let	 896	 True	 False	 False	 Xxx	 False
# your	 900	 True	 False	 False	 xxxx	 True
# behaviour	 905	 True	 False	 False	 xxxx	 False
# here	 915	 True	 False	 False	 xxxx	 True
# be	 920	 True	 False	 False	 xx	 True
# a	 923	 True	 False	 False	 x	 True
# credit	 925	 True	 False	 False	 xxxx	 False
# unto	 932	 True	 False	 False	 xxxx	 False
# them	 937	 True	 False	 False	 xxxx	 True
#
# 	 941	 False	 False	 True
# 	 False
# which	 942	 True	 False	 False	 xxxx	 True
# brought	 948	 True	 False	 False	 xxxx	 False
# you	 956	 True	 False	 False	 xxx	 True
# up	 960	 True	 False	 False	 xx	 True
# by	 963	 True	 False	 False	 xx	 True
# hand	 966	 True	 False	 False	 xxxx	 False
# !	 970	 False	 True	 False	 !	 False
# "	 971	 False	 True	 False	 "	 False
# I	 973	 True	 False	 False	 X	 True
# was	 975	 True	 False	 False	 xxx	 True
# not	 979	 True	 False	 False	 xxx	 True
# free	 983	 True	 False	 False	 xxxx	 False
# from	 988	 True	 False	 False	 xxxx	 True
# apprehension	 993	 True	 False	 False	 xxxx	 False
# that	 1006	 True	 False	 False	 xxxx	 True
# he	 1011	 True	 False	 False	 xx	 True
# would	 1014	 True	 False	 False	 xxxx	 True
# come	 1020	 True	 False	 False	 xxxx	 False
# back	 1025	 True	 False	 False	 xxxx	 True
# to	 1030	 True	 False	 False	 xx	 True
# propound	 1033	 True	 False	 False	 xxxx	 False
#
# 	 1041	 False	 False	 True
# 	 False
# through	 1042	 True	 False	 False	 xxxx	 True
# the	 1050	 True	 False	 False	 xxx	 True
# gate	 1054	 True	 False	 False	 xxxx	 False
# ,	 1058	 False	 True	 False	 ,	 False
# "	 1060	 False	 True	 False	 "	 False
# And	 1061	 True	 False	 False	 Xxx	 True
# sixteen	 1065	 True	 False	 False	 xxxx	 False
# ?	 1072	 False	 True	 False	 ?	 False
# "	 1073	 False	 True	 False	 "	 False
# But	 1075	 True	 False	 False	 Xxx	 True
# he	 1079	 True	 False	 False	 xx	 True
# did	 1082	 True	 False	 False	 xxx	 True
# n't	 1085	 False	 False	 False	 x'x	 True
# .	 1088	 False	 True	 False	 .	 False
#
# 	 1089	 False	 False	 True
# 	 False
# My	 1090	 True	 False	 False	 Xx	 True
# young	 1093	 True	 False	 False	 xxxx	 False
# conductress	 1099	 True	 False	 False	 xxxx	 False
# locked	 1111	 True	 False	 False	 xxxx	 False
# the	 1118	 True	 False	 False	 xxx	 True
# gate	 1122	 True	 False	 False	 xxxx	 False
# ,	 1126	 False	 True	 False	 ,	 False
# and	 1128	 True	 False	 False	 xxx	 True
# we	 1132	 True	 False	 False	 xx	 True
# went	 1135	 True	 False	 False	 xxxx	 False
# across	 1140	 True	 False	 False	 xxxx	 True
# the	 1147	 True	 False	 False	 xxx	 True
# court	 1151	 True	 False	 False	 xxxx	 False
# -	 1156	 False	 True	 False	 -	 False
# yard	 1157	 True	 False	 False	 xxxx	 False
# .	 1161	 False	 True	 False	 .	 False
# It	 1163	 True	 False	 False	 Xx	 True
# was	 1166	 True	 False	 False	 xxx	 True
# paved	 1170	 True	 False	 False	 xxxx	 False
# and	 1176	 True	 False	 False	 xxx	 True
# clean	 1180	 True	 False	 False	 xxxx	 False
# ,	 1185	 False	 True	 False	 ,	 False
# but	 1187	 True	 False	 False	 xxx	 True
#
# 	 1190	 False	 False	 True
# 	 False
# grass	 1191	 True	 False	 False	 xxxx	 False
# was	 1197	 True	 False	 False	 xxx	 True
# growing	 1201	 True	 False	 False	 xxxx	 False
# in	 1209	 True	 False	 False	 xx	 True
# every	 1212	 True	 False	 False	 xxxx	 True
# crevice	 1218	 True	 False	 False	 xxxx	 False
# .	 1225	 False	 True	 False	 .	 False
# The	 1227	 True	 False	 False	 Xxx	 True
# brewery	 1231	 True	 False	 False	 xxxx	 False
# buildings	 1239	 True	 False	 False	 xxxx	 False
# had	 1249	 True	 False	 False	 xxx	 True
# a	 1253	 True	 False	 False	 x	 True
# little	 1255	 True	 False	 False	 xxxx	 False
# lane	 1262	 True	 False	 False	 xxxx	 False
# of	 1267	 True	 False	 False	 xx	 True
# communication	 1270	 True	 False	 False	 xxxx	 False
# with	 1284	 True	 False	 False	 xxxx	 True
# it	 1289	 True	 False	 False	 xx	 True
# ,	 1291	 False	 True	 False	 ,	 False
# and	 1293	 True	 False	 False	 xxx	 True
#
# 	 1296	 False	 False	 True
# 	 False
# the	 1297	 True	 False	 False	 xxx	 True
# wooden	 1301	 True	 False	 False	 xxxx	 False
# gates	 1308	 True	 False	 False	 xxxx	 False
# of	 1314	 True	 False	 False	 xx	 True
# that	 1317	 True	 False	 False	 xxxx	 True
# lane	 1322	 True	 False	 False	 xxxx	 False
# stood	 1327	 True	 False	 False	 xxxx	 False
# open	 1333	 True	 False	 False	 xxxx	 False
# ,	 1337	 False	 True	 False	 ,	 False
# and	 1339	 True	 False	 False	 xxx	 True
# all	 1343	 True	 False	 False	 xxx	 True
# the	 1347	 True	 False	 False	 xxx	 True
# brewery	 1351	 True	 False	 False	 xxxx	 False
# beyond	 1359	 True	 False	 False	 xxxx	 True
# ,	 1365	 False	 True	 False	 ,	 False
# stood	 1367	 True	 False	 False	 xxxx	 False
# open	 1373	 True	 False	 False	 xxxx	 False
# ,	 1377	 False	 True	 False	 ,	 False
# away	 1379	 True	 False	 False	 xxxx	 False
# to	 1384	 True	 False	 False	 xx	 True
# the	 1387	 True	 False	 False	 xxx	 True
# high	 1391	 True	 False	 False	 xxxx	 False
#
# 	 1395	 False	 False	 True
# 	 False
# enclosing	 1396	 True	 False	 False	 xxxx	 False
# wall	 1406	 True	 False	 False	 xxxx	 False
# ;	 1410	 False	 True	 False	 ;	 False
# and	 1412	 True	 False	 False	 xxx	 True
# all	 1416	 True	 False	 False	 xxx	 True
# was	 1420	 True	 False	 False	 xxx	 True
# empty	 1424	 True	 False	 False	 xxxx	 True
# and	 1430	 True	 False	 False	 xxx	 True
# disused	 1434	 True	 False	 False	 xxxx	 False
# .	 1441	 False	 True	 False	 .	 False
# The	 1443	 True	 False	 False	 Xxx	 True
# cold	 1447	 True	 False	 False	 xxxx	 False
# wind	 1452	 True	 False	 False	 xxxx	 False
# seemed	 1457	 True	 False	 False	 xxxx	 True
# to	 1464	 True	 False	 False	 xx	 True
# blow	 1467	 True	 False	 False	 xxxx	 False
# colder	 1472	 True	 False	 False	 xxxx	 False
# there	 1479	 True	 False	 False	 xxxx	 True
# ,	 1484	 False	 True	 False	 ,	 False
# than	 1486	 True	 False	 False	 xxxx	 True
# outside	 1491	 True	 False	 False	 xxxx	 False
#
# 	 1498	 False	 False	 True
# 	 False
# the	 1499	 True	 False	 False	 xxx	 True
# gate	 1503	 True	 False	 False	 xxxx	 False
# ;	 1507	 False	 True	 False	 ;	 False
# and	 1509	 True	 False	 False	 xxx	 True
# it	 1513	 True	 False	 False	 xx	 True
# made	 1516	 True	 False	 False	 xxxx	 True
# a	 1521	 True	 False	 False	 x	 True
# shrill	 1523	 True	 False	 False	 xxxx	 False
# noise	 1530	 True	 False	 False	 xxxx	 False
# in	 1536	 True	 False	 False	 xx	 True
# howling	 1539	 True	 False	 False	 xxxx	 False
# in	 1547	 True	 False	 False	 xx	 True
# and	 1550	 True	 False	 False	 xxx	 True
# out	 1554	 True	 False	 False	 xxx	 True
# at	 1558	 True	 False	 False	 xx	 True
# the	 1561	 True	 False	 False	 xxx	 True
# open	 1565	 True	 False	 False	 xxxx	 False
# sides	 1570	 True	 False	 False	 xxxx	 False
# of	 1576	 True	 False	 False	 xx	 True
# the	 1579	 True	 False	 False	 xxx	 True
# brewery	 1583	 True	 False	 False	 xxxx	 False
# ,	 1590	 False	 True	 False	 ,	 False
# like	 1592	 True	 False	 False	 xxxx	 False
# the	 1597	 True	 False	 False	 xxx	 True
# noise	 1601	 True	 False	 False	 xxxx	 False
# of	 1607	 True	 False	 False	 xx	 True
#
# 	 1609	 False	 False	 True
# 	 False
# wind	 1610	 True	 False	 False	 xxxx	 False
# in	 1615	 True	 False	 False	 xx	 True
# the	 1618	 True	 False	 False	 xxx	 True
# rigging	 1622	 True	 False	 False	 xxxx	 False
# of	 1630	 True	 False	 False	 xx	 True
# a	 1633	 True	 False	 False	 x	 True
# ship	 1635	 True	 False	 False	 xxxx	 False
# at	 1640	 True	 False	 False	 xx	 True
# sea	 1643	 True	 False	 False	 xxx	 False
# .	 1646	 False	 True	 False	 .	 False
#
# 	 1647	 False	 False	 True
# 	 False
# She	 1648	 True	 False	 False	 Xxx	 True
# saw	 1652	 True	 False	 False	 xxx	 False
# me	 1656	 True	 False	 False	 xx	 True
# looking	 1659	 True	 False	 False	 xxxx	 False
# at	 1667	 True	 False	 False	 xx	 True
# it	 1670	 True	 False	 False	 xx	 True
# ,	 1672	 False	 True	 False	 ,	 False
# and	 1674	 True	 False	 False	 xxx	 True
# she	 1678	 True	 False	 False	 xxx	 True
# said	 1682	 True	 False	 False	 xxxx	 False
# ,	 1686	 False	 True	 False	 ,	 False
# "	 1688	 False	 True	 False	 "	 False
# You	 1689	 True	 False	 False	 Xxx	 True
# could	 1693	 True	 False	 False	 xxxx	 True
# drink	 1699	 True	 False	 False	 xxxx	 False
# without	 1705	 True	 False	 False	 xxxx	 True
# hurt	 1713	 True	 False	 False	 xxxx	 False
# all	 1718	 True	 False	 False	 xxx	 True
# the	 1722	 True	 False	 False	 xxx	 True
# strong	 1726	 True	 False	 False	 xxxx	 False
# beer	 1733	 True	 False	 False	 xxxx	 False
# that	 1738	 True	 False	 False	 xxxx	 True
# 's	 1742	 False	 False	 False	 'x	 True
# brewed	 1745	 True	 False	 False	 xxxx	 False
#
# 	 1751	 False	 False	 True
# 	 False
# there	 1752	 True	 False	 False	 xxxx	 True
# now	 1758	 True	 False	 False	 xxx	 True
# ,	 1761	 False	 True	 False	 ,	 False
# boy	 1763	 True	 False	 False	 xxx	 False
# .	 1766	 False	 True	 False	 .	 False
# "	 1767	 False	 True	 False	 "	 False
#
# 	 1768	 False	 False	 True
# 	 False
# "	 1769	 False	 True	 False	 "	 False
# I	 1770	 True	 False	 False	 X	 True
# should	 1772	 True	 False	 False	 xxxx	 True
# think	 1779	 True	 False	 False	 xxxx	 False
# I	 1785	 True	 False	 False	 X	 True
# could	 1787	 True	 False	 False	 xxxx	 True
# ,	 1792	 False	 True	 False	 ,	 False
# miss	 1794	 True	 False	 False	 xxxx	 False
# ,	 1798	 False	 True	 False	 ,	 False
# "	 1799	 False	 True	 False	 "	 False
# said	 1801	 True	 False	 False	 xxxx	 False
# I	 1806	 True	 False	 False	 X	 True
# ,	 1807	 False	 True	 False	 ,	 False
# in	 1809	 True	 False	 False	 xx	 True
# a	 1812	 True	 False	 False	 x	 True
# shy	 1814	 True	 False	 False	 xxx	 False
# way	 1818	 True	 False	 False	 xxx	 False
# .	 1821	 False	 True	 False	 .	 False
#
# 	 1822	 False	 False	 True
# 	 False
# "	 1823	 False	 True	 False	 "	 False
# Better	 1824	 True	 False	 False	 Xxxxx	 False
# not	 1831	 True	 False	 False	 xxx	 True
# try	 1835	 True	 False	 False	 xxx	 False
# to	 1839	 True	 False	 False	 xx	 True
# brew	 1842	 True	 False	 False	 xxxx	 False
# beer	 1847	 True	 False	 False	 xxxx	 False
# there	 1852	 True	 False	 False	 xxxx	 True
# now	 1858	 True	 False	 False	 xxx	 True
# ,	 1861	 False	 True	 False	 ,	 False
# or	 1863	 True	 False	 False	 xx	 True
# it	 1866	 True	 False	 False	 xx	 True
# would	 1869	 True	 False	 False	 xxxx	 True
# turn	 1875	 True	 False	 False	 xxxx	 False
# out	 1880	 True	 False	 False	 xxx	 True
# sour	 1884	 True	 False	 False	 xxxx	 False
# ,	 1888	 False	 True	 False	 ,	 False
# boy	 1890	 True	 False	 False	 xxx	 False
# ;	 1893	 False	 True	 False	 ;	 False
# do	 1895	 True	 False	 False	 xx	 True
# n't	 1897	 False	 False	 False	 x'x	 True
# you	 1901	 True	 False	 False	 xxx	 True
# think	 1905	 True	 False	 False	 xxxx	 False
# so	 1911	 True	 False	 False	 xx	 True
# ?	 1913	 False	 True	 False	 ?	 False
# "	 1914	 False	 True	 False	 "	 False
#
# 	 1915	 False	 False	 True
# 	 False
# "	 1916	 False	 True	 False	 "	 False
# It	 1917	 True	 False	 False	 Xx	 True
# looks	 1920	 True	 False	 False	 xxxx	 False
# like	 1926	 True	 False	 False	 xxxx	 False
# it	 1931	 True	 False	 False	 xx	 True
# ,	 1933	 False	 True	 False	 ,	 False
# miss	 1935	 True	 False	 False	 xxxx	 False
# .	 1939	 False	 True	 False	 .	 False
# "	 1940	 False	 True	 False	 "	 False
#
# 	 1941	 False	 False	 True
# 	 False
# "	 1942	 False	 True	 False	 "	 False
# Not	 1943	 True	 False	 False	 Xxx	 True
# that	 1947	 True	 False	 False	 xxxx	 True
# anybody	 1952	 True	 False	 False	 xxxx	 False
# means	 1960	 True	 False	 False	 xxxx	 False
# to	 1966	 True	 False	 False	 xx	 True
# try	 1969	 True	 False	 False	 xxx	 False
# ,	 1972	 False	 True	 False	 ,	 False
# "	 1973	 False	 True	 False	 "	 False
# she	 1975	 True	 False	 False	 xxx	 True
# added	 1979	 True	 False	 False	 xxxx	 False
# ,	 1984	 False	 True	 False	 ,	 False
# "	 1986	 False	 True	 False	 "	 False
# for	 1987	 True	 False	 False	 xxx	 True
# that	 1991	 True	 False	 False	 xxxx	 True
# 's	 1995	 False	 False	 False	 'x	 True
# all	 1998	 True	 False	 False	 xxx	 True
# done	 2002	 True	 False	 False	 xxxx	 True
# with	 2007	 True	 False	 False	 xxxx	 True
# ,	 2011	 False	 True	 False	 ,	 False
# and	 2013	 True	 False	 False	 xxx	 True
# the	 2017	 True	 False	 False	 xxx	 True
# place	 2021	 True	 False	 False	 xxxx	 False
# will	 2027	 True	 False	 False	 xxxx	 True
# stand	 2032	 True	 False	 False	 xxxx	 False
# as	 2038	 True	 False	 False	 xx	 True
# idle	 2041	 True	 False	 False	 xxxx	 False
# as	 2046	 True	 False	 False	 xx	 True
# it	 2049	 True	 False	 False	 xx	 True
#
# 	 2051	 False	 False	 True
# 	 False
# is	 2052	 True	 False	 False	 xx	 True
# ,	 2054	 False	 True	 False	 ,	 False
# till	 2056	 True	 False	 False	 xxxx	 False
# it	 2061	 True	 False	 False	 xx	 True
# falls	 2064	 True	 False	 False	 xxxx	 False
# .	 2069	 False	 True	 False	 .	 False
# As	 2071	 True	 False	 False	 Xx	 True
# to	 2074	 True	 False	 False	 xx	 True
# strong	 2077	 True	 False	 False	 xxxx	 False
# beer	 2084	 True	 False	 False	 xxxx	 False
# ,	 2088	 False	 True	 False	 ,	 False
# there	 2090	 True	 False	 False	 xxxx	 True
# 's	 2095	 False	 False	 False	 'x	 True
# enough	 2098	 True	 False	 False	 xxxx	 True
# of	 2105	 True	 False	 False	 xx	 True
# it	 2108	 True	 False	 False	 xx	 True
# in	 2111	 True	 False	 False	 xx	 True
# the	 2114	 True	 False	 False	 xxx	 True
# cellars	 2118	 True	 False	 False	 xxxx	 False
# already	 2126	 True	 False	 False	 xxxx	 True
# ,	 2133	 False	 True	 False	 ,	 False
# to	 2135	 True	 False	 False	 xx	 True
# drown	 2138	 True	 False	 False	 xxxx	 False
# the	 2144	 True	 False	 False	 xxx	 True
# Manor	 2148	 True	 False	 False	 Xxxxx	 False
# House	 2154	 True	 False	 False	 Xxxxx	 False
# .	 2159	 False	 True	 False	 .	 False
# "	 2160	 False	 True	 False	 "	 False
#
# 	 2161	 False	 False	 True
# 	 False
# "	 2162	 False	 True	 False	 "	 False
# Is	 2163	 True	 False	 False	 Xx	 True
# that	 2166	 True	 False	 False	 xxxx	 True
# the	 2171	 True	 False	 False	 xxx	 True
# name	 2175	 True	 False	 False	 xxxx	 True
# of	 2180	 True	 False	 False	 xx	 True
# this	 2183	 True	 False	 False	 xxxx	 True
# house	 2188	 True	 False	 False	 xxxx	 False
# ,	 2193	 False	 True	 False	 ,	 False
# miss	 2195	 True	 False	 False	 xxxx	 False
# ?	 2199	 False	 True	 False	 ?	 False
# "	 2200	 False	 True	 False	 "	 False
#
# 	 2201	 False	 False	 True
# 	 False
# "	 2202	 False	 True	 False	 "	 False
# One	 2203	 True	 False	 False	 Xxx	 True
# of	 2207	 True	 False	 False	 xx	 True
# its	 2210	 True	 False	 False	 xxx	 True
# names	 2214	 True	 False	 False	 xxxx	 False
# ,	 2219	 False	 True	 False	 ,	 False
# boy	 2221	 True	 False	 False	 xxx	 False
# .	 2224	 False	 True	 False	 .	 False
# "	 2225	 False	 True	 False	 "	 False
#
# 	 2226	 False	 False	 True
# 	 False
# "	 2227	 False	 True	 False	 "	 False
# It	 2228	 True	 False	 False	 Xx	 True
# has	 2231	 True	 False	 False	 xxx	 True
# more	 2235	 True	 False	 False	 xxxx	 True
# than	 2240	 True	 False	 False	 xxxx	 True
# one	 2245	 True	 False	 False	 xxx	 True
# ,	 2248	 False	 True	 False	 ,	 False
# then	 2250	 True	 False	 False	 xxxx	 True
# ,	 2254	 False	 True	 False	 ,	 False
# miss	 2256	 True	 False	 False	 xxxx	 False
# ?	 2260	 False	 True	 False	 ?	 False
# "	 2261	 False	 True	 False	 "	 False
#
# 	 2262	 False	 False	 True
# 	 False
# "	 2263	 False	 True	 False	 "	 False
# One	 2264	 True	 False	 False	 Xxx	 True
# more	 2268	 True	 False	 False	 xxxx	 True
# .	 2272	 False	 True	 False	 .	 False
# Its	 2274	 True	 False	 False	 Xxx	 True
# other	 2278	 True	 False	 False	 xxxx	 True
# name	 2284	 True	 False	 False	 xxxx	 True
# was	 2289	 True	 False	 False	 xxx	 True
# Satis	 2293	 True	 False	 False	 Xxxxx	 False
# ;	 2298	 False	 True	 False	 ;	 False
# which	 2300	 True	 False	 False	 xxxx	 True
# is	 2306	 True	 False	 False	 xx	 True
# Greek	 2309	 True	 False	 False	 Xxxxx	 False
# ,	 2314	 False	 True	 False	 ,	 False
# or	 2316	 True	 False	 False	 xx	 True
# Latin	 2319	 True	 False	 False	 Xxxxx	 False
# ,	 2324	 False	 True	 False	 ,	 False
# or	 2326	 True	 False	 False	 xx	 True
# Hebrew	 2329	 True	 False	 False	 Xxxxx	 False
# ,	 2335	 False	 True	 False	 ,	 False
# or	 2337	 True	 False	 False	 xx	 True
# all	 2340	 True	 False	 False	 xxx	 True
# three	 2344	 True	 False	 False	 xxxx	 True
# -	 2350	 False	 True	 False	 -	 False
# or	 2352	 True	 False	 False	 xx	 True
# all	 2355	 True	 False	 False	 xxx	 True
# one	 2359	 True	 False	 False	 xxx	 True
# to	 2363	 True	 False	 False	 xx	 True
# me	 2366	 True	 False	 False	 xx	 True
# -	 2369	 False	 True	 False	 -	 False
#
# 	 2370	 False	 False	 True
# 	 False
# for	 2371	 True	 False	 False	 xxx	 True
# enough	 2375	 True	 False	 False	 xxxx	 True
# .	 2381	 False	 True	 False	 .	 False
# "	 2382	 False	 True	 False	 "	 False
#
# 	 2383	 False	 False	 True
# 	 False
# "	 2384	 False	 True	 False	 "	 False
# Enough	 2385	 True	 False	 False	 Xxxxx	 True
# House	 2392	 True	 False	 False	 Xxxxx	 False
# ,	 2397	 False	 True	 False	 ,	 False
# "	 2398	 False	 True	 False	 "	 False
# said	 2400	 True	 False	 False	 xxxx	 False
# I	 2405	 True	 False	 False	 X	 True
# ;	 2406	 False	 True	 False	 ;	 False
# "	 2408	 False	 True	 False	 "	 False
# that	 2409	 True	 False	 False	 xxxx	 True
# 's	 2413	 False	 False	 False	 'x	 True
# a	 2416	 True	 False	 False	 x	 True
# curious	 2418	 True	 False	 False	 xxxx	 False
# name	 2426	 True	 False	 False	 xxxx	 True
# ,	 2430	 False	 True	 False	 ,	 False
# miss	 2432	 True	 False	 False	 xxxx	 False
# .	 2436	 False	 True	 False	 .	 False
# "	 2437	 False	 True	 False	 "	 False
#
# 	 2438	 False	 False	 True
# 	 False
# "	 2439	 False	 True	 False	 "	 False
# Yes	 2440	 True	 False	 False	 Xxx	 False
# ,	 2443	 False	 True	 False	 ,	 False
# "	 2444	 False	 True	 False	 "	 False
# she	 2446	 True	 False	 False	 xxx	 True
# replied	 2450	 True	 False	 False	 xxxx	 False
# ;	 2457	 False	 True	 False	 ;	 False
# "	 2459	 False	 True	 False	 "	 False
# but	 2460	 True	 False	 False	 xxx	 True
# it	 2464	 True	 False	 False	 xx	 True
# meant	 2467	 True	 False	 False	 xxxx	 False
# more	 2473	 True	 False	 False	 xxxx	 True
# than	 2478	 True	 False	 False	 xxxx	 True
# it	 2483	 True	 False	 False	 xx	 True
# said	 2486	 True	 False	 False	 xxxx	 False
# .	 2490	 False	 True	 False	 .	 False
# It	 2492	 True	 False	 False	 Xx	 True
# meant	 2495	 True	 False	 False	 xxxx	 False
# ,	 2500	 False	 True	 False	 ,	 False
# when	 2502	 True	 False	 False	 xxxx	 True
# it	 2507	 True	 False	 False	 xx	 True
# was	 2510	 True	 False	 False	 xxx	 True
# given	 2514	 True	 False	 False	 xxxx	 False
# ,	 2519	 False	 True	 False	 ,	 False
# that	 2521	 True	 False	 False	 xxxx	 True
# whoever	 2526	 True	 False	 False	 xxxx	 True
# had	 2534	 True	 False	 False	 xxx	 True
# this	 2538	 True	 False	 False	 xxxx	 True
#
# 	 2542	 False	 False	 True
# 	 False
# house	 2543	 True	 False	 False	 xxxx	 False
# ,	 2548	 False	 True	 False	 ,	 False
# could	 2550	 True	 False	 False	 xxxx	 True
# want	 2556	 True	 False	 False	 xxxx	 False
# nothing	 2561	 True	 False	 False	 xxxx	 True
# else	 2569	 True	 False	 False	 xxxx	 True
# .	 2573	 False	 True	 False	 .	 False
# They	 2575	 True	 False	 False	 Xxxx	 True
# must	 2580	 True	 False	 False	 xxxx	 True
# have	 2585	 True	 False	 False	 xxxx	 True
# been	 2590	 True	 False	 False	 xxxx	 True
# easily	 2595	 True	 False	 False	 xxxx	 False
# satisfied	 2602	 True	 False	 False	 xxxx	 False
# in	 2612	 True	 False	 False	 xx	 True
# those	 2615	 True	 False	 False	 xxxx	 True
# days	 2621	 True	 False	 False	 xxxx	 False
# ,	 2625	 False	 True	 False	 ,	 False
# I	 2627	 True	 False	 False	 X	 True
# should	 2629	 True	 False	 False	 xxxx	 True
# think	 2636	 True	 False	 False	 xxxx	 False
# .	 2641	 False	 True	 False	 .	 False
# But	 2643	 True	 False	 False	 Xxx	 True
#
# 	 2646	 False	 False	 True
# 	 False
# do	 2647	 True	 False	 False	 xx	 True
# n't	 2649	 False	 False	 False	 x'x	 True
# loiter	 2653	 True	 False	 False	 xxxx	 False
# ,	 2659	 False	 True	 False	 ,	 False
# boy	 2661	 True	 False	 False	 xxx	 False
# .	 2664	 False	 True	 False	 .	 False
# "	 2665	 False	 True	 False	 "	 False
#
# 	 2667	 False	 False	 True
# 	 False

# %%
print("token\t lemma_\t norm_\t tag\t pos_\t morph")
for token in dickens_doc:
    print("{}\t {}\t {}\t {}\t {}\t {}\t"
            .format(token, token.lemma_, token.norm_, token.tag_, token.pos_, token.morph))
# Out:
# token	 lemma_	 norm_	 tag	 pos_	 morph
# A	 a	 a	 DT	 DET	 Definite=Ind|PronType=Art
# window	 window	 window	 NN	 NOUN	 Number=Sing
# was	 be	 was	 VBD	 AUX	 Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# raised	 raise	 raised	 VBN	 VERB	 Aspect=Perf|Tense=Past|VerbForm=Part
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# and	 and	 and	 CC	 CCONJ	 ConjType=Cmp
# a	 a	 a	 DT	 DET	 Definite=Ind|PronType=Art
# clear	 clear	 clear	 JJ	 ADJ	 Degree=Pos
# voice	 voice	 voice	 NN	 NOUN	 Number=Sing
# demanded	 demand	 demanded	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# What	 what	 what	 WDT	 DET
# name	 name	 name	 NN	 NOUN	 Number=Sing
# ?	 ?	 ?	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
# To	 to	 to	 TO	 PART
# which	 which	 which	 WDT	 DET
# my	 my	 my	 PRP$	 PRON	 Number=Sing|Person=1|Poss=Yes|PronType=Prs
# conductor	 conductor	 conductor	 NN	 NOUN	 Number=Sing
# replied	 reply	 replied	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
#
#
#
# 	 _SP	 SPACE	 PunctSide=Fin|PunctType=Quot
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# Pumblechook	 Pumblechook	 pumblechook	 NNP	 PROPN	 NounType=Prop|Number=Sing
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
# The	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# voice	 voice	 voice	 NN	 NOUN	 Number=Sing
# returned	 return	 returned	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# Quite	 quite	 quite	 RB	 ADV
# right	 right	 right	 RB	 ADV
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
# and	 and	 and	 CC	 CCONJ	 ConjType=Cmp
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# window	 window	 window	 NN	 NOUN	 Number=Sing
# was	 be	 was	 VBD	 AUX	 Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# shut	 shut	 shut	 VBN	 VERB	 Aspect=Perf|Tense=Past|VerbForm=Part
# again	 again	 again	 RB	 ADV
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# and	 and	 and	 CC	 CCONJ	 ConjType=Cmp
# a	 a	 a	 DT	 DET	 Definite=Ind|PronType=Art
# young	 young	 young	 JJ	 ADJ	 Degree=Pos
# lady	 lady	 lady	 NN	 NOUN	 Number=Sing
#
#
#
# 	 _SP	 SPACE	 Number=Sing
# came	 come	 came	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# across	 across	 across	 IN	 ADP
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# court	 court	 court	 NN	 NOUN	 Number=Sing
# -	 -	 -	 HYPH	 PUNCT	 PunctType=Dash
# yard	 yard	 yard	 NN	 NOUN	 Number=Sing
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# with	 with	 with	 IN	 ADP
# keys	 key	 keys	 NNS	 NOUN	 Number=Plur
# in	 in	 in	 IN	 ADP
# her	 her	 her	 PRP$	 PRON	 Gender=Fem|Number=Sing|Person=3|Poss=Yes|PronType=Prs
# hand	 hand	 hand	 NN	 NOUN	 Number=Sing
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
#
#
#
# 	 _SP	 SPACE	 PunctSide=Fin|PunctType=Quot
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# This	 this	 this	 DT	 DET	 Number=Sing|PronType=Dem
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
# said	 say	 said	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# Mr.	 Mr.	 mr.	 NNP	 PROPN	 NounType=Prop|Number=Sing
# Pumblechook	 Pumblechook	 pumblechook	 NNP	 PROPN	 NounType=Prop|Number=Sing
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
# is	 be	 is	 VBZ	 AUX	 Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Pip	 Pip	 pip	 NNP	 PROPN	 NounType=Prop|Number=Sing
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
#
#
#
# 	 _SP	 SPACE	 PunctSide=Fin|PunctType=Quot
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# This	 this	 this	 DT	 DET	 Number=Sing|PronType=Dem
# is	 be	 is	 VBZ	 AUX	 Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Pip	 Pip	 pip	 NNP	 PROPN	 NounType=Prop|Number=Sing
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# is	 be	 is	 VBZ	 AUX	 Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# it	 it	 it	 PRP	 PRON	 Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# ?	 ?	 ?	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
# returned	 return	 returned	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# young	 young	 young	 JJ	 ADJ	 Degree=Pos
# lady	 lady	 lady	 NN	 NOUN	 Number=Sing
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# who	 who	 who	 WP	 PRON
# was	 be	 was	 VBD	 VERB	 Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# very	 very	 very	 RB	 ADV
# pretty	 pretty	 pretty	 RB	 ADV
# and	 and	 and	 CC	 CCONJ	 ConjType=Cmp
# seemed	 seem	 seemed	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# very	 very	 very	 RB	 ADV
# proud	 proud	 proud	 JJ	 ADJ	 Degree=Pos
# ;	 ;	 ;	 :	 PUNCT
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# come	 come	 come	 VB	 VERB	 VerbForm=Inf
# in	 in	 in	 RP	 ADP
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# Pip	 Pip	 pip	 NNP	 PROPN	 NounType=Prop|Number=Sing
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
#
#
#
# 	 _SP	 SPACE	 NounType=Prop|Number=Sing
# Mr.	 Mr.	 mr.	 NNP	 PROPN	 NounType=Prop|Number=Sing
# Pumblechook	 Pumblechook	 pumblechook	 NNP	 PROPN	 NounType=Prop|Number=Sing
# was	 be	 was	 VBD	 AUX	 Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# coming	 come	 coming	 VBG	 VERB	 Aspect=Prog|Tense=Pres|VerbForm=Part
# in	 in	 in	 RP	 ADP
# also	 also	 also	 RB	 ADV
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# when	 when	 when	 WRB	 ADV
# she	 she	 she	 PRP	 PRON	 Case=Nom|Gender=Fem|Number=Sing|Person=3|PronType=Prs
# stopped	 stop	 stopped	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# him	 he	 him	 PRP	 PRON	 Case=Acc|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# with	 with	 with	 IN	 ADP
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# gate	 gate	 gate	 NN	 NOUN	 Number=Sing
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
#
#
#
# 	 _SP	 SPACE	 PunctSide=Fin|PunctType=Quot
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# Oh	 oh	 oh	 UH	 INTJ
# !	 !	 !	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
# she	 she	 she	 PRP	 PRON	 Case=Nom|Gender=Fem|Number=Sing|Person=3|PronType=Prs
# said	 say	 said	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# Did	 do	 did	 VBD	 AUX	 Tense=Past|VerbForm=Fin
# you	 you	 you	 PRP	 PRON	 Case=Nom|Person=2|PronType=Prs
# wish	 wish	 wish	 VB	 VERB	 VerbForm=Inf
# to	 to	 to	 TO	 PART
# see	 see	 see	 VB	 VERB	 VerbForm=Inf
# Miss	 Miss	 miss	 NNP	 PROPN	 NounType=Prop|Number=Sing
# Havisham	 Havisham	 havisham	 NNP	 PROPN	 NounType=Prop|Number=Sing
# ?	 ?	 ?	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
#
#
#
# 	 _SP	 SPACE	 PunctSide=Fin|PunctType=Quot
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# If	 if	 if	 IN	 SCONJ
# Miss	 Miss	 miss	 NNP	 PROPN	 NounType=Prop|Number=Sing
# Havisham	 Havisham	 havisham	 NNP	 PROPN	 NounType=Prop|Number=Sing
# wished	 wish	 wished	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# to	 to	 to	 TO	 PART
# see	 see	 see	 VB	 VERB	 VerbForm=Inf
# me	 I	 me	 PRP	 PRON	 Case=Acc|Number=Sing|Person=1|PronType=Prs
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
# returned	 return	 returned	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# Mr.	 Mr.	 mr.	 NNP	 PROPN	 NounType=Prop|Number=Sing
# Pumblechook	 Pumblechook	 pumblechook	 NNP	 PROPN	 NounType=Prop|Number=Sing
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# discomfited	 discomfited	 discomfited	 JJ	 ADJ	 Degree=Pos
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
#
#
#
# 	 _SP	 SPACE	 PunctSide=Fin|PunctType=Quot
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# Ah	 ah	 ah	 UH	 INTJ
# !	 !	 !	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
# said	 say	 said	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# girl	 girl	 girl	 NN	 NOUN	 Number=Sing
# ;	 ;	 ;	 :	 PUNCT
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# but	 but	 but	 CC	 CCONJ	 ConjType=Cmp
# you	 you	 you	 PRP	 PRON	 Case=Nom|Person=2|PronType=Prs
# see	 see	 see	 VBP	 VERB	 Tense=Pres|VerbForm=Fin
# she	 she	 she	 PRP	 PRON	 Case=Nom|Gender=Fem|Number=Sing|Person=3|PronType=Prs
# do	 do	 do	 VBP	 VERB	 Mood=Ind|Tense=Pres|VerbForm=Fin
# n't	 n't	 not	 RB	 PART
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
#
#
#
# 	 _SP	 SPACE	 PunctSide=Fin|PunctType=Quot
# She	 she	 she	 PRP	 PRON	 Case=Nom|Gender=Fem|Number=Sing|Person=3|PronType=Prs
# said	 say	 said	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# it	 it	 it	 PRP	 PRON	 Case=Acc|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# so	 so	 so	 RB	 ADV
# finally	 finally	 finally	 RB	 ADV
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# and	 and	 and	 CC	 CCONJ	 ConjType=Cmp
# in	 in	 in	 IN	 ADP
# such	 such	 such	 PDT	 DET
# an	 an	 an	 DT	 DET	 Definite=Ind|PronType=Art
# undiscussible	 undiscussible	 undiscussible	 JJ	 ADJ	 Degree=Pos
# way	 way	 way	 NN	 NOUN	 Number=Sing
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# that	 that	 that	 IN	 SCONJ
# Mr.	 Mr.	 mr.	 NNP	 PROPN	 NounType=Prop|Number=Sing
# Pumblechook	 Pumblechook	 pumblechook	 NNP	 PROPN	 NounType=Prop|Number=Sing
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# though	 though	 though	 IN	 SCONJ
# in	 in	 in	 IN	 ADP
# a	 a	 a	 DT	 DET	 Definite=Ind|PronType=Art
# condition	 condition	 condition	 NN	 NOUN	 Number=Sing
# of	 of	 of	 IN	 ADP
#
#
#
# 	 _SP	 SPACE	 Number=Sing
# ruffled	 ruffle	 ruffled	 VBN	 VERB	 Aspect=Perf|Tense=Past|VerbForm=Part
# dignity	 dignity	 dignity	 NN	 NOUN	 Number=Sing
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# could	 could	 could	 MD	 AUX	 VerbForm=Fin
# not	 not	 not	 RB	 PART
# protest	 protest	 protest	 VB	 VERB	 VerbForm=Inf
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# But	 but	 but	 CC	 CCONJ	 ConjType=Cmp
# he	 he	 he	 PRP	 PRON	 Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# eyed	 eye	 eyed	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# me	 I	 me	 PRP	 PRON	 Case=Acc|Number=Sing|Person=1|PronType=Prs
# severely	 severely	 severely	 RB	 ADV
# -	 -	 -	 :	 PUNCT
# as	 as	 as	 IN	 ADP
# if	 if	 if	 IN	 SCONJ
# I	 I	 i	 PRP	 PRON	 Case=Nom|Number=Sing|Person=1|PronType=Prs
# had	 have	 had	 VBD	 AUX	 Tense=Past|VerbForm=Fin
# done	 do	 done	 VBN	 VERB	 Aspect=Perf|Tense=Past|VerbForm=Part
# anything	 anything	 anything	 NN	 PRON	 Number=Sing
# to	 to	 to	 IN	 ADP
# him	 he	 him	 PRP	 PRON	 Case=Acc|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# !	 !	 !	 .	 PUNCT	 PunctType=Peri
# -	 -	 -	 :	 PUNCT
# and	 and	 and	 CC	 CCONJ	 ConjType=Cmp
#
#
#
# 	 _SP	 SPACE	 Number=Sing
# departed	 depart	 departed	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# with	 with	 with	 IN	 ADP
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# words	 word	 words	 NNS	 NOUN	 Number=Plur
# reproachfully	 reproachfully	 reproachfully	 RB	 ADV
# delivered	 deliver	 delivered	 VBN	 VERB	 Aspect=Perf|Tense=Past|VerbForm=Part
# :	 :	 :	 :	 PUNCT
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# Boy	 boy	 boy	 UH	 INTJ
# !	 !	 !	 .	 PUNCT	 PunctType=Peri
# Let	 let	 let	 VB	 VERB	 VerbForm=Inf
# your	 your	 your	 PRP$	 PRON	 Person=2|Poss=Yes|PronType=Prs
# behaviour	 behaviour	 behavior	 NN	 NOUN	 Number=Sing
# here	 here	 here	 RB	 ADV	 PronType=Dem
# be	 be	 be	 VB	 VERB	 VerbForm=Inf
# a	 a	 a	 DT	 DET	 Definite=Ind|PronType=Art
# credit	 credit	 credit	 NN	 NOUN	 Number=Sing
# unto	 unto	 unto	 IN	 ADP
# them	 they	 them	 PRP	 PRON	 Case=Acc|Number=Plur|Person=3|PronType=Prs
#
#
#
# 	 _SP	 SPACE
# which	 which	 which	 WDT	 DET
# brought	 bring	 brought	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# you	 you	 you	 PRP	 PRON	 Case=Acc|Person=2|PronType=Prs
# up	 up	 up	 RP	 ADP
# by	 by	 by	 IN	 ADP
# hand	 hand	 hand	 NN	 NOUN	 Number=Sing
# !	 !	 !	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# I	 I	 i	 PRP	 PRON	 Case=Nom|Number=Sing|Person=1|PronType=Prs
# was	 be	 was	 VBD	 AUX	 Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# not	 not	 not	 RB	 PART
# free	 free	 free	 JJ	 ADJ	 Degree=Pos
# from	 from	 from	 IN	 ADP
# apprehension	 apprehension	 apprehension	 NN	 NOUN	 Number=Sing
# that	 that	 that	 IN	 SCONJ
# he	 he	 he	 PRP	 PRON	 Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# would	 would	 would	 MD	 AUX	 VerbForm=Fin
# come	 come	 come	 VB	 VERB	 VerbForm=Inf
# back	 back	 back	 RB	 ADV
# to	 to	 to	 IN	 ADP
# propound	 propound	 propound	 NN	 NOUN	 Number=Sing
#
#
#
# 	 _SP	 SPACE	 Number=Sing
# through	 through	 through	 IN	 ADP
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# gate	 gate	 gate	 NN	 NOUN	 Number=Sing
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
# And	 and	 and	 CC	 CCONJ	 ConjType=Cmp
# sixteen	 sixteen	 sixteen	 CD	 NUM	 NumType=Card
# ?	 ?	 ?	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
# But	 but	 but	 CC	 CCONJ	 ConjType=Cmp
# he	 he	 he	 PRP	 PRON	 Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# did	 do	 do	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# n't	 n't	 not	 RB	 PART
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
#
#
#
# 	 _SP	 SPACE	 PunctSide=Fin|PunctType=Quot
# My	 my	 my	 PRP$	 PRON	 Number=Sing|Person=1|Poss=Yes|PronType=Prs
# young	 young	 young	 JJ	 ADJ	 Degree=Pos
# conductress	 conductress	 conductress	 NN	 NOUN	 Number=Sing
# locked	 lock	 locked	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# gate	 gate	 gate	 NN	 NOUN	 Number=Sing
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# and	 and	 and	 CC	 CCONJ	 ConjType=Cmp
# we	 we	 we	 PRP	 PRON	 Case=Nom|Number=Plur|Person=1|PronType=Prs
# went	 go	 went	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# across	 across	 across	 IN	 ADP
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# court	 court	 court	 NN	 NOUN	 Number=Sing
# -	 -	 -	 HYPH	 PUNCT	 PunctType=Dash
# yard	 yard	 yard	 NN	 NOUN	 Number=Sing
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# It	 it	 it	 PRP	 PRON	 Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# was	 be	 was	 VBD	 AUX	 Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# paved	 paved	 paved	 JJ	 ADJ	 Degree=Pos
# and	 and	 and	 CC	 CCONJ	 ConjType=Cmp
# clean	 clean	 clean	 JJ	 ADJ	 Degree=Pos
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# but	 but	 but	 CC	 CCONJ	 ConjType=Cmp
#
#
#
# 	 _SP	 SPACE	 Number=Sing
# grass	 grass	 grass	 NN	 NOUN	 Number=Sing
# was	 be	 was	 VBD	 AUX	 Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# growing	 grow	 growing	 VBG	 VERB	 Aspect=Prog|Tense=Pres|VerbForm=Part
# in	 in	 in	 IN	 ADP
# every	 every	 every	 DT	 DET
# crevice	 crevice	 crevice	 NN	 NOUN	 Number=Sing
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# The	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# brewery	 brewery	 brewery	 NN	 NOUN	 Number=Sing
# buildings	 building	 buildings	 NNS	 NOUN	 Number=Plur
# had	 have	 had	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# a	 a	 a	 DT	 DET	 Definite=Ind|PronType=Art
# little	 little	 little	 JJ	 ADJ	 Degree=Pos
# lane	 lane	 lane	 NN	 NOUN	 Number=Sing
# of	 of	 of	 IN	 ADP
# communication	 communication	 communication	 NN	 NOUN	 Number=Sing
# with	 with	 with	 IN	 ADP
# it	 it	 it	 PRP	 PRON	 Case=Acc|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# and	 and	 and	 CC	 CCONJ	 ConjType=Cmp
#
#
#
# 	 _SP	 SPACE
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# wooden	 wooden	 wooden	 JJ	 ADJ	 Degree=Pos
# gates	 gate	 gates	 NNS	 NOUN	 Number=Plur
# of	 of	 of	 IN	 ADP
# that	 that	 that	 DT	 DET	 Number=Sing|PronType=Dem
# lane	 lane	 lane	 NN	 NOUN	 Number=Sing
# stood	 stand	 stood	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# open	 open	 open	 JJ	 ADJ	 Degree=Pos
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# and	 and	 and	 CC	 CCONJ	 ConjType=Cmp
# all	 all	 all	 PDT	 DET
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# brewery	 brewery	 brewery	 NN	 NOUN	 Number=Sing
# beyond	 beyond	 beyond	 IN	 ADP
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# stood	 stand	 stood	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# open	 open	 open	 JJ	 ADJ	 Degree=Pos
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# away	 away	 away	 RB	 ADV
# to	 to	 to	 IN	 ADP
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# high	 high	 high	 JJ	 ADJ	 Degree=Pos
#
#
#
# 	 _SP	 SPACE	 Number=Sing
# enclosing	 enclosing	 enclosing	 NN	 NOUN	 Number=Sing
# wall	 wall	 wall	 NN	 NOUN	 Number=Sing
# ;	 ;	 ;	 :	 PUNCT
# and	 and	 and	 CC	 CCONJ	 ConjType=Cmp
# all	 all	 all	 DT	 DET
# was	 be	 was	 VBD	 VERB	 Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# empty	 empty	 empty	 JJ	 ADJ	 Degree=Pos
# and	 and	 and	 CC	 CCONJ	 ConjType=Cmp
# disused	 disuse	 disused	 VBN	 VERB	 Aspect=Perf|Tense=Past|VerbForm=Part
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# The	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# cold	 cold	 cold	 JJ	 ADJ	 Degree=Pos
# wind	 wind	 wind	 NN	 NOUN	 Number=Sing
# seemed	 seem	 seemed	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# to	 to	 to	 TO	 PART
# blow	 blow	 blow	 VB	 VERB	 VerbForm=Inf
# colder	 cold	 colder	 JJR	 ADJ	 Degree=Cmp
# there	 there	 there	 RB	 ADV	 PronType=Dem
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# than	 than	 than	 IN	 SCONJ
# outside	 outside	 outside	 RB	 ADV
#
#
#
# 	 _SP	 SPACE
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# gate	 gate	 gate	 NN	 NOUN	 Number=Sing
# ;	 ;	 ;	 :	 PUNCT
# and	 and	 and	 CC	 CCONJ	 ConjType=Cmp
# it	 it	 it	 PRP	 PRON	 Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# made	 make	 made	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# a	 a	 a	 DT	 DET	 Definite=Ind|PronType=Art
# shrill	 shrill	 shrill	 JJ	 ADJ	 Degree=Pos
# noise	 noise	 noise	 NN	 NOUN	 Number=Sing
# in	 in	 in	 IN	 ADP
# howling	 howl	 howling	 VBG	 VERB	 Aspect=Prog|Tense=Pres|VerbForm=Part
# in	 in	 in	 RB	 ADV
# and	 and	 and	 CC	 CCONJ	 ConjType=Cmp
# out	 out	 out	 RB	 ADV
# at	 at	 at	 IN	 ADP
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# open	 open	 open	 JJ	 ADJ	 Degree=Pos
# sides	 side	 sides	 NNS	 NOUN	 Number=Plur
# of	 of	 of	 IN	 ADP
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# brewery	 brewery	 brewery	 NN	 NOUN	 Number=Sing
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# like	 like	 like	 IN	 ADP
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# noise	 noise	 noise	 NN	 NOUN	 Number=Sing
# of	 of	 of	 IN	 ADP
#
#
#
# 	 _SP	 SPACE
# wind	 wind	 wind	 NN	 NOUN	 Number=Sing
# in	 in	 in	 IN	 ADP
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# rigging	 rigging	 rigging	 NN	 NOUN	 Number=Sing
# of	 of	 of	 IN	 ADP
# a	 a	 a	 DT	 DET	 Definite=Ind|PronType=Art
# ship	 ship	 ship	 NN	 NOUN	 Number=Sing
# at	 at	 at	 IN	 ADP
# sea	 sea	 sea	 NN	 NOUN	 Number=Sing
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
#
#
#
# 	 _SP	 SPACE	 PunctSide=Fin|PunctType=Quot
# She	 she	 she	 PRP	 PRON	 Case=Nom|Gender=Fem|Number=Sing|Person=3|PronType=Prs
# saw	 see	 saw	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# me	 I	 me	 PRP	 PRON	 Case=Acc|Number=Sing|Person=1|PronType=Prs
# looking	 look	 looking	 VBG	 VERB	 Aspect=Prog|Tense=Pres|VerbForm=Part
# at	 at	 at	 IN	 ADP
# it	 it	 it	 PRP	 PRON	 Case=Acc|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# and	 and	 and	 CC	 CCONJ	 ConjType=Cmp
# she	 she	 she	 PRP	 PRON	 Case=Nom|Gender=Fem|Number=Sing|Person=3|PronType=Prs
# said	 say	 said	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# You	 you	 you	 PRP	 PRON	 Case=Nom|Person=2|PronType=Prs
# could	 could	 could	 MD	 AUX	 VerbForm=Fin
# drink	 drink	 drink	 VB	 VERB	 VerbForm=Inf
# without	 without	 without	 IN	 ADP
# hurt	 hurt	 hurt	 VB	 VERB	 VerbForm=Inf
# all	 all	 all	 PDT	 DET
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# strong	 strong	 strong	 JJ	 ADJ	 Degree=Pos
# beer	 beer	 beer	 NN	 NOUN	 Number=Sing
# that	 that	 that	 WDT	 DET
# 's	 be	 's	 VBZ	 AUX	 Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# brewed	 brew	 brewed	 VBN	 VERB	 Aspect=Perf|Tense=Past|VerbForm=Part
#
#
#
# 	 _SP	 SPACE	 Number=Sing
# there	 there	 there	 RB	 ADV	 PronType=Dem
# now	 now	 now	 RB	 ADV
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# boy	 boy	 boy	 UH	 INTJ
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
#
#
#
# 	 _SP	 SPACE
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# I	 I	 i	 PRP	 PRON	 Case=Nom|Number=Sing|Person=1|PronType=Prs
# should	 should	 should	 MD	 AUX	 VerbForm=Fin
# think	 think	 think	 VB	 VERB	 VerbForm=Inf
# I	 I	 i	 PRP	 PRON	 Case=Nom|Number=Sing|Person=1|PronType=Prs
# could	 could	 could	 MD	 AUX	 VerbForm=Fin
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# miss	 miss	 miss	 VB	 VERB	 VerbForm=Inf
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
# said	 say	 said	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# I	 I	 i	 PRP	 PRON	 Case=Nom|Number=Sing|Person=1|PronType=Prs
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# in	 in	 in	 IN	 ADP
# a	 a	 a	 DT	 DET	 Definite=Ind|PronType=Art
# shy	 shy	 shy	 JJ	 ADJ	 Degree=Pos
# way	 way	 way	 NN	 NOUN	 Number=Sing
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
#
#
#
# 	 _SP	 SPACE	 PunctSide=Fin|PunctType=Quot
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# Better	 well	 better	 RBR	 ADV	 Degree=Cmp
# not	 not	 not	 RB	 PART
# try	 try	 try	 VB	 VERB	 VerbForm=Inf
# to	 to	 to	 TO	 PART
# brew	 brew	 brew	 VB	 VERB	 VerbForm=Inf
# beer	 beer	 beer	 NN	 NOUN	 Number=Sing
# there	 there	 there	 RB	 ADV	 PronType=Dem
# now	 now	 now	 RB	 ADV
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# or	 or	 or	 CC	 CCONJ	 ConjType=Cmp
# it	 it	 it	 PRP	 PRON	 Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# would	 would	 would	 MD	 AUX	 VerbForm=Fin
# turn	 turn	 turn	 VB	 VERB	 VerbForm=Inf
# out	 out	 out	 RP	 ADP
# sour	 sour	 sour	 JJ	 ADJ	 Degree=Pos
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# boy	 boy	 boy	 UH	 INTJ
# ;	 ;	 ;	 :	 PUNCT
# do	 do	 do	 VBP	 AUX	 Mood=Ind|Tense=Pres|VerbForm=Fin
# n't	 n't	 not	 RB	 PART
# you	 you	 you	 PRP	 PRON	 Case=Nom|Person=2|PronType=Prs
# think	 think	 think	 VB	 VERB	 VerbForm=Inf
# so	 so	 so	 RB	 ADV
# ?	 ?	 ?	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
#
#
#
# 	 _SP	 SPACE	 PunctSide=Fin|PunctType=Quot
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# It	 it	 it	 PRP	 PRON	 Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# looks	 look	 looks	 VBZ	 VERB	 Number=Sing|Person=Three|Tense=Pres|VerbForm=Fin
# like	 like	 like	 IN	 ADP
# it	 it	 it	 PRP	 PRON	 Case=Acc|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# miss	 miss	 miss	 VBP	 VERB	 Tense=Pres|VerbForm=Fin
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
#
#
#
# 	 _SP	 SPACE	 PunctSide=Fin|PunctType=Quot
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# Not	 not	 not	 RB	 PART
# that	 that	 that	 IN	 SCONJ
# anybody	 anybody	 anybody	 NN	 PRON	 Number=Sing
# means	 mean	 means	 VBZ	 VERB	 Number=Sing|Person=Three|Tense=Pres|VerbForm=Fin
# to	 to	 to	 TO	 PART
# try	 try	 try	 VB	 VERB	 VerbForm=Inf
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
# she	 she	 she	 PRP	 PRON	 Case=Nom|Gender=Fem|Number=Sing|Person=3|PronType=Prs
# added	 add	 added	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# for	 for	 for	 IN	 ADP
# that	 that	 that	 DT	 DET	 Number=Sing|PronType=Dem
# 's	 be	 's	 VBZ	 AUX	 Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# all	 all	 all	 DT	 DET
# done	 do	 done	 VBN	 VERB	 Aspect=Perf|Tense=Past|VerbForm=Part
# with	 with	 with	 IN	 ADP
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# and	 and	 and	 CC	 CCONJ	 ConjType=Cmp
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# place	 place	 place	 NN	 NOUN	 Number=Sing
# will	 will	 will	 MD	 AUX	 VerbForm=Fin
# stand	 stand	 stand	 VB	 VERB	 VerbForm=Inf
# as	 as	 as	 RB	 ADV
# idle	 idle	 idle	 JJ	 ADJ	 Degree=Pos
# as	 as	 as	 IN	 ADP
# it	 it	 it	 PRP	 PRON	 Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
#
#
# 	 _SP	 SPACE	 Tense=Pres|VerbForm=Fin
# is	 be	 is	 VBZ	 VERB	 Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# till	 till	 till	 IN	 SCONJ
# it	 it	 it	 PRP	 PRON	 Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# falls	 fall	 falls	 VBZ	 VERB	 Number=Sing|Person=Three|Tense=Pres|VerbForm=Fin
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# As	 as	 as	 IN	 ADP
# to	 to	 to	 IN	 ADP
# strong	 strong	 strong	 JJ	 ADJ	 Degree=Pos
# beer	 beer	 beer	 NN	 NOUN	 Number=Sing
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# there	 there	 there	 EX	 PRON	 AdvType=Ex
# 's	 be	 's	 VBZ	 AUX	 Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# enough	 enough	 enough	 JJ	 ADJ	 Degree=Pos
# of	 of	 of	 IN	 ADP
# it	 it	 it	 PRP	 PRON	 Case=Acc|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# in	 in	 in	 IN	 ADP
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# cellars	 cellar	 cellars	 NNS	 NOUN	 Number=Plur
# already	 already	 already	 RB	 ADV
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# to	 to	 to	 TO	 PART
# drown	 drown	 drown	 VB	 VERB	 VerbForm=Inf
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# Manor	 Manor	 manor	 NNP	 PROPN	 NounType=Prop|Number=Sing
# House	 House	 house	 NNP	 PROPN	 NounType=Prop|Number=Sing
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
#
#
#
# 	 _SP	 SPACE	 Number=Sing
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# Is	 be	 is	 VBZ	 AUX	 Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# that	 that	 that	 DT	 DET	 Number=Sing|PronType=Dem
# the	 the	 the	 DT	 DET	 Definite=Def|PronType=Art
# name	 name	 name	 NN	 NOUN	 Number=Sing
# of	 of	 of	 IN	 ADP
# this	 this	 this	 DT	 DET	 Number=Sing|PronType=Dem
# house	 house	 house	 NN	 NOUN	 Number=Sing
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# miss	 miss	 miss	 VB	 VERB	 VerbForm=Inf
# ?	 ?	 ?	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
#
#
#
# 	 _SP	 SPACE	 PunctSide=Fin|PunctType=Quot
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# One	 one	 one	 CD	 NUM	 NumType=Card
# of	 of	 of	 IN	 ADP
# its	 its	 its	 PRP$	 PRON	 Gender=Neut|Number=Sing|Person=3|Poss=Yes|PronType=Prs
# names	 name	 names	 NNS	 NOUN	 Number=Plur
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# boy	 boy	 boy	 UH	 INTJ
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
#
#
#
# 	 _SP	 SPACE	 PunctSide=Fin|PunctType=Quot
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# It	 it	 it	 PRP	 PRON	 Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# has	 have	 has	 VBZ	 VERB	 Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# more	 more	 more	 JJR	 ADJ	 Degree=Cmp
# than	 than	 than	 IN	 SCONJ
# one	 one	 one	 CD	 NUM	 NumType=Card
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# then	 then	 then	 RB	 ADV	 PronType=Dem
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# miss	 miss	 miss	 VB	 VERB	 VerbForm=Inf
# ?	 ?	 ?	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
#
#
#
# 	 _SP	 SPACE	 PunctSide=Fin|PunctType=Quot
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# One	 one	 one	 CD	 NUM	 NumType=Card
# more	 more	 more	 JJR	 ADJ	 Degree=Cmp
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# Its	 its	 its	 PRP$	 PRON	 Gender=Neut|Number=Sing|Person=3|Poss=Yes|PronType=Prs
# other	 other	 other	 JJ	 ADJ	 Degree=Pos
# name	 name	 name	 NN	 NOUN	 Number=Sing
# was	 be	 was	 VBD	 AUX	 Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# Satis	 Satis	 satis	 NNP	 PROPN	 NounType=Prop|Number=Sing
# ;	 ;	 ;	 :	 PUNCT
# which	 which	 which	 WDT	 DET
# is	 be	 is	 VBZ	 VERB	 Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Greek	 greek	 greek	 JJ	 ADJ	 Degree=Pos
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# or	 or	 or	 CC	 CCONJ	 ConjType=Cmp
# Latin	 Latin	 latin	 NNP	 PROPN	 NounType=Prop|Number=Sing
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# or	 or	 or	 CC	 CCONJ	 ConjType=Cmp
# Hebrew	 Hebrew	 hebrew	 NNP	 PROPN	 NounType=Prop|Number=Sing
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# or	 or	 or	 CC	 CCONJ	 ConjType=Cmp
# all	 all	 all	 DT	 DET
# three	 three	 three	 CD	 NUM	 NumType=Card
# -	 -	 -	 HYPH	 PUNCT	 PunctType=Dash
# or	 or	 or	 CC	 CCONJ	 ConjType=Cmp
# all	 all	 all	 DT	 DET
# one	 one	 one	 CD	 NUM	 NumType=Card
# to	 to	 to	 IN	 ADP
# me	 I	 me	 PRP	 PRON	 Case=Acc|Number=Sing|Person=1|PronType=Prs
# -	 -	 -	 :	 PUNCT
#
#
#
# 	 _SP	 SPACE	 NounType=Prop|Number=Sing
# for	 for	 for	 IN	 ADP
# enough	 enough	 enough	 JJ	 ADJ	 Degree=Pos
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
#
#
#
# 	 _SP	 SPACE	 PunctSide=Fin|PunctType=Quot
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# Enough	 Enough	 enough	 NNP	 PROPN	 NounType=Prop|Number=Sing
# House	 House	 house	 NNP	 PROPN	 NounType=Prop|Number=Sing
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
# said	 say	 said	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# I	 I	 i	 PRP	 PRON	 Case=Nom|Number=Sing|Person=1|PronType=Prs
# ;	 ;	 ;	 :	 PUNCT
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# that	 that	 that	 DT	 DET	 Number=Sing|PronType=Dem
# 's	 be	 's	 VBZ	 AUX	 Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# a	 a	 a	 DT	 DET	 Definite=Ind|PronType=Art
# curious	 curious	 curious	 JJ	 ADJ	 Degree=Pos
# name	 name	 name	 NN	 NOUN	 Number=Sing
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# miss	 miss	 miss	 VBP	 VERB	 Tense=Pres|VerbForm=Fin
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
#
#
#
# 	 _SP	 SPACE	 PunctSide=Fin|PunctType=Quot
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# Yes	 yes	 yes	 UH	 INTJ
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
# she	 she	 she	 PRP	 PRON	 Case=Nom|Gender=Fem|Number=Sing|Person=3|PronType=Prs
# replied	 reply	 replied	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# ;	 ;	 ;	 :	 PUNCT
# "	 "	 "	 ``	 PUNCT	 PunctSide=Ini|PunctType=Quot
# but	 but	 but	 CC	 CCONJ	 ConjType=Cmp
# it	 it	 it	 PRP	 PRON	 Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# meant	 mean	 meant	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# more	 more	 more	 JJR	 ADJ	 Degree=Cmp
# than	 than	 than	 IN	 SCONJ
# it	 it	 it	 PRP	 PRON	 Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# said	 say	 said	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# It	 it	 it	 PRP	 PRON	 Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# meant	 mean	 meant	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# when	 when	 when	 WRB	 ADV
# it	 it	 it	 PRP	 PRON	 Gender=Neut|Number=Sing|Person=3|PronType=Prs
# was	 be	 was	 VBD	 AUX	 Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# given	 give	 given	 VBN	 VERB	 Aspect=Perf|Tense=Past|VerbForm=Part
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# that	 that	 that	 IN	 SCONJ
# whoever	 whoever	 whoever	 WP	 PRON
# had	 have	 had	 VBD	 VERB	 Tense=Past|VerbForm=Fin
# this	 this	 this	 DT	 DET	 Number=Sing|PronType=Dem
#
#
#
# 	 _SP	 SPACE	 Number=Sing
# house	 house	 house	 NN	 NOUN	 Number=Sing
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# could	 could	 could	 MD	 AUX	 VerbForm=Fin
# want	 want	 want	 VB	 VERB	 VerbForm=Inf
# nothing	 nothing	 nothing	 NN	 PRON	 Number=Sing
# else	 else	 else	 RB	 ADV
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# They	 they	 they	 PRP	 PRON	 Case=Nom|Number=Plur|Person=3|PronType=Prs
# must	 must	 must	 MD	 AUX	 VerbForm=Fin
# have	 have	 have	 VB	 AUX	 VerbForm=Inf
# been	 be	 been	 VBN	 VERB	 Tense=Past|VerbForm=Part
# easily	 easily	 easily	 RB	 ADV
# satisfied	 satisfied	 satisfied	 JJ	 ADJ	 Degree=Pos
# in	 in	 in	 IN	 ADP
# those	 those	 those	 DT	 DET	 Number=Plur|PronType=Dem
# days	 day	 days	 NNS	 NOUN	 Number=Plur
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# I	 I	 i	 PRP	 PRON	 Case=Nom|Number=Sing|Person=1|PronType=Prs
# should	 should	 should	 MD	 AUX	 VerbForm=Fin
# think	 think	 think	 VB	 VERB	 VerbForm=Inf
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# But	 but	 but	 CC	 CCONJ	 ConjType=Cmp
#
#
#
# 	 _SP	 SPACE
# do	 do	 do	 VBP	 AUX	 Mood=Ind|Tense=Pres|VerbForm=Fin
# n't	 n't	 not	 RB	 PART
# loiter	 loiter	 loiter	 VB	 VERB	 VerbForm=Inf
# ,	 ,	 ,	 ,	 PUNCT	 PunctType=Comm
# boy	 boy	 boy	 UH	 INTJ
# .	 .	 .	 .	 PUNCT	 PunctType=Peri
# "	 "	 "	 ''	 PUNCT	 PunctSide=Fin|PunctType=Quot
#
#
#
# 	 _SP	 SPACE

# %% [markdown]
# #### Etape 1. Le Tokenizer Spacy
#
# Il est possible de personnaliser le Tokenizer de Spacy en modifiant quelques paramètres :
#
# La démarche est assez complexe mais peut être intéressante selon ce qu'on souhaite traiter.
#
# Le code qui suit est issu de : https://stackoverflow.com/questions/51012476/spacy-custom-tokenizer-to-include-only-hyphen-words-as-tokens-using-infix-regex
#
# Dans cet exemple, on a redéfinit la manière dont on tokénize de manière à obtenir it's en deux tokens "it" et "'s", et d'obtenir un seul token pour le mot composé "male-dominated"

# %%
text = "Note: Since the fourteenth century the practice of “medicine” has become a profession; and more importantly, it\'s a male-dominated profession.'"

textEx = nlp(text)

print ([token.text for token in textEx])
# Out:
# ['Note', ':', 'Since', 'the', 'fourteenth', 'century', 'the', 'practice', 'of', '“', 'medicine', '”', 'has', 'become', 'a', 'profession', ';', 'and', 'more', 'importantly', ',', 'it', "'s", 'a', 'male', '-', 'dominated', 'profession', '.', "'"]

# %%
import re
import spacy
from spacy.tokenizer import Tokenizer
from spacy.util import compile_prefix_regex, compile_infix_regex, compile_suffix_regex

def custom_tokenizer(nlp):
    infix_re = re.compile(r'''[.\,\?\:\;\...\‘\’\`\“\”\"\'~]''')
    prefix_re = compile_prefix_regex(nlp.Defaults.prefixes)
    suffix_re = compile_suffix_regex(nlp.Defaults.suffixes)

    return Tokenizer(nlp.vocab, prefix_search=prefix_re.search,
                                suffix_search=suffix_re.search,
                                infix_finditer=infix_re.finditer,
                                token_match=None)

nlp2 = spacy.load('en_core_web_sm')
nlp2.tokenizer = custom_tokenizer(nlp)

doc = nlp2(u'Note: Since the fourteenth century the practice of “medicine” has become a profession; and more importantly, it\'s a male-dominated profession.')
[token.text for token in doc]
# Out:
# ['Note',
#  ':',
#  'Since',
#  'the',
#  'fourteenth',
#  'century',
#  'the',
#  'practice',
#  'of',
#  '“',
#  'medicine',
#  '”',
#  'has',
#  'become',
#  'a',
#  'profession',
#  ';',
#  'and',
#  'more',
#  'importantly',
#  ',',
#  'it',
#  "'s",
#  'a',
#  'male-dominated',
#  'profession',
#  '.']

# %% [markdown]
# #### Etape 2 : Détection de phrases
#
# On a choisit de découper un extrait.
# De cette simple découpe, on peut constater plusieurs choses qui pourraient être améliorés en modifiant la pipeline.
#
# 1. Voulons-nous considérer les citations comme phrases indépendantes ?
# 2. Il serait intéressant de nettoyer les phrases vides. Cependant ceci vient peut-être de notre structure de données de base.

# %%
phrases_dickens = list(dickens_doc.sents)
print("Il y a {} phrases découpées selon Spacy dans mon extrait".format(len(phrases_dickens)))
print("--"*5)

for phrase in phrases_dickens[:10]:
    print(phrase)
    print("--"*5)
# Out:
# Il y a 41 phrases découpées selon Spacy dans mon extrait
# ----------
# A window was raised, and a clear voice demanded "What name?"
# ----------
# To which my conductor replied,
# "Pumblechook."
# ----------
# The voice returned, "Quite right," and the window was shut again, and a young lady
# came across the court-yard, with keys in her hand.
# ----------
#
#
# ----------
# "This," said Mr. Pumblechook, "is Pip."
# ----------
#
# "This is Pip, is it?" returned the young lady, who was very pretty and seemed very proud; "come in, Pip."
# ----------
#
# Mr. Pumblechook was coming in also, when she stopped him with the gate.
# ----------
#
#
# ----------
# "Oh!" she said.
# ----------
# "Did you wish to see Miss Havisham?"
# ----------

# %%
from nltk.tokenize import sent_tokenize

phrases_dickens_nltk = sent_tokenize(dickens_text)

print("Il y a {} phrases découpées selon Spacy dans mon extrait".format(len(phrases_dickens_nltk)))
print("--"*5)

for phrase in phrases_dickens_nltk[:10]:
    print(phrase)
    print("--"*5)
# Out:
# Il y a 39 phrases découpées selon Spacy dans mon extrait
# ----------
# A window was raised, and a clear voice demanded "What name?"
# ----------
# To which my conductor replied,
# "Pumblechook."
# ----------
# The voice returned, "Quite right," and the window was shut again, and a young lady
# came across the court-yard, with keys in her hand.
# ----------
# "This," said Mr. Pumblechook, "is Pip."
# ----------
# "This is Pip, is it?"
# ----------
# returned the young lady, who was very pretty and seemed very proud; "come in, Pip."
# ----------
# Mr. Pumblechook was coming in also, when she stopped him with the gate.
# ----------
# "Oh!"
# ----------
# she said.
# ----------
# "Did you wish to see Miss Havisham?"
# ----------

# %% [markdown]
# Malgré l'apparition de quelques phrases vides, le tokenizer de phrases de spaCy semble être offrir une tokenization intéressante.
#
# On le voit particulièrement pour la phrase :
# `"This is Pip, is it?" returned the young lady, who was very pretty and seemed very proud; "come in, Pip."` tokenizée en une seule phrase par spaCy mais en deux par nltk.
#
# Un post traitement pour supprimer les phrases vides pourrait être intéressant

# %% [markdown]
# #### Etape 3 - Stopwords
#
# spaCy propose des listes de stopwords dans différentes langues.
# Il peut être intéressant d'observer ces listes et, si besoin, de les retirer de nos textes en pré-traitement.
#
# Attention, ce n'est pas toujours pertinent de retirer les stopwords.

# %%
from spacy.lang.fr.stop_words import STOP_WORDS as fr_stop
from spacy.lang.en.stop_words import STOP_WORDS as en_stop

spacy_stopwords_en = list(en_stop)
spacy_stopwords_fr = list(fr_stop)

print(len(spacy_stopwords_en))
print(len(spacy_stopwords_fr))

print(spacy_stopwords_en[:40])
print("------")
print(spacy_stopwords_fr[:40])
# Out:
# 326
# 487
# ['anywhere', 'whither', 'those', 'about', 'however', 'via', 'whatever', 'were', 'mine', 'enough', 'although', 'hers', 'she', 'a', 'twenty', 'will', 'upon', 'to', 'off', 'unless', 'their', 'two', 'under', 'perhaps', 'them', 'not', 'eight', 'whose', 'next', 'most', 'elsewhere', 'must', 'again', 'by', 'other', "'ve", 'everyone', 'four', 'side', 'former']
# ------
# ['différents', 'via', 'nombreuses', 'leur', 'néanmoins', 'certains', 'apres', 'près', 'toujours', 't’', "quelqu'un", 'parfois', 'treize', 'celles-là', 'dix-sept', 'a', 'retour', 'ayant', 'directement', 'parlent', 'dans', 'entre', 'nouvea', 'dès', 'merci', 'importe', 'ceux', 'lors', 'quand', 'cinquante', 'voici', 'hé', 'aussi', 'suivants', 'aie', 'comme', 'hi', 'donc', 'eux', 'quatre-vingt']

# %% [markdown]
# Exemple simple

# %%
nlp = spacy.load('en_core_web_sm')

exemple_en = nlp("My name is Morgann and I like chocolate. I am a french student")

exemple_en_tok = [token.text for token in exemple_en]

exemple_en_nostop = [word for word in exemple_en_tok if not word in spacy_stopwords_en]

print(list(exemple_en))
print(exemple_en_nostop)
# Out:
# [My, name, is, Morgann, and, I, like, chocolate, ., I, am, a, french, student]
# ['My', 'Morgann', 'I', 'like', 'chocolate', '.', 'I', 'french', 'student']

# %%
dickens_tok = [token.text for token in dickens_doc]

dickens_nostop = [word for word in dickens_tok if not word in spacy_stopwords_en]

print(dickens_tok[:50])
print(dickens_nostop[:50])
# Out:
# ['A', 'window', 'was', 'raised', ',', 'and', 'a', 'clear', 'voice', 'demanded', '"', 'What', 'name', '?', '"', 'To', 'which', 'my', 'conductor', 'replied', ',', '\n', '"', 'Pumblechook', '.', '"', 'The', 'voice', 'returned', ',', '"', 'Quite', 'right', ',', '"', 'and', 'the', 'window', 'was', 'shut', 'again', ',', 'and', 'a', 'young', 'lady', '\n', 'came', 'across', 'the']
# ['A', 'window', 'raised', ',', 'clear', 'voice', 'demanded', '"', 'What', '?', '"', 'To', 'conductor', 'replied', ',', '\n', '"', 'Pumblechook', '.', '"', 'The', 'voice', 'returned', ',', '"', 'Quite', 'right', ',', '"', 'window', 'shut', ',', 'young', 'lady', '\n', 'came', 'court', '-', 'yard', ',', 'keys', 'hand', '.', '\n', '"', 'This', ',', '"', 'said', 'Mr.']

# %% [markdown]
# Et les stopwords de NLTK ?

# %%
import nltk
from nltk.corpus import stopwords

nltk_stopwords_en = list(stopwords.words("english"))
nltk_stopwords_fr = list(stopwords.words("french"))

print(len(nltk_stopwords_en))
print(len(nltk_stopwords_fr))

print(list(nltk_stopwords_en[:40]))
print("------")
print(list(nltk_stopwords_fr[:40]))
# Out:
# 179
# 157
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this']
# ['au', 'aux', 'avec', 'ce', 'ces', 'dans', 'de', 'des', 'du', 'elle', 'en', 'et', 'eux', 'il', 'ils', 'je', 'la', 'le', 'les', 'leur', 'lui', 'ma', 'mais', 'me', 'même', 'mes', 'moi', 'mon', 'ne', 'nos', 'notre', 'nous', 'on', 'ou', 'par', 'pas', 'pour', 'qu', 'que', 'qui']

# %%
exemple_en = "My name is Morgann and I like chocolate. I am a french student"

exemple_en_tok = nltk.word_tokenize(exemple_en)

exemple_en_nostop = [word for word in exemple_en_tok if not word in nltk_stopwords_en]

print(exemple_en)
print(exemple_en_nostop)
# Out:
# My name is Morgann and I like chocolate. I am a french student
# ['My', 'name', 'Morgann', 'I', 'like', 'chocolate', '.', 'I', 'french', 'student']

# %% [markdown]
# On observe que la liste de stopwords de spacy est bien plus fournie. Cependant, on peut débattre de son contenu. Les stopwords de spaCy semblent simplement être sélectionnés parmi les mots ayant le plus d'occurences dans les corpus sélectionnés pour entrainer les modèles de spaCy.
#
# NLTK propose une liste bien moins fournie mais qui semble bien plus pertinente.

# %% [markdown]
# #### Etape 4 : La lemmatisation
#
# Dans cette étape, nous allons nous intéresser aux outils de lemmatisation et de stemming à partir de notre extrait.
#
# _Note : contrairement à NLTK, spaCy ne possède pas de stemmer_

# %%
print("Token \t\t Lemme")
for token in dickens_doc:
    print(token, "\t\t",token.lemma_)
# Out:
# Token 		 Lemme
# A 		 a
# window 		 window
# was 		 be
# raised 		 raise
# , 		 ,
# and 		 and
# a 		 a
# clear 		 clear
# voice 		 voice
# demanded 		 demand
# " 		 "
# What 		 what
# name 		 name
# ? 		 ?
# " 		 "
# To 		 to
# which 		 which
# my 		 my
# conductor 		 conductor
# replied 		 reply
# , 		 ,
#
#
#
# " 		 "
# Pumblechook 		 Pumblechook
# . 		 .
# " 		 "
# The 		 the
# voice 		 voice
# returned 		 return
# , 		 ,
# " 		 "
# Quite 		 quite
# right 		 right
# , 		 ,
# " 		 "
# and 		 and
# the 		 the
# window 		 window
# was 		 be
# shut 		 shut
# again 		 again
# , 		 ,
# and 		 and
# a 		 a
# young 		 young
# lady 		 lady
#
#
#
# came 		 come
# across 		 across
# the 		 the
# court 		 court
# - 		 -
# yard 		 yard
# , 		 ,
# with 		 with
# keys 		 key
# in 		 in
# her 		 her
# hand 		 hand
# . 		 .
#
#
#
# " 		 "
# This 		 this
# , 		 ,
# " 		 "
# said 		 say
# Mr. 		 Mr.
# Pumblechook 		 Pumblechook
# , 		 ,
# " 		 "
# is 		 be
# Pip 		 Pip
# . 		 .
# " 		 "
#
#
#
# " 		 "
# This 		 this
# is 		 be
# Pip 		 Pip
# , 		 ,
# is 		 be
# it 		 it
# ? 		 ?
# " 		 "
# returned 		 return
# the 		 the
# young 		 young
# lady 		 lady
# , 		 ,
# who 		 who
# was 		 be
# very 		 very
# pretty 		 pretty
# and 		 and
# seemed 		 seem
# very 		 very
# proud 		 proud
# ; 		 ;
# " 		 "
# come 		 come
# in 		 in
# , 		 ,
# Pip 		 Pip
# . 		 .
# " 		 "
#
#
#
# Mr. 		 Mr.
# Pumblechook 		 Pumblechook
# was 		 be
# coming 		 come
# in 		 in
# also 		 also
# , 		 ,
# when 		 when
# she 		 she
# stopped 		 stop
# him 		 he
# with 		 with
# the 		 the
# gate 		 gate
# . 		 .
#
#
#
# " 		 "
# Oh 		 oh
# ! 		 !
# " 		 "
# she 		 she
# said 		 say
# . 		 .
# " 		 "
# Did 		 do
# you 		 you
# wish 		 wish
# to 		 to
# see 		 see
# Miss 		 Miss
# Havisham 		 Havisham
# ? 		 ?
# " 		 "
#
#
#
# " 		 "
# If 		 if
# Miss 		 Miss
# Havisham 		 Havisham
# wished 		 wish
# to 		 to
# see 		 see
# me 		 I
# , 		 ,
# " 		 "
# returned 		 return
# Mr. 		 Mr.
# Pumblechook 		 Pumblechook
# , 		 ,
# discomfited 		 discomfited
# . 		 .
#
#
#
# " 		 "
# Ah 		 ah
# ! 		 !
# " 		 "
# said 		 say
# the 		 the
# girl 		 girl
# ; 		 ;
# " 		 "
# but 		 but
# you 		 you
# see 		 see
# she 		 she
# do 		 do
# n't 		 n't
# . 		 .
# " 		 "
#
#
#
# She 		 she
# said 		 say
# it 		 it
# so 		 so
# finally 		 finally
# , 		 ,
# and 		 and
# in 		 in
# such 		 such
# an 		 an
# undiscussible 		 undiscussible
# way 		 way
# , 		 ,
# that 		 that
# Mr. 		 Mr.
# Pumblechook 		 Pumblechook
# , 		 ,
# though 		 though
# in 		 in
# a 		 a
# condition 		 condition
# of 		 of
#
#
#
# ruffled 		 ruffle
# dignity 		 dignity
# , 		 ,
# could 		 could
# not 		 not
# protest 		 protest
# . 		 .
# But 		 but
# he 		 he
# eyed 		 eye
# me 		 I
# severely 		 severely
# - 		 -
# as 		 as
# if 		 if
# I 		 I
# had 		 have
# done 		 do
# anything 		 anything
# to 		 to
# him 		 he
# ! 		 !
# - 		 -
# and 		 and
#
#
#
# departed 		 depart
# with 		 with
# the 		 the
# words 		 word
# reproachfully 		 reproachfully
# delivered 		 deliver
# : 		 :
# " 		 "
# Boy 		 boy
# ! 		 !
# Let 		 let
# your 		 your
# behaviour 		 behaviour
# here 		 here
# be 		 be
# a 		 a
# credit 		 credit
# unto 		 unto
# them 		 they
#
#
#
# which 		 which
# brought 		 bring
# you 		 you
# up 		 up
# by 		 by
# hand 		 hand
# ! 		 !
# " 		 "
# I 		 I
# was 		 be
# not 		 not
# free 		 free
# from 		 from
# apprehension 		 apprehension
# that 		 that
# he 		 he
# would 		 would
# come 		 come
# back 		 back
# to 		 to
# propound 		 propound
#
#
#
# through 		 through
# the 		 the
# gate 		 gate
# , 		 ,
# " 		 "
# And 		 and
# sixteen 		 sixteen
# ? 		 ?
# " 		 "
# But 		 but
# he 		 he
# did 		 do
# n't 		 n't
# . 		 .
#
#
#
# My 		 my
# young 		 young
# conductress 		 conductress
# locked 		 lock
# the 		 the
# gate 		 gate
# , 		 ,
# and 		 and
# we 		 we
# went 		 go
# across 		 across
# the 		 the
# court 		 court
# - 		 -
# yard 		 yard
# . 		 .
# It 		 it
# was 		 be
# paved 		 paved
# and 		 and
# clean 		 clean
# , 		 ,
# but 		 but
#
#
#
# grass 		 grass
# was 		 be
# growing 		 grow
# in 		 in
# every 		 every
# crevice 		 crevice
# . 		 .
# The 		 the
# brewery 		 brewery
# buildings 		 building
# had 		 have
# a 		 a
# little 		 little
# lane 		 lane
# of 		 of
# communication 		 communication
# with 		 with
# it 		 it
# , 		 ,
# and 		 and
#
#
#
# the 		 the
# wooden 		 wooden
# gates 		 gate
# of 		 of
# that 		 that
# lane 		 lane
# stood 		 stand
# open 		 open
# , 		 ,
# and 		 and
# all 		 all
# the 		 the
# brewery 		 brewery
# beyond 		 beyond
# , 		 ,
# stood 		 stand
# open 		 open
# , 		 ,
# away 		 away
# to 		 to
# the 		 the
# high 		 high
#
#
#
# enclosing 		 enclosing
# wall 		 wall
# ; 		 ;
# and 		 and
# all 		 all
# was 		 be
# empty 		 empty
# and 		 and
# disused 		 disuse
# . 		 .
# The 		 the
# cold 		 cold
# wind 		 wind
# seemed 		 seem
# to 		 to
# blow 		 blow
# colder 		 cold
# there 		 there
# , 		 ,
# than 		 than
# outside 		 outside
#
#
#
# the 		 the
# gate 		 gate
# ; 		 ;
# and 		 and
# it 		 it
# made 		 make
# a 		 a
# shrill 		 shrill
# noise 		 noise
# in 		 in
# howling 		 howl
# in 		 in
# and 		 and
# out 		 out
# at 		 at
# the 		 the
# open 		 open
# sides 		 side
# of 		 of
# the 		 the
# brewery 		 brewery
# , 		 ,
# like 		 like
# the 		 the
# noise 		 noise
# of 		 of
#
#
#
# wind 		 wind
# in 		 in
# the 		 the
# rigging 		 rigging
# of 		 of
# a 		 a
# ship 		 ship
# at 		 at
# sea 		 sea
# . 		 .
#
#
#
# She 		 she
# saw 		 see
# me 		 I
# looking 		 look
# at 		 at
# it 		 it
# , 		 ,
# and 		 and
# she 		 she
# said 		 say
# , 		 ,
# " 		 "
# You 		 you
# could 		 could
# drink 		 drink
# without 		 without
# hurt 		 hurt
# all 		 all
# the 		 the
# strong 		 strong
# beer 		 beer
# that 		 that
# 's 		 be
# brewed 		 brew
#
#
#
# there 		 there
# now 		 now
# , 		 ,
# boy 		 boy
# . 		 .
# " 		 "
#
#
#
# " 		 "
# I 		 I
# should 		 should
# think 		 think
# I 		 I
# could 		 could
# , 		 ,
# miss 		 miss
# , 		 ,
# " 		 "
# said 		 say
# I 		 I
# , 		 ,
# in 		 in
# a 		 a
# shy 		 shy
# way 		 way
# . 		 .
#
#
#
# " 		 "
# Better 		 well
# not 		 not
# try 		 try
# to 		 to
# brew 		 brew
# beer 		 beer
# there 		 there
# now 		 now
# , 		 ,
# or 		 or
# it 		 it
# would 		 would
# turn 		 turn
# out 		 out
# sour 		 sour
# , 		 ,
# boy 		 boy
# ; 		 ;
# do 		 do
# n't 		 n't
# you 		 you
# think 		 think
# so 		 so
# ? 		 ?
# " 		 "
#
#
#
# " 		 "
# It 		 it
# looks 		 look
# like 		 like
# it 		 it
# , 		 ,
# miss 		 miss
# . 		 .
# " 		 "
#
#
#
# " 		 "
# Not 		 not
# that 		 that
# anybody 		 anybody
# means 		 mean
# to 		 to
# try 		 try
# , 		 ,
# " 		 "
# she 		 she
# added 		 add
# , 		 ,
# " 		 "
# for 		 for
# that 		 that
# 's 		 be
# all 		 all
# done 		 do
# with 		 with
# , 		 ,
# and 		 and
# the 		 the
# place 		 place
# will 		 will
# stand 		 stand
# as 		 as
# idle 		 idle
# as 		 as
# it 		 it
#
#
#
# is 		 be
# , 		 ,
# till 		 till
# it 		 it
# falls 		 fall
# . 		 .
# As 		 as
# to 		 to
# strong 		 strong
# beer 		 beer
# , 		 ,
# there 		 there
# 's 		 be
# enough 		 enough
# of 		 of
# it 		 it
# in 		 in
# the 		 the
# cellars 		 cellar
# already 		 already
# , 		 ,
# to 		 to
# drown 		 drown
# the 		 the
# Manor 		 Manor
# House 		 House
# . 		 .
# " 		 "
#
#
#
# " 		 "
# Is 		 be
# that 		 that
# the 		 the
# name 		 name
# of 		 of
# this 		 this
# house 		 house
# , 		 ,
# miss 		 miss
# ? 		 ?
# " 		 "
#
#
#
# " 		 "
# One 		 one
# of 		 of
# its 		 its
# names 		 name
# , 		 ,
# boy 		 boy
# . 		 .
# " 		 "
#
#
#
# " 		 "
# It 		 it
# has 		 have
# more 		 more
# than 		 than
# one 		 one
# , 		 ,
# then 		 then
# , 		 ,
# miss 		 miss
# ? 		 ?
# " 		 "
#
#
#
# " 		 "
# One 		 one
# more 		 more
# . 		 .
# Its 		 its
# other 		 other
# name 		 name
# was 		 be
# Satis 		 Satis
# ; 		 ;
# which 		 which
# is 		 be
# Greek 		 greek
# , 		 ,
# or 		 or
# Latin 		 Latin
# , 		 ,
# or 		 or
# Hebrew 		 Hebrew
# , 		 ,
# or 		 or
# all 		 all
# three 		 three
# - 		 -
# or 		 or
# all 		 all
# one 		 one
# to 		 to
# me 		 I
# - 		 -
#
#
#
# for 		 for
# enough 		 enough
# . 		 .
# " 		 "
#
#
#
# " 		 "
# Enough 		 Enough
# House 		 House
# , 		 ,
# " 		 "
# said 		 say
# I 		 I
# ; 		 ;
# " 		 "
# that 		 that
# 's 		 be
# a 		 a
# curious 		 curious
# name 		 name
# , 		 ,
# miss 		 miss
# . 		 .
# " 		 "
#
#
#
# " 		 "
# Yes 		 yes
# , 		 ,
# " 		 "
# she 		 she
# replied 		 reply
# ; 		 ;
# " 		 "
# but 		 but
# it 		 it
# meant 		 mean
# more 		 more
# than 		 than
# it 		 it
# said 		 say
# . 		 .
# It 		 it
# meant 		 mean
# , 		 ,
# when 		 when
# it 		 it
# was 		 be
# given 		 give
# , 		 ,
# that 		 that
# whoever 		 whoever
# had 		 have
# this 		 this
#
#
#
# house 		 house
# , 		 ,
# could 		 could
# want 		 want
# nothing 		 nothing
# else 		 else
# . 		 .
# They 		 they
# must 		 must
# have 		 have
# been 		 be
# easily 		 easily
# satisfied 		 satisfied
# in 		 in
# those 		 those
# days 		 day
# , 		 ,
# I 		 I
# should 		 should
# think 		 think
# . 		 .
# But 		 but
#
#
#
# do 		 do
# n't 		 n't
# loiter 		 loiter
# , 		 ,
# boy 		 boy
# . 		 .
# " 		 "

# %%
import io
nlp_fr = spacy.load("fr_core_news_sm")

path = 'hugoExtrait.txt'

hugo_text = open(path, encoding="utf-8").read()
text = ""
hugo_doc = nlp_fr(hugo_text)

print("Token \t\t Lemme")
for token in hugo_doc:
    print(token, "\t\t",token.lemma_)
# Out:
# Token 		 Lemme
# Le 		 le
# spectacle 		 spectacle
# était 		 être
# épouvantable 		 épouvantable
# et 		 et
# charmant 		 charmer
# . 		 .
# Gavroche 		 Gavroche
# , 		 ,
# fusillé 		 fusiller
# , 		 ,
# taquinait 		 taquiner
# la 		 le
# fusillade 		 fusillade
# . 		 .
# Il 		 il
# avait 		 avoir
# l' 		 le
# air 		 air
# de 		 de
# s' 		 se
# amuser 		 amuser
# beaucoup 		 beaucoup
# . 		 .
# C' 		 ce
# était 		 être
# le 		 le
# moineau 		 moineau
# becquetant 		 becqueter
# les 		 le
# chasseurs 		 chasseur
# . 		 .
# Il 		 il
# répondait 		 répondre
# à 		 à
# chaque 		 chaque
# décharge 		 décharge
# par 		 par
# un 		 un
# couplet 		 couplet
# . 		 .
# On 		 on
# le 		 le
# visait 		 visait
# sans 		 sans
# cesse 		 cesse
# , 		 ,
# on 		 on
# le 		 le
# manquait 		 manquer
# toujours 		 toujours
# . 		 .
# Les 		 le
# gardes 		 garde
# nationaux 		 national
# et 		 et
# les 		 le
# soldats 		 soldat
# riaient 		 rire
# en 		 en
# l' 		 le
# ajustant 		 ajuster
# . 		 .
# Il 		 il
# se 		 se
# couchait 		 coucher
# , 		 ,
# puis 		 puis
# se 		 se
# redressait 		 redresser
# , 		 ,
# s' 		 se
# effaçait 		 effacer
# dans 		 dans
# un 		 un
# coin 		 coin
# de 		 de
# porte 		 porte
# , 		 ,
# puis 		 puis
# bondissait 		 bondir
# , 		 ,
# disparaissait 		 disparaître
# , 		 ,
#
# reparaissait 		 reparaître
# , 		 ,
# se 		 se
# sauvait 		 sauver
# , 		 ,
# revenait 		 revenir
# , 		 ,
# ripostait 		 riposter
# à 		 à
# la 		 le
# mitraille 		 mitraille
# par 		 par
# des 		 un
# pieds 		 pied
# de 		 de
# nez 		 nez
# , 		 ,
# et 		 et
# cependant 		 cependant
# pillait 		 piller
# les 		 le
# cartouches 		 cartouche
# , 		 ,
# vidait 		 vider
# les 		 le
# gibernes 		 giberne
# et 		 et
# remplissait 		 remplir
# son 		 son
# panier 		 panier
# . 		 .
# Les 		 le
# insurgés 		 insurgé
# , 		 ,
# haletants 		 haletant
# d' 		 de
# anxiété 		 anxiété
# , 		 ,
# le 		 le
# suivaient 		 suivaient
# des 		 de
# yeux 		 oeil
# . 		 .
# La 		 le
# barricade 		 barricade
# tremblait 		 trembler
# ; 		 ;
# lui 		 lui
# , 		 ,
# il 		 il
# chantait 		 chanter
# . 		 .
# Ce 		 ce
# n' 		 n'
# était 		 être
# pas 		 pas
# un 		 un
# enfant 		 enfant
# , 		 ,
# ce 		 ce
# n' 		 n'
# était 		 être
# pas 		 pas
# un 		 un
# homme 		 homme
# ; 		 ;
# c' 		 ce
# était 		 être
# un 		 un
# étrange 		 étrange
# gamin 		 gamin
# fée 		 fée
# . 		 .
# On 		 on
# eût 		 eût
# dit 		 dire
# le 		 le
# nain 		 nain
# invulnérable 		 invulnérable
# de 		 de
# la 		 le
# mêlée 		 mêlée
# . 		 .
# Les 		 le
# balles 		 balle
# couraient 		 couraient
# après 		 après
# lui 		 lui
# , 		 ,
# lui 		 lui
# , 		 ,
# il 		 il
# était 		 être
# plus 		 plus
# leste 		 leste
# qu' 		 que
# elles 		 lui
# . 		 .
# Il 		 il
# jouait 		 jouer
# on 		 on
# ne 		 ne
# sait 		 savoir
# quel 		 quel
# effrayant 		 effrayer
# jeu 		 jeu
# de 		 de
# cache-cache 		 cache-cache
# avec 		 avec
# la 		 le
# mort 		 mort
# ; 		 ;
# chaque 		 chaque
# fois 		 fois
# que 		 que
# la 		 le
# face 		 face
# camarde 		 camarde
# du 		 de
# spectre 		 spectre
# s' 		 se
# approchait 		 approcher
# , 		 ,
# le 		 le
# gamin 		 gamin
# lui 		 lui
# donnait 		 donner
# une 		 un
# pichenette 		 pichenette
# . 		 .

# %% [markdown]
# #### Etape 5 : POS tagger
#
# On peut continuer de jouer avec les objets token avec l'étiquettage morpho-syntaxique de ces derniers.

# %%
for token in dickens_doc:
    print("{}\t{}\t{}\t{}\t{}\t".format(token, token.lemma_,token.tag_, token.pos_, spacy.explain(token.tag_)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-54c22e40cbe0> in <module>
# ----> 1 for token in dickens_doc:
#       2     print("{}\t{}\t{}\t{}\t{}\t".format(token, token.lemma_,token.tag_, token.pos_, spacy.explain(token.tag_)))
#
# NameError: name 'dickens_doc' is not defined

# %%
for token in hugo_doc:
    print("{}\t{}\t{}\t{}\t".format(token, token.tag_, token.pos_, spacy.explain(token.tag_), spacy.explain(token.pos_)))
# Out:
# Le	DET	DET	determiner
# spectacle	NOUN	NOUN	noun
# était	AUX	AUX	auxiliary
# épouvantable	ADJ	ADJ	adjective
# et	CCONJ	CCONJ	coordinating conjunction
# charmant	VERB	VERB	verb
# .	PUNCT	PUNCT	punctuation
# Gavroche	PROPN	PROPN	proper noun
# ,	PUNCT	PUNCT	punctuation
# fusillé	ADJ	ADJ	adjective
# ,	PUNCT	PUNCT	punctuation
# taquinait	VERB	VERB	verb
# la	DET	DET	determiner
# fusillade	NOUN	NOUN	noun
# .	PUNCT	PUNCT	punctuation
# Il	PRON	PRON	pronoun
# avait	VERB	VERB	verb
# l'	DET	DET	determiner
# air	NOUN	NOUN	noun
# de	ADP	ADP	adposition
# s'	PRON	PRON	pronoun
# amuser	VERB	VERB	verb
# beaucoup	ADV	ADV	adverb
# .	PUNCT	PUNCT	punctuation
# C'	PRON	PRON	pronoun
# était	AUX	AUX	auxiliary
# le	DET	DET	determiner
# moineau	NOUN	NOUN	noun
# becquetant	VERB	VERB	verb
# les	DET	DET	determiner
# chasseurs	NOUN	NOUN	noun
# .	PUNCT	PUNCT	punctuation
# Il	PRON	PRON	pronoun
# répondait	VERB	VERB	verb
# à	ADP	ADP	adposition
# chaque	DET	DET	determiner
# décharge	NOUN	NOUN	noun
# par	ADP	ADP	adposition
# un	DET	DET	determiner
# couplet	NOUN	NOUN	noun
# .	PUNCT	PUNCT	punctuation
# On	PRON	PRON	pronoun
# le	PRON	PRON	pronoun
# visait	NOUN	NOUN	noun
# sans	ADP	ADP	adposition
# cesse	NOUN	NOUN	noun
# ,	PUNCT	PUNCT	punctuation
# on	PRON	PRON	pronoun
# le	PRON	PRON	pronoun
# manquait	VERB	VERB	verb
# toujours	ADV	ADV	adverb
# .	PUNCT	PUNCT	punctuation
# Les	DET	DET	determiner
# gardes	NOUN	NOUN	noun
# nationaux	ADJ	ADJ	adjective
# et	CCONJ	CCONJ	coordinating conjunction
# les	DET	DET	determiner
# soldats	NOUN	NOUN	noun
# riaient	VERB	VERB	verb
# en	ADP	ADP	adposition
# l'	DET	DET	determiner
# ajustant	VERB	VERB	verb
# .	PUNCT	PUNCT	punctuation
# Il	PRON	PRON	pronoun
# se	PRON	PRON	pronoun
# couchait	VERB	VERB	verb
# ,	PUNCT	PUNCT	punctuation
# puis	CCONJ	CCONJ	coordinating conjunction
# se	PRON	PRON	pronoun
# redressait	VERB	VERB	verb
# ,	PUNCT	PUNCT	punctuation
# s'	PRON	PRON	pronoun
# effaçait	VERB	VERB	verb
# dans	ADP	ADP	adposition
# un	DET	DET	determiner
# coin	NOUN	NOUN	noun
# de	ADP	ADP	adposition
# porte	VERB	VERB	verb
# ,	PUNCT	PUNCT	punctuation
# puis	CCONJ	CCONJ	coordinating conjunction
# bondissait	VERB	VERB	verb
# ,	PUNCT	PUNCT	punctuation
# disparaissait	VERB	VERB	verb
# ,	PUNCT	PUNCT	punctuation
#  	SPACE	SPACE	space
# reparaissait	VERB	VERB	verb
# ,	PUNCT	PUNCT	punctuation
# se	PRON	PRON	pronoun
# sauvait	VERB	VERB	verb
# ,	PUNCT	PUNCT	punctuation
# revenait	VERB	VERB	verb
# ,	PUNCT	PUNCT	punctuation
# ripostait	VERB	VERB	verb
# à	ADP	ADP	adposition
# la	DET	DET	determiner
# mitraille	NOUN	NOUN	noun
# par	ADP	ADP	adposition
# des	DET	DET	determiner
# pieds	NOUN	NOUN	noun
# de	ADP	ADP	adposition
# nez	NOUN	NOUN	noun
# ,	PUNCT	PUNCT	punctuation
# et	CCONJ	CCONJ	coordinating conjunction
# cependant	ADV	ADV	adverb
# pillait	VERB	VERB	verb
# les	DET	DET	determiner
# cartouches	NOUN	NOUN	noun
# ,	PUNCT	PUNCT	punctuation
# vidait	VERB	VERB	verb
# les	DET	DET	determiner
# gibernes	NOUN	NOUN	noun
# et	CCONJ	CCONJ	coordinating conjunction
# remplissait	VERB	VERB	verb
# son	DET	DET	determiner
# panier	NOUN	NOUN	noun
# .	PUNCT	PUNCT	punctuation
# Les	DET	DET	determiner
# insurgés	NOUN	NOUN	noun
# ,	PUNCT	PUNCT	punctuation
# haletants	ADJ	ADJ	adjective
# d'	ADP	ADP	adposition
# anxiété	NOUN	NOUN	noun
# ,	PUNCT	PUNCT	punctuation
# le	DET	DET	determiner
# suivaient	NOUN	NOUN	noun
# des	ADP	ADP	adposition
# yeux	NOUN	NOUN	noun
# .	PUNCT	PUNCT	punctuation
# La	DET	DET	determiner
# barricade	NOUN	NOUN	noun
# tremblait	VERB	VERB	verb
# ;	PUNCT	PUNCT	punctuation
# lui	PRON	PRON	pronoun
# ,	PUNCT	PUNCT	punctuation
# il	PRON	PRON	pronoun
# chantait	VERB	VERB	verb
# .	PUNCT	PUNCT	punctuation
# Ce	PRON	PRON	pronoun
# n'	ADV	ADV	adverb
# était	AUX	AUX	auxiliary
# pas	ADV	ADV	adverb
# un	DET	DET	determiner
# enfant	NOUN	NOUN	noun
# ,	PUNCT	PUNCT	punctuation
# ce	PRON	PRON	pronoun
# n'	ADV	ADV	adverb
# était	AUX	AUX	auxiliary
# pas	ADV	ADV	adverb
# un	DET	DET	determiner
# homme	NOUN	NOUN	noun
# ;	PUNCT	PUNCT	punctuation
# c'	PRON	PRON	pronoun
# était	AUX	AUX	auxiliary
# un	DET	DET	determiner
# étrange	NOUN	NOUN	noun
# gamin	ADJ	ADJ	adjective
# fée	ADV	ADV	adverb
# .	PUNCT	PUNCT	punctuation
# On	PRON	PRON	pronoun
# eût	PRON	PRON	pronoun
# dit	VERB	VERB	verb
# le	DET	DET	determiner
# nain	NOUN	NOUN	noun
# invulnérable	ADJ	ADJ	adjective
# de	ADP	ADP	adposition
# la	DET	DET	determiner
# mêlée	NOUN	NOUN	noun
# .	PUNCT	PUNCT	punctuation
# Les	DET	DET	determiner
# balles	NOUN	NOUN	noun
# couraient	ADV	ADV	adverb
# après	ADP	ADP	adposition
# lui	PRON	PRON	pronoun
# ,	PUNCT	PUNCT	punctuation
# lui	PRON	PRON	pronoun
# ,	PUNCT	PUNCT	punctuation
# il	PRON	PRON	pronoun
# était	AUX	AUX	auxiliary
# plus	ADV	ADV	adverb
# leste	ADJ	ADJ	adjective
# qu'	SCONJ	SCONJ	subordinating conjunction
# elles	PRON	PRON	pronoun
# .	PUNCT	PUNCT	punctuation
# Il	PRON	PRON	pronoun
# jouait	VERB	VERB	verb
# on	PRON	PRON	pronoun
# ne	ADV	ADV	adverb
# sait	VERB	VERB	verb
# quel	DET	DET	determiner
# effrayant	VERB	VERB	verb
# jeu	NOUN	NOUN	noun
# de	ADP	ADP	adposition
# cache-cache	NOUN	NOUN	noun
# avec	ADP	ADP	adposition
# la	DET	DET	determiner
# mort	NOUN	NOUN	noun
# ;	PUNCT	PUNCT	punctuation
# chaque	DET	DET	determiner
# fois	NOUN	NOUN	noun
# que	SCONJ	SCONJ	subordinating conjunction
# la	DET	DET	determiner
# face	NOUN	NOUN	noun
# camarde	NOUN	NOUN	noun
# du	ADP	ADP	adposition
# spectre	NOUN	NOUN	noun
# s'	PRON	PRON	pronoun
# approchait	VERB	VERB	verb
# ,	PUNCT	PUNCT	punctuation
# le	DET	DET	determiner
# gamin	NOUN	NOUN	noun
# lui	PRON	PRON	pronoun
# donnait	VERB	VERB	verb
# une	DET	DET	determiner
# pichenette	NOUN	NOUN	noun
# .	PUNCT	PUNCT	punctuation

# %% [markdown]
# #### Etape 6 : Visualiser
#
# spaCy offre la possibilité de visualiser les dépendances
#
# Attention, en lançant la cellule, ça va ouvrir un petit serveur local consultable à l'adresse : http://127.0.0.1:5000
# Il faudra interrompre l'exécution de la cellule pour arrêter le serveur.

# %%
from spacy import displacy

exemple = "La belle ferme la porte"

exemple_doc = nlp_fr(exemple)

displacy.render(exemple_doc, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="0ac4ffd1db9045e690cba5cf6bf252ce-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">La</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">belle</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">ferme</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">porte</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0ac4ffd1db9045e690cba5cf6bf252ce-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0ac4ffd1db9045e690cba5cf6bf252ce-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0ac4ffd1db9045e690cba5cf6bf252ce-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0ac4ffd1db9045e690cba5cf6bf252ce-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0ac4ffd1db9045e690cba5cf6bf252ce-0-2" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0ac4ffd1db9045e690cba5cf6bf252ce-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,179.0 L587,167.0 603,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0ac4ffd1db9045e690cba5cf6bf252ce-0-3" stroke-width="2px" d="M420,177.0 C420,2.0 750.0,2.0 750.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0ac4ffd1db9045e690cba5cf6bf252ce-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,179.0 L758.0,167.0 742.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
for token in exemple_doc:
    print(token.text, "-->", token.dep_)
# Out:
# La --> det
# belle --> amod
# ferme --> ROOT
# la --> det
# porte --> obj

# %%
exemple_en = "Shakespeare is like mashed potatoes, you can never get enough of him."

exemple_doc = nlp(exemple_en)

displacy.serve(exemple_doc, style="dep")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2bf30272e92f403a84cbd48bad3a6130-0" class="displacy" width="2325" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Shakespeare</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">like</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">mashed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">potatoes,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">never</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">get</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">enough</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">him.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PRON</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2bf30272e92f403a84cbd48bad3a6130-0-0" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2bf30272e92f403a84cbd48bad3a6130-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2bf30272e92f403a84cbd48bad3a6130-0-1" stroke-width="2px" d="M420,352.0 C420,2.0 1625.0,2.0 1625.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2bf30272e92f403a84cbd48bad3a6130-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2bf30272e92f403a84cbd48bad3a6130-0-2" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2bf30272e92f403a84cbd48bad3a6130-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M560.0,354.0 L568.0,342.0 552.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2bf30272e92f403a84cbd48bad3a6130-0-3" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2bf30272e92f403a84cbd48bad3a6130-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2bf30272e92f403a84cbd48bad3a6130-0-4" stroke-width="2px" d="M595,352.0 C595,177.0 915.0,177.0 915.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2bf30272e92f403a84cbd48bad3a6130-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,354.0 L923.0,342.0 907.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2bf30272e92f403a84cbd48bad3a6130-0-5" stroke-width="2px" d="M1120,352.0 C1120,89.5 1620.0,89.5 1620.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2bf30272e92f403a84cbd48bad3a6130-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,354.0 L1112,342.0 1128,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2bf30272e92f403a84cbd48bad3a6130-0-6" stroke-width="2px" d="M1295,352.0 C1295,177.0 1615.0,177.0 1615.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2bf30272e92f403a84cbd48bad3a6130-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,354.0 L1287,342.0 1303,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
import spacy
from spacy import displacy

path = 'marieCurie.txt'
text = open(path, encoding="utf-8").read()

nlp = spacy.load("fr_core_news_lg")
doc = nlp(text)
displacy.render(doc, style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Cinquième enfant d’une famille d’enseignants patriotes et très cultivés,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maria Sklodowska
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  naît le 7 novembre 1867 à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Varsovie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , dans une partie de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     la Pologne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  alors sous domination de l’empire
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . Elevée dans une famille où l’instruction à une grande importance, elle réussit brillamment ses études secondaires, et rêve d’étudier les sciences. Mais à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Varsovie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , à l’époque, les universités ne sont pas ouvertes aux femmes. Le seul moyen pour une jeune polonaise qui souhaite poursuivre des études supérieures est donc de partir à l’étranger. Sa soeur ainée
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bronia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  a le même désir, et veut étudier la médecine. Les deux sœurs concluent ainsi un pacte et choisissent de venir étudier en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  en conjuguant leurs efforts.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  se place comme préceptrice dans une famille pendant plusieurs années pour aider sa sœur partie à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  et se constituer des économies pour ses futures études.</br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Marie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  arrive à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  et s’inscrit à la
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sorbonne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  en octobre 1891. Consciente de ses lacunes, elle se plonge dans les études et décide de refaire une première année. Les enseignements la fascinant, elle travaille parfois au-delà de ses forces. Elle obtient en 1893, une licence ès sciences physiques avec la mention très bien, et en 1894, une licence ès sciences mathématiques avec la mention assez bien. Elle compte retourner enseigner en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pologne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  dès ses deux licences acquises, mais l’obtention, en début 1894, d’un petit contrat financé par la
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Société pour l'encouragement de l'industrie nationale
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SEIN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) pour mesurer les propriétés magnétiques de différents aciers l’amène à rencontrer
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pierre Curie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# .</br></br></div></span>

# %%
import spacy
from spacy import displacy

path = 'marieCurie_en.txt'
text = open(path, encoding="utf-8").read()

nlp = spacy.load("en_core_web_lg")
doc = nlp(text)
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Marie Curie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , née
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maria Sklodowska
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , was born in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Warsaw
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     November 7, 1867
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the daughter of a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     secondary
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -school teacher. She received a general education in local schools and some scientific training from her father. She became involved in a students’ revolutionary organization and found it prudent to leave
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Warsaw
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , then in the part of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Poland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  dominated by
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , for
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cracow
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , which at that time was under
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Austrian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  rule. In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1891
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , she went to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to continue her studies at the Sorbonne where she obtained Licenciateships in
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Physics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Mathematical Sciences
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . She met
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pierre Curie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Professor in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the School of Physics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1894
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the following year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  they were married. She succeeded her husband as Head of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Physics Laboratory
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  at the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sorbonne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , gained her Doctor of Science degree in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1903
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , and following the tragic death of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pierre Curie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1906
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , she took his place as Professor of General Physics in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Faculty of Sciences
#     <span style="font-size: 0.8em; font-weight: bo

# %%
import spacy
from spacy import displacy

path = 'kasparov_ru.txt'
text = open(path, encoding="utf-8").read()

nlp = spacy.load("ru_core_news_sm")
doc = nlp(text)
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Га́рри Ки́мович Каспа́ров
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (фамилия при рождении Вайнште́йн; род. 13 апреля 1963,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Баку
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Азербайджанская ССР
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     СССР
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ) — советский и российский шахматист, 13-й чемпион мира по шахматам, шахматный литератор и политик, часто признаваемый величайшим шахматистом в истории. Международный гроссмейстер (1980), заслуженный мастер спорта
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     СССР
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  (1985), чемпион
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     СССР
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  (1981, 1988), чемпион
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     России
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  (2004). Восьмикратный победитель Всемирных шахматных олимпиад: четырежды в составе команды
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     СССР
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  (1980, 1982, 1986, 1988) и четырежды в составе команды
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     России
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  (1992, 1994, 1996, 2002). Обладатель одиннадцати шахматных «Оскаров» (призов лучшему шахматисту года).
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Каспаров
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  единолично возглавлял рейтинг
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ФИДЕ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  с 1985 по 2006 год с двумя короткими перерывами: в 1994 году он был исключён из рейтинга по решению
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ФИДЕ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , принятому в 1993 году, а в январе 1996 года
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Каспаров
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  имел такой же рейтинг, как
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Владимир Крамник
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . В 1999 году
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Гарри Каспаров
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  достиг рекордного рейтинга в 2851 пункт. Рекорд держался 13 с половиной лет[11], пока не был побит
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Магнусом Карлсеном
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# .</div></span>

# %%
print("Token  --  indexDeb  --  IndexFin  --  Etiq.")
print("--"*30)
for e in doc.ents: 
    print("{} --  {}  --  {}  --  {} --  {}".format(e.text, e.start_char, e.end_char, e.label_, spacy.explain(e.label_)))
# Out:
# Token  --  indexDeb  --  IndexFin  --  Etiq.
# ------------------------------------------------------------
# Га́рри Ки́мович Каспа́ров --  0  --  25  --  PER --  Named person or family.
# Баку --  81  --  85  --  LOC --  Non-GPE locations, mountain ranges, bodies of water
# Азербайджанская ССР --  87  --  106  --  LOC --  Non-GPE locations, mountain ranges, bodies of water
# СССР --  108  --  112  --  LOC --  Non-GPE locations, mountain ranges, bodies of water
# СССР --  326  --  330  --  LOC --  Non-GPE locations, mountain ranges, bodies of water
# СССР --  347  --  351  --  LOC --  Non-GPE locations, mountain ranges, bodies of water
# России --  374  --  380  --  LOC --  Non-GPE locations, mountain ranges, bodies of water
# СССР --  472  --  476  --  LOC --  Non-GPE locations, mountain ranges, bodies of water
# России --  532  --  538  --  LOC --  Non-GPE locations, mountain ranges, bodies of water
# Каспаров --  642  --  650  --  PER --  Named person or family.
# ФИДЕ --  681  --  685  --  ORG --  Companies, agencies, institutions, etc.
# ФИДЕ --  786  --  790  --  ORG --  Companies, agencies, institutions, etc.
# Каспаров --  836  --  844  --  PER --  Named person or family.
# Владимир Крамник --  872  --  888  --  PER --  Named person or family.
# Гарри Каспаров --  902  --  916  --  PER --  Named person or family.
# Магнусом Карлсеном --  1016  --  1034  --  PER --  Named person or family.

# %% [markdown]
# Bien que spaCy offre des possibilités en termes de reconnaissances d'entités nommées, les modèles de bases semblent peu probants et très basiques.
#
# Il est intéressant donc d'envisager d'entrainer ces modèles avec différents corpus.
#
# On peut également ajouter des entités manuellement.

# %%
nlp = spacy.load("fr_core_news_sm")
doc = (nlp("Fb est un réseau social particulièrement populaire en France"))

print("Token  --  indexDeb  --  IndexFin  --  Etiq.")
print("--"*30)
for e in doc.ents: 
    print("{} --  {}  --  {}  --  {}".format(e.text, e.start_char, e.end_char, e.label_, spacy.explain(e.label_)))
# Out:
# Token  --  indexDeb  --  IndexFin  --  Etiq.
# ------------------------------------------------------------
# France --  54  --  60  --  LOC

# %%
from spacy.tokens import Span

Fb_entite = Span(doc, 0, 1, label="ORG")
doc.ents = list(doc.ents)+[Fb_entite]

for e in doc.ents: 
    print("{} --  {}  --  {}  --  {}".format(e.text, e.start_char, e.end_char, e.label_, spacy.explain(e.label_)))
# Out:
# Fb --  0  --  2  --  ORG
# France --  54  --  60  --  LOC

# %% [markdown]
# ### Les vecteurs
#
# Les vecteurs correspondent à une manière de représenter les tokens par des chiffres (on les utilise pour entrainer des modèles) et peuvent permettre de comparer des token, des phrases etc.

# %%
import spacy

text = "Cats are very cool. Dogs are nice too."
doc = nlp(text)

vector_cats = doc[0]
vector_dogs = doc[4]

#print(vector_cats)
#print(vector_dogs)

print(vector_cats.similarity(vector_dogs))
# Out:
# -0.072669536
# <ipython-input-19-9d3d100f482f>:12: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Token.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   print(vector_cats.similarity(vector_dogs))

# %%
nlp = spacy.load("en_core_web_sm")

doc = nlp("Painting and drawing, why?")
token1, token2 = doc[0], doc[2]

# Get the similarity of the tokens "TV" and "books"
similarity = token1.similarity(token2)
print(similarity)
# Out:
# 0.3925574
# <ipython-input-151-e0566e2cc4a7>:7: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Token.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity = token1.similarity(token2)

# %%
# Test avec des span

doc = nlp("I really like to watch TV. However i'd rather go to the cinema")

span_TV = doc[3:6]
span_cine = doc[-4:]

similarity = span_cine.similarity(span_TV)

print(similarity)

doc = nlp("This was a great restaurant. Afterwards, we went to a really nice bar.")

# Create spans for "great restaurant" and "really nice bar"
span1 = doc[3:5]
span2 = doc[12:15]

# Get the similarity of the spans
similarityEX = span1.similarity(span2)
print(similarityEX)
# Out:
# 0.34619305
# 0.6904658
# <ipython-input-164-6b3567cf9c9b>:8: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Span.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity = span_cine.similarity(span_TV)
# <ipython-input-164-6b3567cf9c9b>:19: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Span.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarityEX = span1.similarity(span2)

# %% [markdown]
# Code pour exemple présentation

# %%
import spacy
from spacy.tokens import Span

text = "Morgann explains how spaCy works"

print(len(text))
print(len(doc))
nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

[(print(ent.text, ent.label_)) for ent in doc.ents]

Spacy_ent = Span(doc, 3, 4, label="LIB")
doc.ents = list(doc.ents)+[Spacy_ent]

[(ent.text, ent.label_) for ent in doc.ents]
# Out:
# 32
# 5
# Morgann PERSON
# [('Morgann', 'PERSON'), ('spaCy', 'LIB')]

# %%
spacy.explain("amod")
# Out:
# 'adjectival modifier'

# %%
from spacy import displacy


text_fr = "Morgann explains how spaCy works."
nlp = spacy.load("en_core_web_lg")

doc_fr = nlp(text_fr)

displacy.render(doc_fr, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ec62902eb6c7452d8e3e0d9f252727f4-0" class="displacy" width="925" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Morgann</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">explains</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">how</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">spaCy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">works.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ec62902eb6c7452d8e3e0d9f252727f4-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ec62902eb6c7452d8e3e0d9f252727f4-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ec62902eb6c7452d8e3e0d9f252727f4-0-1" stroke-width="2px" d="M420,264.5 C420,89.5 745.0,89.5 745.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ec62902eb6c7452d8e3e0d9f252727f4-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ec62902eb6c7452d8e3e0d9f252727f4-0-2" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ec62902eb6c7452d8e3e0d9f252727f4-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ec62902eb6c7452d8e3e0d9f252727f4-0-3" stroke-width="2px" d="M245,264.5 C245,2.0 750.0,2.0 750.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ec62902eb6c7452d8e3e0d9f252727f4-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,266.5 L758.0,254.5 742.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>

# %%
import nltk
from nltk import word_tokenize

path = 'marieCurie.txt'
text = open(path, encoding="utf-8").read()
text = "pot-au-feu"

tokensNLTK = word_tokenize(text, language="french")

print(len(tokensNLTK))
print(tokensNLTK)
# Out:
# 1
# ['pot-au-feu']

# %%
nlp = spacy.load("fr_core_news_sm")
doc = nlp(text)

print(len(doc))
print(doc.text)
print(type(doc))
for tok in doc:
    print(tok.text)
# Out:
# 1
# pot-au-feu
# <class 'spacy.tokens.doc.Doc'>
# pot-au-feu

# %%
import spacy

nlp_en = spacy.load("en_core_web_sm")
text = "Hot topics on Twitter: #Life and #Trump"

doc_zh = nlp_en(text)

for tok in doc_zh:
    print(tok)
# Out:
# Hot
# topics
# on
# Twitter
# :
# #
# Life
# and
# #
# Trump

# %%
import nltk
from nltk import word_tokenize

tokensNLTK = word_tokenize(text)

print(len(tokensNLTK))
print(tokensNLTK)
# Out:
# 10
# ['Hot', 'topics', 'on', 'Twitter', ':', '#', 'Life', 'and', '#', 'Trump']

# %%
import spacy

nlp_en = spacy.load("en_core_web_sm")
text = "We are going to look at some spaCy examples."

doc = nlp_en(text)
print("token\t lemma_\t tag\t pos_\t morph \t explain tag\t explain pos")
for token in doc:
    print("{}\t {}\t {}\t {}\t {}\t {}\t"
            .format(token, token.lemma_, token.tag_, token.pos_, token.morph, spacy.explain(token.tag_)))
# Out:
# token	 lemma_	 tag	 pos_	 morph 	 explain tag	 explain pos
# We	 we	 PRP	 PRON	 Case=Nom|Number=Plur|Person=1|PronType=Prs	 pronoun, personal
# are	 be	 VBP	 AUX	 Mood=Ind|Tense=Pres|VerbForm=Fin	 verb, non-3rd person singular present
# going	 go	 VBG	 VERB	 Aspect=Prog|Tense=Pres|VerbForm=Part	 verb, gerund or present participle
# to	 to	 TO	 PART	 	 infinitival "to"
# look	 look	 VB	 VERB	 VerbForm=Inf	 verb, base form
# at	 at	 IN	 ADP	 	 conjunction, subordinating or preposition
# some	 some	 DT	 DET	 	 determiner
# spaCy	 spaCy	 JJR	 ADJ	 Degree=Cmp	 adjective, comparative
# examples	 example	 NNS	 NOUN	 Number=Plur	 noun, plural
# .	 .	 .	 PUNCT	 PunctType=Peri	 punctuation mark, sentence closer

# %%
from spacy import displacy

text = "le tour de France, la tour Eiffel, Bouygues Telecom, Jean-Pierre Pernaut, Game of Thrones, l'Attaque des Titans, le Parisien, Paris, parisien"
nlp_fr = spacy.load("fr_core_news_lg")

doc = nlp_fr(text)

displacy.render(doc, style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">le
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tour de France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , la
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tour Eiffel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bouygues Telecom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jean-Pierre Pernaut
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Game of Thrones
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     l'Attaque des Titans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , le
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Parisien
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , parisien</div></span>

# %%
path = 'marieCurie.txt'
text = open(path, encoding="utf-8").read()

doc = nlp_fr(text)
displacy.render(doc, style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Cinquième enfant d’une famille d’enseignants patriotes et très cultivés,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maria Sklodowska
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  naît le 7 novembre 1867 à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Varsovie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , dans une partie de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     la Pologne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  alors sous domination de l’empire
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . Elevée dans une famille où l’instruction à une grande importance, elle réussit brillamment ses études secondaires, et rêve d’étudier les sciences. Mais à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Varsovie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , à l’époque, les universités ne sont pas ouvertes aux femmes. Le seul moyen pour une jeune polonaise qui souhaite poursuivre des études supérieures est donc de partir à l’étranger. Sa soeur ainée
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bronia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  a le même désir, et veut étudier la médecine. Les deux sœurs concluent ainsi un pacte et choisissent de venir étudier en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  en conjuguant leurs efforts.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  se place comme préceptrice dans une famille pendant plusieurs années pour aider sa sœur partie à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  et se constituer des économies pour ses futures études.</br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Marie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  arrive à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  et s’inscrit à la
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sorbonne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  en octobre 1891. Consciente de ses lacunes, elle se plonge dans les études et décide de refaire une première année. Les enseignements la fascinant, elle travaille parfois au-delà de ses forces. Elle obtient en 1893, une licence ès sciences physiques avec la mention très bien, et en 1894, une licence ès sciences mathématiques avec la mention assez bien. Elle compte retourner enseigner en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pologne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  dès ses deux licences acquises, mais l’obtention, en début 1894, d’un petit contrat financé par la
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Société pour l'encouragement de l'industrie nationale
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SEIN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) pour mesurer les propriétés magnétiques de différents aciers l’amène à rencontrer
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pierre Curie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# .</br></br></div></span>
