# %%
#----Installation----#

# pip install -U spacy
# python -m spacy download en_core_web_sm

import spacy
import time

nlp = spacy.load("en_core_web_sm")
nlp_fr = spacy.load("fr_core_news_sm")
nlp_ru = spacy.load("ru_core_news_sm")

# %%
import nltk
from nltk import word_tokenize

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'ner', 'attribute_ruler', 'lemmatizer']

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x2157565e400>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x215755093b0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x2157545da00>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x21575306a60>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x21568adcb00>),
#  ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x215756d5bc0>)]

# %%
nlp_fr.pipe_names
# Out:
# ['tok2vec', 'morphologizer', 'parser', 'ner', 'attribute_ruler', 'lemmatizer']

# %%
nlp_ru.pipe_names
# Out:
# ['tok2vec', 'morphologizer', 'parser', 'ner', 'attribute_ruler', 'lemmatizer']

# %% [markdown]
# ### Création des doc avec spaCy (tokenisation + annotation etc)

# %%
start_time = time.time()

pathEN = "hawkingEN.txt"
pathFR = "hawkingFR.txt"
pathRU = "hawkingRU.txt"

textEN = open(pathEN, encoding="utf-8").read()
textFR = open(pathFR, encoding="utf-8").read()
textRU = open(pathRU, encoding="utf-8").read()

docEN = nlp(textEN)
docFR = nlp_fr(textFR)
docRU = nlp_ru(textRU)

print("--- %s secondes ---" % (time.time() - start_time))
# Out:
# --- 0.2525629997253418 secondes ---

# %% [markdown]
# ### Tokenization NLTK

# %%
start_time = time.time()

pathEN = "hawkingEN.txt"
pathFR = "hawkingFR.txt"
pathRU = "hawkingRU.txt"

textEN = open(pathEN, encoding="utf-8").read()
textFR = open(pathFR, encoding="utf-8").read()
textRU = open(pathRU, encoding="utf-8").read()

docEN_nltk = word_tokenize(textEN)
docFR_nltk = word_tokenize(textFR)
docRU_nltk = word_tokenize(textRU)

print("--- %s secondes ---" % (time.time() - start_time))
# Out:
# --- 0.007911443710327148 secondes ---

# %% [markdown]
# ### Maintenant allons voir ce qu'on peut extraire des tokens

# %%
print(docFR)
for token in docFR:
    print(token.text)

print(len(docFR))
# Out:
# Stephen William Hawking (prononcé [ˈstiːvən ˈhɔːkɪŋ]), né le 8 janvier 1942 à Oxford et mort le 14 mars 2018 à Cambridge, est un physicien théoricien et cosmologiste britannique. Ses livres et ses apparitions publiques ont fait de ce théoricien de renommée mondiale une célébrité.
#
# Depuis l'âge d'une vingtaine d'années, Hawking souffre d'une forme rare — de début précoce et d'évolution lente — de sclérose latérale amyotrophique (SLA) ; sa maladie progresse au fil des ans au point de le laisser presque complètement paralysé. Pourtant, il est professeur de mathématiques à l'université de Cambridge de 1980 à 20091, membre du Gonville and Caius College et chercheur distingué du Perimeter Institute for Theoretical Physics. Il est connu pour ses contributions dans les domaines de la cosmologie et la gravité quantique, en particulier dans le cadre des trous noirs. Son succès est également lié à ses ouvrages de vulgarisation scientifique dans lesquels il discute de ses théories et de la cosmologie en général, en particulier Une brève histoire du temps.
#
# La clé des principaux travaux scientifiques de Stephen Hawking est fondée, en collaboration avec Roger Penrose, sur l'élaboration des théorèmes sur les singularités dans le cadre de la relativité générale, et la prédiction théorique que les trous noirs devraient émettre ce qui est aujourd'hui connu sous le nom de rayonnement de Hawking.
# Stephen
# William
# Hawking
# (
# prononcé
# [
# ˈstiːvən
# ˈhɔːkɪŋ
# ]
# )
# ,
# né
# le
# 8
# janvier
# 1942
# à
# Oxford
# et
# mort
# le
# 14
# mars
# 2018
# à
# Cambridge
# ,
# est
# un
# physicien
# théoricien
# et
# cosmologiste
# britannique
# .
# Ses
# livres
# et
# ses
# apparitions
# publiques
# ont
# fait
# de
# ce
# théoricien
# de
# renommée
# mondiale
# une
# célébrité
# .
#
#
#
# Depuis
# l'
# âge
# d'
# une
# vingtaine
# d'
# années
# ,
# Hawking
# souffre
# d'
# une
# forme
# rare
# —
# de
# début
# précoce
# et
# d'
# évolution
# lente
# —
# de
# sclérose
# latérale
# amyotrophique
# (
# SLA
# )
# ;
# sa
# maladie
# progresse
# au
# fil
# des
# ans
# au
# point
# de
# le
# laisser
# presque
# complètement
# paralysé
# .
# Pourtant
# ,
# il
# est
# professeur
# de
# mathématiques
# à
# l'
# université
# de
# Cambridge
# de
# 1980
# à
# 20091
# ,
# membre
# du
# Gonville
# and
# Caius
# College
# et
# chercheur
# distingué
# du
# Perimeter
# Institute
# for
# Theoretical
# Physics
# .
# Il
# est
# connu
# pour
# ses
# contributions
# dans
# les
# domaines
# de
# la
# cosmologie
# et
# la
# gravité
# quantique
# ,
# en
# particulier
# dans
# le
# cadre
# des
# trous
# noirs
# .
# Son
# succès
# est
# également
# lié
# à
# ses
# ouvrages
# de
# vulgarisation
# scientifique
# dans
# lesquels
# il
# discute
# de
# ses
# théories
# et
# de
# la
# cosmologie
# en
# général
# ,
# en
# particulier
# Une
# brève
# histoire
# du
# temps
# .
#
#
#
# La
# clé
# des
# principaux
# travaux
# scientifiques
# de
# Stephen
# Hawking
# est
# fondée
# ,
# en
# collaboration
# avec
# Roger
# Penrose
# ,
# sur
# l'
# élaboration
# des
# théorèmes
# sur
# les
# singularités
# dans
# le
# cadre
# de
# la
# relativité
# générale
# ,
# et
# la
# prédiction
# théorique
# que
# les
# trous
# noirs
# devraient
# émettre
# ce
# qui
# est
# aujourd'hui
# connu
# sous
# le
# nom
# de
# rayonnement
# de
# Hawking
# .
# 251

# %%
for token in docFR:
    print(token, token.lemma_, token.pos_, token.tag_, token.dep_, spacy.explain(token.pos_), spacy.explain(token.tag_), token.morph)

#NOTE progresse --> lemme : progress
#
#
# Theoretical Theoretical PROPN PROPN nmod proper noun proper noun Gender=Masc|Number=Sing
# Physics Physics PROPN PROPN flat:name proper noun proper noun Gender=Masc|Number=Sing
# cosmologiste cosmologist ADJ ADJ conj adjective adjective Number=Sing
# Out:
# Stephen Stephen PROPN PROPN ROOT proper noun proper noun
# William William PROPN PROPN nmod proper noun proper noun
# Hawking Hawking PROPN PROPN flat:name proper noun proper noun Gender=Masc|Number=Sing
# ( ( PUNCT PUNCT punct punctuation punctuation
# prononcé prononcer VERB VERB appos verb verb Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part
# [ [ PUNCT PUNCT punct punctuation punctuation
# ˈstiːvən ˈstiːvən NOUN NOUN ROOT noun noun Gender=Masc|Number=Sing
# ˈhɔːkɪŋ ˈhɔːkɪŋ ADJ ADJ amod adjective adjective
# ] ] PUNCT PUNCT punct punctuation punctuation
# ) ) PUNCT PUNCT punct punctuation punctuation
# , , PUNCT PUNCT punct punctuation punctuation
# né naître VERB VERB ROOT verb verb Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part
# le le DET DET det determiner determiner Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# 8 8 NUM NUM obl:mod numeral numeral NumType=Card
# janvier janvier NOUN NOUN nmod noun noun Gender=Masc|Number=Sing
# 1942 1942 NUM NUM nmod numeral numeral NumType=Card
# à à ADP ADP case adposition adposition
# Oxford Oxford PROPN PROPN obl:arg proper noun proper noun Gender=Masc|Number=Sing
# et et CCONJ CCONJ cc coordinating conjunction coordinating conjunction
# mort mort NOUN NOUN conj noun noun Gender=Fem|Number=Sing
# le le DET DET det determiner determiner Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# 14 14 NUM NUM obl:mod numeral numeral NumType=Card
# mars mars NOUN NOUN nmod noun noun Gender=Masc|Number=Sing
# 2018 2018 NUM NUM nmod numeral numeral NumType=Card
# à à ADP ADP case adposition adposition
# Cambridge Cambridge PROPN PROPN obl:arg proper noun proper noun Gender=Masc|Number=Sing
# , , PUNCT PUNCT punct punctuation punctuation
# est être AUX AUX cop auxiliary auxiliary Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# un un DET DET det determiner determiner Definite=Ind|Gender=Masc|Number=Sing|PronType=Art
# physicien physicien NOUN NOUN conj noun noun Gender=Masc|Number=Sing
# théoricien théoricien ADJ ADJ amod adjective adjective Gender=Masc|Number=Sing
# et et CCONJ CCONJ cc coordinating conjunction coordinating conjunction
# cosmologiste cosmologist ADJ ADJ conj adjective adjective Number=Sing
# britannique britannique ADJ ADJ xcomp adjective adjective Number=Sing
# . . PUNCT PUNCT punct punctuation punctuation
# Ses son DET DET det determiner determiner Number=Plur|Poss=Yes
# livres livre NOUN NOUN nsubj noun noun Number=Plur
# et et CCONJ CCONJ cc coordinating conjunction coordinating conjunction
# ses son DET DET det determiner determiner Number=Plur|Poss=Yes
# apparitions apparition NOUN NOUN conj noun noun Gender=Masc|Number=Plur
# publiques public ADJ ADJ amod adjective adjective Gender=Fem|Number=Plur
# ont avoir AUX AUX aux:tense auxiliary auxiliary Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin
# fait faire VERB VERB ROOT verb verb Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part
# de de ADP ADP case adposition adposition
# ce ce DET DET det determiner determiner Gender=Masc|Number=Sing|PronType=Dem
# théoricien théoricien NOUN NOUN obl:arg noun noun Gender=Masc|Number=Sing
# de de ADP ADP case adposition adposition
# renommée renommée NOUN NOUN nmod noun noun Gender=Fem|Number=Sing
# mondiale mondial ADJ ADJ amod adjective adjective Gender=Fem|Number=Sing
# une un DET DET det determiner determiner Definite=Ind|Gender=Fem|Number=Sing|PronType=Art
# célébrité célébrité NOUN NOUN obj noun noun Gender=Fem|Number=Sing
# . . PUNCT PUNCT punct punctuation punctuation
#
#
#
#
#  SPACE SPACE cc space space Gender=Fem|Number=Plur
# Depuis depuis ADP ADP case adposition adposition
# l' le DET DET det determiner determiner Definite=Def|Number=Sing|PronType=Art
# âge âge NOUN NOUN obl:mod noun noun Gender=Masc|Number=Sing
# d' de ADP ADP case adposition adposition
# une un DET DET det determiner determiner Definite=Ind|Gender=Fem|Number=Sing|PronType=Art
# vingtaine vingtaine NOUN NOUN nmod noun noun Gender=Fem|Number=Sing
# d' de ADP ADP case adposition adposition
# années année NOUN NOUN nmod noun noun Gender=Fem|Number=Plur
# , , PUNCT PUNCT punct punctuation punctuation
# Hawking Hawking PROPN PROPN nsubj proper noun proper noun Gender=Masc|Number=Sing
# souffre souffrir VERB VERB ROOT verb verb Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# d' de ADP ADP case adposition adposition
# une un DET DET det determiner determiner Definite=Ind|Gender=Fem|Number=Sing|PronType=Art
# forme forme NOUN NOUN obl:arg noun noun Gender=Fem|Number=Sing
# rare rare ADJ ADJ amod adjective adjective Gender=Fem|Number=Sing
# — — NOUN NOUN ROOT noun noun Gender=Masc|Number=Sing
# de de ADP ADP case adposition adposition
# début début NOUN NOUN nmod noun noun Gender=Masc|Number=Sing
# précoce précoce ADJ ADJ amod adjective adjective Number=Sing
# et et CCONJ CCONJ cc coordinating conjunction coordinating conjunction
# d' de ADP ADP case adposition adposition
# évolution évolution NOUN NOUN conj noun noun Gender=Fem|Number=Sing
# lente lent ADJ ADJ amod adjective adjective Gender=Fem|Number=Sing
# — — PRON PRON punct pronoun pronoun Gender=Masc|Number=Sing
# de de ADP ADP case adposition adposition
# sclérose sclérose NOUN NOUN nmod noun noun Gender=Fem|Number=Sing
# latérale latéral ADJ ADJ amod adjective adjective Gender=Fem|Number=Sing
# amyotrophique amyotrophique ADJ ADJ amod adjective adjective Number=Sing
# ( ( PUNCT PUNCT punct punctuation punctuation
# SLA SLA PROPN PROPN appos proper noun proper noun
# ) ) PUNCT PUNCT punct punctuation punctuation
# ; ; PUNCT PUNCT punct punctuation punctuation
# sa son DET DET det determiner determiner Gender=Fem|Number=Sing|Poss=Yes
# maladie maladie NOUN NOUN nsubj noun noun Gender=Fem|Number=Sing
# progresse progress ADJ ADJ amod adjective adjective Gender=Fem|Number=Sing
# au au ADP ADP case adposition adposition Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# fil fil NOUN NOUN nmod noun noun Gender=Masc|Number=Sing
# des de ADP ADP case adposition adposition Definite=Def|Number=Plur|PronType=Art
# ans an NOUN NOUN nmod noun noun Gender=Masc|Number=Plur
# au au ADP ADP case adposition adposition Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# point point NOUN NOUN nmod noun noun Gender=Masc|Number=Sing
# de de ADP ADP mark adposition adposition
# le le PRON PRON obj pronoun pronoun Gender=Masc|Number=Sing|Person=3
# laisser laisser VERB VERB aux:tense verb verb VerbForm=Inf
# presque presque ADV ADV advmod adverb adverb
# complètement complètement ADV ADV advmod adverb adverb
# paralysé paralyser VERB VERB ROOT verb verb Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass
# . . PUNCT PUNCT punct punctuation punctuation
# Pourtant pourtant ADV ADV advmod adverb adverb
# , , PUNCT PUNCT punct punctuation punctuation
# il il PRON PRON expl:subj pronoun pronoun Gender=Masc|Number=Sing|Person=3
# est être AUX AUX cop auxiliary auxiliary Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# professeur professeur NOUN NOUN ROOT noun noun Gender=Masc|Number=Sing
# de de ADP ADP case adposition adposition
# mathématiques mathématique ADJ ADJ nmod adjective adjective Number=Plur
# à à ADP ADP case adposition adposition
# l' le DET DET det determiner determiner Definite=Def|Number=Sing|PronType=Art
# université université NOUN NOUN obl:mod noun noun Gender=Fem|Number=Sing
# de de ADP ADP case adposition adposition
# Cambridge Cambridge PROPN PROPN nmod proper noun proper noun Gender=Masc|Number=Sing
# de de ADP ADP case adposition adposition
# 1980 1980 NUM NUM nmod numeral numeral NumType=Card
# à à ADP ADP case adposition adposition
# 20091 20091 NUM NUM nmod numeral numeral NumType=Card
# , , PUNCT PUNCT punct punctuation punctuation
# membre membre NOUN NOUN conj noun noun Gender=Masc|Number=Sing
# du de ADP ADP case adposition adposition Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# Gonville Gonville PROPN PROPN nmod proper noun proper noun
# and and X X dep other other
# Caius Caius PROPN PROPN flat:name proper noun proper noun Gender=Masc|Number=Sing
# College College PROPN PROPN flat:name proper noun proper noun
# et et CCONJ CCONJ cc coordinating conjunction coordinating conjunction
# chercheur chercheur NOUN NOUN conj noun noun Gender=Masc|Number=Sing
# distingué distingué ADJ ADJ amod adjective adjective Gender=Masc|Number=Sing
# du de ADP ADP case adposition adposition Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# Perimeter perimeter VERB VERB nmod verb verb VerbForm=Inf
# Institute Institute PROPN PROPN flat:name proper noun proper noun
# for for ADP ADP case adposition adposition
# Theoretical Theoretical PROPN PROPN nmod proper noun proper noun Gender=Masc|Number=Sing
# Physics Physics PROPN PROPN flat:name proper noun proper noun Gender=Masc|Number=Sing
# . . PUNCT PUNCT punct punctuation punctuation
# Il il PRON PRON nsubj:pass pronoun pronoun Gender=Masc|Number=Sing|Person=3
# est être AUX AUX aux:pass auxiliary auxiliary Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# connu connaître VERB VERB ROOT verb verb Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass
# pour pour ADP ADP case adposition adposition
# ses son DET DET det determiner determiner Number=Plur|Poss=Yes
# contributions contribution NOUN NOUN obl:mod noun noun Gender=Fem|Number=Plur
# dans dans ADP ADP case adposition adposition
# les le DET DET det determiner determiner Definite=Def|Number=Plur|PronType=Art
# domaines domaine NOUN NOUN nmod noun noun Gender=Masc|Number=Plur
# de de ADP ADP case adposition adposition
# la le DET DET det determiner determiner Definite=Def|Gender=Fem|Number=Sing|PronType=Art
# cosmologie cosmologie NOUN NOUN nmod noun noun Gender=Fem|Number=Sing
# et et CCONJ CCONJ cc coordinating conjunction coordinating conjunction
# la le DET DET det determiner determiner Definite=Def|Gender=Fem|Number=Sing|PronType=Art
# gravité gravité NOUN NOUN conj noun noun Gender=Fem|Number=Sing
# quantique quantique PRON PRON mark pronoun pronoun PronType=Rel
# , , PUNCT PUNCT punct punctuation punctuation
# en en ADP ADP advmod adposition adposition
# particulier particulier ADJ ADJ fixed adjective adjective Gender=Masc|Number=Sing
# dans dans ADP ADP case adposition adposition
# le le DET DET det determiner determiner Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# cadre cadre NOUN NOUN obl:mod noun noun Gender=Masc|Number=Sing
# des de ADP ADP case adposition adposition Definite=Def|Number=Plur|PronType=Art
# trous trou NOUN NOUN nmod noun noun Gender=Masc|Number=Plur
# noirs noir ADJ ADJ amod adjective adjective Gender=Masc|Number=Plur
# . . PUNCT PUNCT punct punctuation punctuation
# Son son DET DET det determiner determiner Number=Sing|Poss=Yes
# succès succès NOUN NOUN nsubj:pass noun noun Gender=Masc|Number=Sing
# est être AUX AUX aux:pass auxiliary auxiliary Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# également également ADV ADV advmod adverb adverb
# lié lier VERB VERB ROOT verb verb Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass
# à à ADP ADP case adposition adposition
# ses son DET DET det determiner determiner Number=Plur|Poss=Yes
# ouvrages ouvrage NOUN NOUN obl:arg noun noun Gender=Masc|Number=Plur
# de de ADP ADP case adposition adposition
# vulgarisation vulgarisation NOUN NOUN nmod noun noun Gender=Fem|Number=Sing
# scientifique scientifique ADJ ADJ amod adjective adjective Number=Sing
# dans dans ADP ADP case adposition adposition
# lesquels lequel PRON PRON obl:mod pronoun pronoun Gender=Masc|Number=Plur|PronType=Rel
# il il PRON PRON nsubj pronoun pronoun Gender=Masc|Number=Sing|Person=3
# discute discut ADJ ADJ acl:relcl adjective adjective Gender=Fem|Number=Sing
# de de ADP ADP case adposition adposition
# ses son DET DET det determiner determiner Number=Plur|Poss=Yes
# théories théorie NOUN NOUN obl:arg noun noun Gender=Fem|Number=Plur
# et et CCONJ CCONJ cc coordinating conjunction coordinating conjunction
# de de ADP ADP case adposition adposition
# la le DET DET det determiner determiner Definite=Def|Gender=Fem|Number=Sing|PronType=Art
# cosmologie cosmologie NOUN NOUN conj noun noun Gender=Fem|Number=Sing
# en en ADP ADP case adposition adposition
# général général NOUN NOUN nmod noun noun Gender=Masc|Number=Sing
# , , PUNCT PUNCT punct punctuation punctuation
# en en ADP ADP dep adposition adposition
# particulier particulier ADJ ADJ fixed adjective adjective Gender=Masc|Number=Sing
# Une un DET DET det determiner determiner Definite=Ind|Gender=Fem|Number=Sing|PronType=Art
# brève bref ADJ ADJ amod adjective adjective Gender=Fem|Number=Sing
# histoire histoire NOUN NOUN obj noun noun Gender=Fem|Number=Sing
# du de ADP ADP case adposition adposition Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# temps temps NOUN NOUN nmod noun noun Gender=Masc|Number=Sing
# . . PUNCT PUNCT punct punctuation punctuation
#
#
#
#
#  SPACE SPACE nsubj:pass space space NumType=Card
# La le DET DET det determiner determiner Definite=Def|Gender=Fem|Number=Sing|PronType=Art
# clé clé NOUN NOUN nsubj:pass noun noun Gender=Fem|Number=Sing
# des de ADP ADP case adposition adposition Definite=Def|Number=Plur|PronType=Art
# principaux principal ADJ ADJ amod adjective adjective Gender=Masc|Number=Plur
# travaux travail NOUN NOUN nmod noun noun Gender=Masc|Number=Plur
# scientifiques scientifique ADJ ADJ amod adjective adjective Number=Plur
# de de ADP ADP case adposition adposition
# Stephen Stephen PROPN PROPN nmod proper noun proper noun
# Hawking Hawking PROPN PROPN flat:name proper noun proper noun Gender=Masc|Number=Sing
# est être AUX AUX aux:pass auxiliary auxiliary Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# fondée fonder VERB VERB ROOT verb verb Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass
# , , PUNCT PUNCT punct punctuation punctuation
# en en ADP ADP case adposition adposition
# collaboration collaboration NOUN NOUN obl:mod noun noun Gender=Fem|Number=Sing
# avec avec ADP ADP case adposition adposition
# Roger Roger PROPN PROPN nmod proper noun proper noun Gender=Masc|Number=Sing
# Penrose Penrose PROPN PROPN flat:name proper noun proper noun
# , , PUNCT PUNCT punct punctuation punctuation
# sur sur ADP ADP case adposition adposition
# l' le DET DET det determiner determiner Definite=Def|Number=Sing|PronType=Art
# élaboration élaboration NOUN NOUN obl:mod noun noun Gender=Fem|Number=Sing
# des de ADP ADP case adposition adposition Definite=Def|Number=Plur|PronType=Art
# théorèmes théorème NOUN NOUN nmod noun noun Gender=Masc|Number=Plur
# sur sur ADP ADP case adposition adposition
# les le DET DET det determiner determiner Definite=Def|Number=Plur|PronType=Art
# singularités singularité NOUN NOUN nmod noun noun Gender=Fem|Number=Plur
# dans dans ADP ADP case adposition adposition
# le le DET DET det determiner determiner Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# cadre cadre NOUN NOUN obl:mod noun noun Gender=Masc|Number=Sing
# de de ADP ADP case adposition adposition
# la le DET DET det determiner determiner Definite=Def|Gender=Fem|Number=Sing|PronType=Art
# relativité relativité NOUN NOUN nmod noun noun Gender=Fem|Number=Sing
# générale général ADJ ADJ amod adjective adjective Gender=Fem|Number=Sing
# , , PUNCT PUNCT punct punctuation punctuation
# et et CCONJ CCONJ cc coordinating conjunction coordinating conjunction
# la le DET DET det determiner determiner Definite=Def|Gender=Fem|Number=Sing|PronType=Art
# prédiction prédiction NOUN NOUN nsubj noun noun Gender=Fem|Number=Sing
# théorique théorique VERB VERB advcl verb verb Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# que que SCONJ SCONJ mark subordinating conjunction subordinating conjunction
# les le DET DET det determiner determiner Definite=Def|Number=Plur|PronType=Art
# trous trou NOUN NOUN nsubj noun noun Gender=Masc|Number=Plur
# noirs noir ADJ ADJ amod adjective adjective Gender=Masc|Number=Plur
# devraient devoir VERB VERB ccomp verb verb Mood=Cnd|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin
# émettre émettre VERB VERB xcomp verb verb VerbForm=Inf
# ce ce PRON PRON obj pronoun pronoun
# qui qui PRON PRON nsubj:pass pronoun pronoun PronType=Rel
# est être AUX AUX aux:pass auxiliary auxiliary Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# aujourd'hui aujourd'hui ADV ADV advmod adverb adverb
# connu connaître VERB VERB acl:relcl verb verb Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass
# sous sous ADP ADP case adposition adposition
# le le DET DET det determiner determiner Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# nom nom NOUN NOUN obl:mod noun noun Gender=Masc|Number=Sing
# de de ADP ADP case adposition adposition
# rayonnement rayonnement NOUN NOUN nmod noun noun Gender=Masc|Number=Sing
# de de ADP ADP case adposition adposition
# Hawking Hawking PROPN PROPN nmod proper noun proper noun Gender=Masc|Number=Sing
# . . PUNCT PUNCT punct punctuation punctuation

# %%
for token in docEN:
        print(token, token.lemma_, token.pos_, token.tag_, token.dep_, spacy.explain(token.pos_), spacy.explain(token.tag_), token.morph)
# Out:
# Stephen Stephen PROPN NNP compound proper noun noun, proper singular NounType=Prop|Number=Sing
# William William PROPN NNP compound proper noun noun, proper singular NounType=Prop|Number=Sing
# Hawking Hawking PROPN NNP compound proper noun noun, proper singular NounType=Prop|Number=Sing
# CH CH PROPN NNP compound proper noun noun, proper singular NounType=Prop|Number=Sing
# CBE CBE PROPN NNP compound proper noun noun, proper singular NounType=Prop|Number=Sing
# FRS FRS PROPN NNP compound proper noun noun, proper singular NounType=Prop|Number=Sing
# FRSA FRSA PROPN NNP nsubj proper noun noun, proper singular NounType=Prop|Number=Sing
# ( ( PUNCT -LRB- punct punctuation left round bracket PunctSide=Ini|PunctType=Brck
# 8 8 NUM CD appos numeral cardinal number NumType=Card
# January January PROPN NNP npadvmod proper noun noun, proper singular NounType=Prop|Number=Sing
# 1942 1942 NUM CD nummod numeral cardinal number NumType=Card
# – – PUNCT : punct punctuation punctuation mark, colon or ellipsis
# 14 14 NUM CD nummod numeral cardinal number NumType=Card
# March March PROPN NNP appos proper noun noun, proper singular NounType=Prop|Number=Sing
# 2018 2018 NUM CD nummod numeral cardinal number NumType=Card
# ) ) PUNCT -RRB- punct punctuation right round bracket PunctSide=Fin|PunctType=Brck
# was be AUX VBD ROOT auxiliary verb, past tense Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# an an DET DT det determiner determiner Definite=Ind|PronType=Art
# English english ADJ JJ amod adjective adjective Degree=Pos
# theoretical theoretical ADJ JJ amod adjective adjective Degree=Pos
# physicist physicist NOUN NN attr noun noun, singular or mass Number=Sing
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# cosmologist cosmologist NOUN NN conj noun noun, singular or mass Number=Sing
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# and and CCONJ CC cc coordinating conjunction conjunction, coordinating ConjType=Cmp
# author author NOUN NN conj noun noun, singular or mass Number=Sing
# who who PRON WP nsubj pronoun wh-pronoun, personal
# was be VERB VBD relcl verb verb, past tense Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# director director NOUN NN attr noun noun, singular or mass Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# research research NOUN NN pobj noun noun, singular or mass Number=Sing
# at at ADP IN prep adposition conjunction, subordinating or preposition
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# Centre Centre PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# for for ADP IN prep adposition conjunction, subordinating or preposition
# Theoretical Theoretical PROPN NNP compound proper noun noun, proper singular NounType=Prop|Number=Sing
# Cosmology Cosmology PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# at at ADP IN prep adposition conjunction, subordinating or preposition
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# University University PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# Cambridge Cambridge PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# at at ADP IN prep adposition conjunction, subordinating or preposition
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# time time NOUN NN pobj noun noun, singular or mass Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# his his PRON PRP$ poss pronoun pronoun, possessive Gender=Masc|Number=Sing|Person=3|Poss=Yes|PronType=Prs
# death death NOUN NN pobj noun noun, singular or mass Number=Sing
# . . PUNCT . punct punctuation punctuation mark, sentence closer PunctType=Peri
# He he PRON PRP nsubj pronoun pronoun, personal Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# was be AUX VBD ROOT auxiliary verb, past tense Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# Lucasian lucasian ADJ JJ amod adjective adjective Degree=Pos
# Professor Professor PROPN NNP attr proper noun noun, proper singular NounType=Prop|Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# Mathematics Mathematics PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# at at ADP IN prep adposition conjunction, subordinating or preposition
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# University University PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# Cambridge Cambridge PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# between between ADP IN prep adposition conjunction, subordinating or preposition
# 1979 1979 NUM CD pobj numeral cardinal number NumType=Card
# and and CCONJ CC cc coordinating conjunction conjunction, coordinating ConjType=Cmp
# 2009 2009 NUM CD conj numeral cardinal number NumType=Card
# . . PUNCT . punct punctuation punctuation mark, sentence closer PunctType=Peri
#
#
#
#
#  SPACE _SP dep space None
# Hawking hawk VERB VBG nsubjpass verb verb, gerund or present participle Aspect=Prog|Tense=Pres|VerbForm=Part
# was be AUX VBD auxpass auxiliary verb, past tense Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# born bear VERB VBN ROOT verb verb, past participle Aspect=Perf|Tense=Past|VerbForm=Part
# in in ADP IN prep adposition conjunction, subordinating or preposition
# Oxford Oxford PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# into into ADP IN prep adposition conjunction, subordinating or preposition
# a a DET DT det determiner determiner Definite=Ind|PronType=Art
# family family NOUN NN pobj noun noun, singular or mass Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# doctors doctor NOUN NNS pobj noun noun, plural Number=Plur
# . . PUNCT . punct punctuation punctuation mark, sentence closer PunctType=Peri
# He he PRON PRP nsubj pronoun pronoun, personal Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# began begin VERB VBD ROOT verb verb, past tense Tense=Past|VerbForm=Fin
# his his PRON PRP$ poss pronoun pronoun, possessive Gender=Masc|Number=Sing|Person=3|Poss=Yes|PronType=Prs
# university university NOUN NN compound noun noun, singular or mass Number=Sing
# education education NOUN NN dobj noun noun, singular or mass Number=Sing
# at at ADP IN prep adposition conjunction, subordinating or preposition
# University University PROPN NNP compound proper noun noun, proper singular NounType=Prop|Number=Sing
# College College PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# Oxford Oxford PROPN NNP appos proper noun noun, proper singular NounType=Prop|Number=Sing
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# in in ADP IN prep adposition conjunction, subordinating or preposition
# October October PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# 1959 1959 NUM CD nummod numeral cardinal number NumType=Card
# at at ADP IN prep adposition conjunction, subordinating or preposition
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# age age NOUN NN pobj noun noun, singular or mass Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# 17 17 NUM CD pobj numeral cardinal number NumType=Card
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# where where ADV WRB advmod adverb wh-adverb
# he he PRON PRP nsubj pronoun pronoun, personal Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# received receive VERB VBD relcl verb verb, past tense Tense=Past|VerbForm=Fin
# a a DET DT det determiner determiner Definite=Ind|PronType=Art
# first first ADJ JJ amod adjective adjective Degree=Pos
# - - PUNCT HYPH punct punctuation punctuation mark, hyphen PunctType=Dash
# class class NOUN NN compound noun noun, singular or mass Number=Sing
# BA BA PROPN NNP nmod proper noun noun, proper singular NounType=Prop|Number=Sing
# ( ( PUNCT -LRB- punct punctuation left round bracket PunctSide=Ini|PunctType=Brck
# Hons Hons PROPN NNP appos proper noun noun, proper singular NounType=Prop|Number=Sing
# . . PUNCT . punct punctuation punctuation mark, sentence closer PunctType=Peri
# ) ) PUNCT -RRB- punct punctuation right round bracket PunctSide=Fin|PunctType=Brck
# degree degree NOUN NN dobj noun noun, singular or mass Number=Sing
# in in ADP IN prep adposition conjunction, subordinating or preposition
# physics physics NOUN NN pobj noun noun, singular or mass Number=Sing
# . . PUNCT . punct punctuation punctuation mark, sentence closer PunctType=Peri
# He he PRON PRP nsubj pronoun pronoun, personal Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# began begin VERB VBD ROOT verb verb, past tense Tense=Past|VerbForm=Fin
# his his PRON PRP$ poss pronoun pronoun, possessive Gender=Masc|Number=Sing|Person=3|Poss=Yes|PronType=Prs
# graduate graduate ADJ JJ compound adjective adjective Degree=Pos
# work work NOUN NN dobj noun noun, singular or mass Number=Sing
# at at ADP IN prep adposition conjunction, subordinating or preposition
# Trinity Trinity PROPN NNP compound proper noun noun, proper singular NounType=Prop|Number=Sing
# Hall Hall PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# Cambridge Cambridge PROPN NNP npadvmod proper noun noun, proper singular NounType=Prop|Number=Sing
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# in in ADP IN prep adposition conjunction, subordinating or preposition
# October October PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# 1962 1962 NUM CD nummod numeral cardinal number NumType=Card
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# where where ADV WRB advmod adverb wh-adverb
# he he PRON PRP nsubj pronoun pronoun, personal Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# obtained obtain VERB VBD relcl verb verb, past tense Tense=Past|VerbForm=Fin
# his his PRON PRP$ poss pronoun pronoun, possessive Gender=Masc|Number=Sing|Person=3|Poss=Yes|PronType=Prs
# PhD phd NOUN NN compound noun noun, singular or mass Number=Sing
# degree degree NOUN NN dobj noun noun, singular or mass Number=Sing
# in in ADP IN prep adposition conjunction, subordinating or preposition
# applied apply VERB VBN amod verb verb, past participle Aspect=Perf|Tense=Past|VerbForm=Part
# mathematics mathematic NOUN NNS pobj noun noun, plural Number=Plur
# and and CCONJ CC cc coordinating conjunction conjunction, coordinating ConjType=Cmp
# theoretical theoretical ADJ JJ amod adjective adjective Degree=Pos
# physics physics NOUN NN conj noun noun, singular or mass Number=Sing
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# specialising specialise VERB VBG advcl verb verb, gerund or present participle Aspect=Prog|Tense=Pres|VerbForm=Part
# in in ADP IN prep adposition conjunction, subordinating or preposition
# general general ADJ JJ amod adjective adjective Degree=Pos
# relativity relativity NOUN NN pobj noun noun, singular or mass Number=Sing
# and and CCONJ CC cc coordinating conjunction conjunction, coordinating ConjType=Cmp
# cosmology cosmology NOUN NN conj noun noun, singular or mass Number=Sing
# in in ADP IN prep adposition conjunction, subordinating or preposition
# March March PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# 1966 1966 NUM CD nummod numeral cardinal number NumType=Card
# . . PUNCT . punct punctuation punctuation mark, sentence closer PunctType=Peri
# In in ADP IN prep adposition conjunction, subordinating or preposition
# 1963 1963 NUM CD pobj numeral cardinal number NumType=Card
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# Hawking hawk VERB VBG nsubjpass verb verb, gerund or present participle Aspect=Prog|Tense=Pres|VerbForm=Part
# was be AUX VBD auxpass auxiliary verb, past tense Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# diagnosed diagnose VERB VBN ROOT verb verb, past participle Aspect=Perf|Tense=Past|VerbForm=Part
# with with ADP IN prep adposition conjunction, subordinating or preposition
# an an DET DT det determiner determiner Definite=Ind|PronType=Art
# early early ADJ JJ amod adjective adjective Degree=Pos
# - - PUNCT HYPH punct punctuation punctuation mark, hyphen PunctType=Dash
# onset onset NOUN NN amod noun noun, singular or mass Number=Sing
# slow slow ADV RB advmod adverb adverb
# - - PUNCT HYPH punct punctuation punctuation mark, hyphen PunctType=Dash
# progressing progress VERB VBG amod verb verb, gerund or present participle Aspect=Prog|Tense=Pres|VerbForm=Part
# form form NOUN NN pobj noun noun, singular or mass Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# motor motor NOUN NN compound noun noun, singular or mass Number=Sing
# neurone neurone NOUN NN compound noun noun, singular or mass Number=Sing
# disease disease NOUN NN pobj noun noun, singular or mass Number=Sing
# that that DET WDT nsubj determiner wh-determiner
# gradually gradually ADV RB advmod adverb adverb
# paralysed paralyse VERB VBD relcl verb verb, past tense Tense=Past|VerbForm=Fin
# him he PRON PRP dobj pronoun pronoun, personal Case=Acc|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# over over ADP IN prep adposition conjunction, subordinating or preposition
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# decades decade NOUN NNS pobj noun noun, plural Number=Plur
# . . PUNCT . punct punctuation punctuation mark, sentence closer PunctType=Peri
# After after ADP IN prep adposition conjunction, subordinating or preposition
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# loss loss NOUN NN pobj noun noun, singular or mass Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# his his PRON PRP$ poss pronoun pronoun, possessive Gender=Masc|Number=Sing|Person=3|Poss=Yes|PronType=Prs
# speech speech NOUN NN pobj noun noun, singular or mass Number=Sing
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# he he PRON PRP nsubj pronoun pronoun, personal Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# communicated communicate VERB VBD ROOT verb verb, past tense Tense=Past|VerbForm=Fin
# through through ADP IN prep adposition conjunction, subordinating or preposition
# a a DET DT det determiner determiner Definite=Ind|PronType=Art
# speech speech NOUN NN npadvmod noun noun, singular or mass Number=Sing
# - - PUNCT HYPH punct punctuation punctuation mark, hyphen PunctType=Dash
# generating generate VERB VBG amod verb verb, gerund or present participle Aspect=Prog|Tense=Pres|VerbForm=Part
# device device NOUN NN pobj noun noun, singular or mass Number=Sing
# initially initially ADV RB advmod adverb adverb
# through through ADP IN prep adposition conjunction, subordinating or preposition
# use use NOUN NN pobj noun noun, singular or mass Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# a a DET DT det determiner determiner Definite=Ind|PronType=Art
# handheld handheld ADJ JJ amod adjective adjective Degree=Pos
# switch switch NOUN NN pobj noun noun, singular or mass Number=Sing
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# and and CCONJ CC cc coordinating conjunction conjunction, coordinating ConjType=Cmp
# eventually eventually ADV RB advmod adverb adverb
# by by ADP IN prep adposition conjunction, subordinating or preposition
# using use VERB VBG pcomp verb verb, gerund or present participle Aspect=Prog|Tense=Pres|VerbForm=Part
# a a DET DT det determiner determiner Definite=Ind|PronType=Art
# single single ADJ JJ amod adjective adjective Degree=Pos
# cheek cheek NOUN NN compound noun noun, singular or mass Number=Sing
# muscle muscle NOUN NN dobj noun noun, singular or mass Number=Sing
# . . PUNCT . punct punctuation punctuation mark, sentence closer PunctType=Peri
#
#
#
#
#  SPACE _SP prep space None
# Hawking Hawking PROPN NNP poss proper noun noun, proper singular NounType=Prop|Number=Sing
# 's 's PART POS case particle possessive ending
# scientific scientific ADJ JJ amod adjective adjective Degree=Pos
# works work NOUN NNS nsubj noun noun, plural Number=Plur
# included include VERB VBD ROOT verb verb, past tense Tense=Past|VerbForm=Fin
# a a DET DT det determiner determiner Definite=Ind|PronType=Art
# collaboration collaboration NOUN NN dobj noun noun, singular or mass Number=Sing
# with with ADP IN prep adposition conjunction, subordinating or preposition
# Roger Roger PROPN NNP compound proper noun noun, proper singular NounType=Prop|Number=Sing
# Penrose Penrose PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# on on ADP IN prep adposition conjunction, subordinating or preposition
# gravitational gravitational ADJ JJ amod adjective adjective Degree=Pos
# singularity singularity NOUN NN compound noun noun, singular or mass Number=Sing
# theorems theorem NOUN NNS pobj noun noun, plural Number=Plur
# in in ADP IN prep adposition conjunction, subordinating or preposition
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# framework framework NOUN NN pobj noun noun, singular or mass Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# general general ADJ JJ amod adjective adjective Degree=Pos
# relativity relativity NOUN NN pobj noun noun, singular or mass Number=Sing
# and and CCONJ CC cc coordinating conjunction conjunction, coordinating ConjType=Cmp
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# theoretical theoretical ADJ JJ amod adjective adjective Degree=Pos
# prediction prediction NOUN NN conj noun noun, singular or mass Number=Sing
# that that SCONJ IN mark subordinating conjunction conjunction, subordinating or preposition
# black black ADJ JJ amod adjective adjective Degree=Pos
# holes hole NOUN NNS nsubj noun noun, plural Number=Plur
# emit emit VERB VBP relcl verb verb, non-3rd person singular present Tense=Pres|VerbForm=Fin
# radiation radiation NOUN NN dobj noun noun, singular or mass Number=Sing
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# often often ADV RB advmod adverb adverb
# called call VERB VBD acl verb verb, past tense Tense=Past|VerbForm=Fin
# Hawking hawk VERB VBG xcomp verb verb, gerund or present participle Aspect=Prog|Tense=Pres|VerbForm=Part
# radiation radiation NOUN NN dobj noun noun, singular or mass Number=Sing
# . . PUNCT . punct punctuation punctuation mark, sentence closer PunctType=Peri
# Initially initially ADV RB advmod adverb adverb
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# Hawking hawk VERB VBG csubj verb verb, gerund or present participle Aspect=Prog|Tense=Pres|VerbForm=Part
# radiation radiation NOUN NN dobj noun noun, singular or mass Number=Sing
# was be AUX VBD ROOT auxiliary verb, past tense Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# controversial controversial ADJ JJ acomp adjective adjective Degree=Pos
# . . PUNCT . punct punctuation punctuation mark, sentence closer PunctType=Peri
# By by ADP IN prep adposition conjunction, subordinating or preposition
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# late late ADJ JJ amod adjective adjective Degree=Pos
# 1970s 1970 NOUN NNS pobj noun noun, plural Number=Plur
# and and CCONJ CC cc coordinating conjunction conjunction, coordinating ConjType=Cmp
# following follow VERB VBG conj verb verb, gerund or present participle Aspect=Prog|Tense=Pres|VerbForm=Part
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# publication publication NOUN NN dobj noun noun, singular or mass Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# further further ADJ JJ amod adjective adjective Degree=Pos
# research research NOUN NN pobj noun noun, singular or mass Number=Sing
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# discovery discovery NOUN NN nsubjpass noun noun, singular or mass Number=Sing
# was be AUX VBD auxpass auxiliary verb, past tense Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# widely widely ADV RB advmod adverb adverb
# accepted accept VERB VBN ROOT verb verb, past participle Aspect=Perf|Tense=Past|VerbForm=Part
# as as ADP IN prep adposition conjunction, subordinating or preposition
# a a DET DT det determiner determiner Definite=Ind|PronType=Art
# significant significant ADJ JJ amod adjective adjective Degree=Pos
# breakthrough breakthrough NOUN NN pobj noun noun, singular or mass Number=Sing
# in in ADP IN prep adposition conjunction, subordinating or preposition
# theoretical theoretical ADJ JJ amod adjective adjective Degree=Pos
# physics physics NOUN NN pobj noun noun, singular or mass Number=Sing
# . . PUNCT . punct punctuation punctuation mark, sentence closer PunctType=Peri
# Hawking hawk VERB VBG nsubj verb verb, gerund or present participle Aspect=Prog|Tense=Pres|VerbForm=Part
# was be AUX VBD ROOT auxiliary verb, past tense Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# first first ADJ JJ attr adjective adjective Degree=Pos
# to to PART TO aux particle infinitival "to"
# set set VERB VB relcl verb verb, base form VerbForm=Inf
# out out ADP RP prt adposition adverb, particle
# a a DET DT det determiner determiner Definite=Ind|PronType=Art
# theory theory NOUN NN dobj noun noun, singular or mass Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# cosmology cosmology NOUN NN pobj noun noun, singular or mass Number=Sing
# explained explain VERB VBN acl verb verb, past participle Aspect=Perf|Tense=Past|VerbForm=Part
# by by ADP IN agent adposition conjunction, subordinating or preposition
# a a DET DT det determiner determiner Definite=Ind|PronType=Art
# union union NOUN NN pobj noun noun, singular or mass Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# general general ADJ JJ amod adjective adjective Degree=Pos
# theory theory NOUN NN pobj noun noun, singular or mass Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# relativity relativity NOUN NN pobj noun noun, singular or mass Number=Sing
# and and CCONJ CC cc coordinating conjunction conjunction, coordinating ConjType=Cmp
# quantum quantum NOUN NN compound noun noun, singular or mass Number=Sing
# mechanics mechanic NOUN NNS conj noun noun, plural Number=Plur
# . . PUNCT . punct punctuation punctuation mark, sentence closer PunctType=Peri
# He he PRON PRP nsubj pronoun pronoun, personal Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# was be AUX VBD ROOT auxiliary verb, past tense Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# a a DET DT det determiner determiner Definite=Ind|PronType=Art
# vigorous vigorous ADJ JJ amod adjective adjective Degree=Pos
# supporter supporter NOUN NN attr noun noun, singular or mass Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# many many ADJ JJ amod adjective adjective Degree=Pos
# - - PUNCT HYPH punct punctuation punctuation mark, hyphen PunctType=Dash
# worlds world NOUN NNS compound noun noun, plural Number=Plur
# interpretation interpretation NOUN NN pobj noun noun, singular or mass Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# quantum quantum NOUN NN compound noun noun, singular or mass Number=Sing
# mechanics mechanic NOUN NNS pobj noun noun, plural Number=Plur
# . . PUNCT . punct punctuation punctuation mark, sentence closer PunctType=Peri
#
#
#
#
#  SPACE _SP dep space None Number=Plur
# Hawking hawk VERB VBG nsubj verb verb, gerund or present participle Aspect=Prog|Tense=Pres|VerbForm=Part
# achieved achieve VERB VBD ROOT verb verb, past tense Tense=Past|VerbForm=Fin
# commercial commercial ADJ JJ amod adjective adjective Degree=Pos
# success success NOUN NN dobj noun noun, singular or mass Number=Sing
# with with ADP IN prep adposition conjunction, subordinating or preposition
# several several ADJ JJ amod adjective adjective Degree=Pos
# works work NOUN NNS pobj noun noun, plural Number=Plur
# of of ADP IN prep adposition conjunction, subordinating or preposition
# popular popular ADJ JJ amod adjective adjective Degree=Pos
# science science NOUN NN pobj noun noun, singular or mass Number=Sing
# in in ADP IN prep adposition conjunction, subordinating or preposition
# which which DET WDT pobj determiner wh-determiner
# he he PRON PRP nsubj pronoun pronoun, personal Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# discussed discuss VERB VBD relcl verb verb, past tense Tense=Past|VerbForm=Fin
# his his PRON PRP$ poss pronoun pronoun, possessive Gender=Masc|Number=Sing|Person=3|Poss=Yes|PronType=Prs
# theories theory NOUN NNS dobj noun noun, plural Number=Plur
# and and CCONJ CC cc coordinating conjunction conjunction, coordinating ConjType=Cmp
# cosmology cosmology NOUN NN conj noun noun, singular or mass Number=Sing
# in in ADP IN prep adposition conjunction, subordinating or preposition
# general general ADJ JJ amod adjective adjective Degree=Pos
# . . PUNCT . punct punctuation punctuation mark, sentence closer PunctType=Peri
# His his PRON PRP$ poss pronoun pronoun, possessive Gender=Masc|Number=Sing|Person=3|Poss=Yes|PronType=Prs
# book book NOUN NN nsubj noun noun, singular or mass Number=Sing
# A a DET DT det determiner determiner Definite=Ind|PronType=Art
# Brief brief ADJ JJ amod adjective adjective Degree=Pos
# History history NOUN NN appos noun noun, singular or mass Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# Time Time PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# appeared appear VERB VBD ROOT verb verb, past tense Tense=Past|VerbForm=Fin
# on on ADP IN prep adposition conjunction, subordinating or preposition
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# Sunday Sunday PROPN NNP compound proper noun noun, proper singular NounType=Prop|Number=Sing
# Times Times PROPN NNP compound proper noun noun, proper singular NounType=Prop|Number=Sing
# bestseller bestseller NOUN NN compound noun noun, singular or mass Number=Sing
# list list NOUN NN pobj noun noun, singular or mass Number=Sing
# for for ADP IN prep adposition conjunction, subordinating or preposition
# a a DET DT det determiner determiner Definite=Ind|PronType=Art
# record record NOUN NN npadvmod noun noun, singular or mass Number=Sing
# - - PUNCT HYPH punct punctuation punctuation mark, hyphen PunctType=Dash
# breaking break VERB VBG amod verb verb, gerund or present participle Aspect=Prog|Tense=Pres|VerbForm=Part
# 237 237 NUM CD nummod numeral cardinal number NumType=Card
# weeks week NOUN NNS pobj noun noun, plural Number=Plur
# . . PUNCT . punct punctuation punctuation mark, sentence closer PunctType=Peri
# Hawking hawk VERB VBG nsubj verb verb, gerund or present participle Aspect=Prog|Tense=Pres|VerbForm=Part
# was be AUX VBD ROOT auxiliary verb, past tense Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# a a DET DT det determiner determiner Definite=Ind|PronType=Art
# Fellow Fellow PROPN NNP attr proper noun noun, proper singular NounType=Prop|Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# Royal Royal PROPN NNP compound proper noun noun, proper singular NounType=Prop|Number=Sing
# Society Society PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# a a DET DT det determiner determiner Definite=Ind|PronType=Art
# lifetime lifetime NOUN NN compound noun noun, singular or mass Number=Sing
# member member NOUN NN appos noun noun, singular or mass Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# Pontifical Pontifical PROPN NNP compound proper noun noun, proper singular NounType=Prop|Number=Sing
# Academy Academy PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# Sciences Sciences PROPN NNPS pobj proper noun noun, proper plural NounType=Prop|Number=Plur
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# and and CCONJ CC cc coordinating conjunction conjunction, coordinating ConjType=Cmp
# a a DET DT det determiner determiner Definite=Ind|PronType=Art
# recipient recipient NOUN NN conj noun noun, singular or mass Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# Presidential Presidential PROPN NNP compound proper noun noun, proper singular NounType=Prop|Number=Sing
# Medal Medal PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# Freedom Freedom PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# highest high ADJ JJS amod adjective adjective, superlative Degree=Sup
# civilian civilian ADJ JJ amod adjective adjective Degree=Pos
# award award NOUN NN appos noun noun, singular or mass Number=Sing
# in in ADP IN prep adposition conjunction, subordinating or preposition
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# United United PROPN NNP compound proper noun noun, proper singular NounType=Prop|Number=Sing
# States States PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# . . PUNCT . punct punctuation punctuation mark, sentence closer PunctType=Peri
# In in ADP IN prep adposition conjunction, subordinating or preposition
# 2002 2002 NUM CD pobj numeral cardinal number NumType=Card
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# Hawking Hawking PROPN NNP nsubjpass proper noun noun, proper singular NounType=Prop|Number=Sing
# was be AUX VBD auxpass auxiliary verb, past tense Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# ranked rank VERB VBN ROOT verb verb, past participle Aspect=Perf|Tense=Past|VerbForm=Part
# number number NOUN NN oprd noun noun, singular or mass Number=Sing
# 25 25 NUM CD nummod numeral cardinal number NumType=Card
# in in ADP IN prep adposition conjunction, subordinating or preposition
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# BBC BBC PROPN NNP poss proper noun noun, proper singular NounType=Prop|Number=Sing
# 's 's PART POS case particle possessive ending
# poll poll NOUN NN pobj noun noun, singular or mass Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# 100 100 NUM CD nummod numeral cardinal number NumType=Card
# Greatest Greatest PROPN NNP compound proper noun noun, proper singular NounType=Prop|Number=Sing
# Britons Britons PROPN NNPS pobj proper noun noun, proper plural NounType=Prop|Number=Plur
# . . PUNCT . punct punctuation punctuation mark, sentence closer PunctType=Peri
# He he PRON PRP nsubj pronoun pronoun, personal Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# died die VERB VBD ROOT verb verb, past tense Tense=Past|VerbForm=Fin
# on on ADP IN prep adposition conjunction, subordinating or preposition
# 14 14 NUM CD nummod numeral cardinal number NumType=Card
# March March PROPN NNP pobj proper noun noun, proper singular NounType=Prop|Number=Sing
# 2018 2018 NUM CD nummod numeral cardinal number NumType=Card
# at at ADP IN prep adposition conjunction, subordinating or preposition
# the the DET DT det determiner determiner Definite=Def|PronType=Art
# age age NOUN NN pobj noun noun, singular or mass Number=Sing
# of of ADP IN prep adposition conjunction, subordinating or preposition
# 76 76 NUM CD pobj numeral cardinal number NumType=Card
# , , PUNCT , punct punctuation punctuation mark, comma PunctType=Comm
# after after ADP IN prep adposition conjunction, subordinating or preposition
# living live VERB VBG pcomp verb verb, gerund or present participle Aspect=Prog|Tense=Pres|VerbForm=Part
# with with ADP IN prep adposition conjunction, subordinating or preposition
# motor motor NOUN NN compound noun noun, singular or mass Number=Sing
# neurone neurone NOUN NN compound noun noun, singular or mass Number=Sing
# disease disease NOUN NN pobj noun noun, singular or mass Number=Sing
# for for ADP IN prep adposition conjunction, subordinating or preposition
# more more ADJ JJR amod adjective adjective, comparative Degree=Cmp
# than than SCONJ IN quantmod subordinating conjunction conjunction, subordinating or preposition
# 50 50 NUM CD nummod numeral cardinal number NumType=Card
# years year NOUN NNS pobj noun noun, plural Number=Plur
# . . PUNCT . punct punctuation punctuation mark, sentence closer PunctType=Peri

# %%
for token in docRU:
        print(token, token.lemma_, token.pos_, token.tag_, token.dep_, spacy.explain(token.pos_), spacy.explain(token.tag_), token.morph)


# Хо́кинг хо́кинг X X appos other other Foreign=Yes (Hawking) 
# протяжении протяжение NOUN NOUN obl noun noun Animacy=Inan|Case=Loc|Gender=Neut|Number=Sing
# Out:
# Сти́вен Сти́вен PUNCT PUNCT punct punctuation punctuation
# Уи́льям уи́льям PROPN PROPN ROOT proper noun proper noun Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# Хо́кинг хо́кинг X X appos other other Foreign=Yes
# ( ( PUNCT PUNCT punct punctuation punctuation
# англ англ ADJ ADJ amod adjective adjective Case=Nom|Degree=Pos|Gender=Neut|Number=Sing
# . . PUNCT PUNCT punct punctuation punctuation
# Stephen stephen X X appos other other Foreign=Yes
# William william X X flat:foreign other other Foreign=Yes
# Hawking hawking X X flat:foreign other other Foreign=Yes
# ; ; PUNCT PUNCT punct punctuation punctuation
# 8 8 ADJ ADJ nmod adjective adjective
# января январь NOUN NOUN flat noun noun Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# 1942 1942 ADJ ADJ flat adjective adjective
# , , PUNCT PUNCT punct punctuation punctuation
# Оксфорд оксфорд PROPN PROPN nsubj proper noun proper noun Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# , , PUNCT PUNCT punct punctuation punctuation
# Великобритания великобритания PROPN PROPN conj proper noun proper noun Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing
# — — PUNCT PUNCT punct punctuation punctuation
# 14 14 ADJ ADJ orphan adjective adjective
# марта март NOUN NOUN flat noun noun Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# 2018 2018 ADJ ADJ flat adjective adjective
# , , PUNCT PUNCT punct punctuation punctuation
# Кембридж кембридж PROPN PROPN conj proper noun proper noun Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# , , PUNCT PUNCT punct punctuation punctuation
# Великобритания великобритания PROPN PROPN conj proper noun proper noun Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing
# ) ) PUNCT PUNCT punct punctuation punctuation
# — — PUNCT PUNCT punct punctuation punctuation
# английский английский ADJ ADJ amod adjective adjective Case=Nom|Degree=Pos|Gender=Masc|Number=Sing
# физик физик NOUN NOUN ROOT noun noun Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# - - NOUN NOUN conj noun noun Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# теоретик теоретик NOUN NOUN conj noun noun Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# , , PUNCT PUNCT punct punctuation punctuation
# космолог космолог NOUN NOUN conj noun noun Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# и и CCONJ CCONJ cc coordinating conjunction coordinating conjunction
# астрофизик астрофизик NOUN NOUN conj noun noun Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# , , PUNCT PUNCT punct punctuation punctuation
# писатель писатель NOUN NOUN conj noun noun Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# , , PUNCT PUNCT punct punctuation punctuation
# директор директор NOUN NOUN conj noun noun Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# по по ADP ADP case adposition adposition
# научной научный ADJ ADJ amod adjective adjective Case=Dat|Degree=Pos|Gender=Fem|Number=Sing
# работе работа NOUN NOUN nmod noun noun Animacy=Inan|Case=Dat|Gender=Fem|Number=Sing
# Центра центр PROPN PROPN nmod proper noun proper noun Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# теоретической теоретический ADJ ADJ amod adjective adjective Case=Gen|Degree=Pos|Gender=Fem|Number=Sing
# космологии космология NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# Кембриджского кембриджский ADJ ADJ amod adjective adjective Case=Gen|Degree=Pos|Gender=Masc|Number=Sing
# университета университет NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# . . PUNCT PUNCT punct punctuation punctuation
# Автор автор NOUN NOUN ROOT noun noun Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# ряда ряд NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# научных научный ADJ ADJ amod adjective adjective Case=Gen|Degree=Pos|Number=Plur
# трудов труд NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur
# , , PUNCT PUNCT punct punctuation punctuation
# в в ADP ADP case adposition adposition
# том тот DET DET det determiner determiner Case=Loc|Gender=Neut|Number=Sing
# числе число NOUN NOUN nmod noun noun Animacy=Inan|Case=Loc|Gender=Neut|Number=Sing
# совместной совместный ADJ ADJ amod adjective adjective Case=Gen|Degree=Pos|Gender=Fem|Number=Sing
# с с ADP ADP case adposition adposition
# Роджером роджер PROPN PROPN obl proper noun proper noun Animacy=Anim|Case=Ins|Gender=Masc|Number=Sing
# Пенроузом пенроузом PROPN PROPN flat:name proper noun proper noun Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing
# работы работа NOUN NOUN appos noun noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# по по ADP ADP case adposition adposition
# теоремам теоремам NOUN NOUN nmod noun noun Animacy=Inan|Case=Dat|Gender=Masc|Number=Plur
# о о ADP ADP case adposition adposition
# гравитационной гравитационный ADJ ADJ amod adjective adjective Case=Loc|Degree=Pos|Gender=Fem|Number=Sing
# сингулярности сингулярность NOUN NOUN nmod noun noun Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing
# в в ADP ADP case adposition adposition
# рамках рамка NOUN NOUN nmod noun noun Animacy=Inan|Case=Loc|Gender=Fem|Number=Plur
# общей общий ADJ ADJ amod adjective adjective Case=Gen|Degree=Pos|Gender=Fem|Number=Sing
# теории теория NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# относительности относительность NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# и и CCONJ CCONJ cc coordinating conjunction coordinating conjunction
# теоретическому теоретический ADJ ADJ amod adjective adjective Case=Dat|Degree=Pos|Gender=Neut|Number=Sing
# предсказанию предсказание NOUN NOUN conj noun noun Animacy=Inan|Case=Dat|Gender=Neut|Number=Sing
# выделения выделение NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing
# чёрными чёрный ADJ ADJ amod adjective adjective Case=Ins|Degree=Pos|Number=Plur
# дырами дыра NOUN NOUN nmod noun noun Animacy=Inan|Case=Ins|Gender=Fem|Number=Plur
# излучения излучение NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing
# , , PUNCT PUNCT punct punctuation punctuation
# часто часто ADV ADV advmod adverb adverb Degree=Pos
# именуемого именуемого VERB VERB acl verb verb Aspect=Perf|Case=Gen|Gender=Neut|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass
# излучением излучение NOUN NOUN obl:agent noun noun Animacy=Inan|Case=Ins|Gender=Neut|Number=Sing
# Хокинга хокинг PROPN PROPN nmod proper noun proper noun Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing
# . . PUNCT PUNCT punct punctuation punctuation
# Хокинг хокинг PROPN PROPN nsubj proper noun proper noun Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# первым первый ADJ ADJ obl adjective adjective Case=Ins|Degree=Pos|Gender=Masc|Number=Sing
# изложил изложить VERB VERB ROOT verb verb Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# космологическую космологический ADJ ADJ amod adjective adjective Case=Acc|Degree=Pos|Gender=Fem|Number=Sing
# теорию теория NOUN NOUN obj noun noun Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing
# , , PUNCT PUNCT punct punctuation punctuation
# в в ADP ADP case adposition adposition
# которой которой PRON PRON obl pronoun pronoun Case=Loc|Gender=Fem|Number=Sing
# были были AUX AUX aux:pass auxiliary auxiliary Aspect=Imp|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act
# объединены объединить VERB VERB acl:relcl verb verb Aspect=Perf|Number=Plur|StyleVariant=Short|Tense=Past|VerbForm=Part|Voice=Pass
# представления представление NOUN NOUN nsubj:pass noun noun Animacy=Inan|Case=Nom|Gender=Neut|Number=Plur
# общей общий ADJ ADJ amod adjective adjective Case=Gen|Degree=Pos|Gender=Fem|Number=Sing
# теории теория NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# относительности относительность NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# и и CCONJ CCONJ cc coordinating conjunction coordinating conjunction
# квантовой квантовый ADJ ADJ amod adjective adjective Case=Gen|Degree=Pos|Gender=Fem|Number=Sing
# механики механика NOUN NOUN conj noun noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# . . PUNCT PUNCT punct punctuation punctuation
# Активно активно ADV ADV advmod adverb adverb Degree=Pos
# поддерживал поддерживать VERB VERB ROOT verb verb Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# многомировую многомировую ADJ ADJ amod adjective adjective Case=Acc|Degree=Pos|Gender=Fem|Number=Sing
# интерпретацию интерпретация NOUN NOUN obj noun noun Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing
# квантовой квантовый ADJ ADJ amod adjective adjective Case=Gen|Degree=Pos|Gender=Fem|Number=Sing
# механики механика NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# . . PUNCT PUNCT punct punctuation punctuation
#
#
#
#
#  SPACE SPACE nummod space space
# Хокинг хокинг PROPN PROPN nsubj proper noun proper noun Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# был был AUX AUX cop auxiliary auxiliary Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# почётным почётный ADJ ADJ amod adjective adjective Case=Ins|Degree=Pos|Gender=Masc|Number=Sing
# членом член NOUN NOUN ROOT noun noun Animacy=Anim|Case=Ins|Gender=Masc|Number=Sing
# Королевского королевский ADJ ADJ amod adjective adjective Case=Gen|Degree=Pos|Gender=Neut|Number=Sing
# общества общество NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing
# искусств искусство NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur
# , , PUNCT PUNCT punct punctuation punctuation
# пожизненным пожизненный ADJ ADJ amod adjective adjective Case=Ins|Degree=Pos|Gender=Masc|Number=Sing
# членом член NOUN NOUN conj noun noun Animacy=Anim|Case=Ins|Gender=Masc|Number=Sing
# Папской папский ADJ ADJ amod adjective adjective Case=Gen|Degree=Pos|Gender=Fem|Number=Sing
# академии академия NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# наук наука NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Plur
# , , PUNCT PUNCT punct punctuation punctuation
# был был AUX AUX aux:pass auxiliary auxiliary Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# удостоен удостоить VERB VERB conj verb verb Aspect=Perf|Gender=Masc|Number=Sing|StyleVariant=Short|Tense=Past|VerbForm=Part|Voice=Pass
# Президентской президентский ADJ ADJ amod adjective adjective Case=Gen|Degree=Pos|Gender=Fem|Number=Sing
# медали медаль NOUN NOUN iobj noun noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# Свободы свобода PROPN PROPN nmod proper noun proper noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# — — PUNCT PUNCT punct punctuation punctuation
# высшей высокий ADJ ADJ amod adjective adjective Case=Gen|Degree=Pos|Gender=Fem|Number=Sing
# награды награда NOUN NOUN appos noun noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# для для ADP ADP case adposition adposition
# гражданских гражданский ADJ ADJ amod adjective adjective Case=Gen|Degree=Pos|Number=Plur
# лиц лицо NOUN NOUN nmod noun noun Animacy=Anim|Case=Gen|Gender=Neut|Number=Plur
# в в ADP ADP case adposition adposition
# США сша PROPN PROPN nmod proper noun proper noun Animacy=Inan|Case=Loc|Gender=Masc|Number=Plur
# . . PUNCT PUNCT punct punctuation punctuation
# В в ADP ADP case adposition adposition
# 2002 2002 ADJ ADJ amod adjective adjective
# году год NOUN NOUN obl noun noun Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing
# в в ADP ADP case adposition adposition
# результате результат NOUN NOUN obl noun noun Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing
# опроса опрос NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# Би би PROPN PROPN nmod proper noun proper noun Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing
# - - PROPN PROPN nmod proper noun proper noun Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing
# би би PROPN PROPN nmod proper noun proper noun Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing
# - - PROPN PROPN nmod proper noun proper noun Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing
# си си PROPN PROPN nmod proper noun proper noun Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing
# по по ADP ADP case adposition adposition
# определению определение NOUN NOUN nmod noun noun Animacy=Inan|Case=Dat|Gender=Neut|Number=Sing
# ста сто NUM NUM nummod numeral numeral Case=Gen
# величайших великий ADJ ADJ amod adjective adjective Case=Gen|Degree=Sup|Number=Plur
# британцев британец NOUN NOUN nmod noun noun Animacy=Anim|Case=Gen|Gender=Masc|Number=Plur
# всех весь DET DET det determiner determiner Animacy=Inan|Case=Acc|Number=Plur
# времён времён NOUN NOUN nmod noun noun Animacy=Anim|Case=Nom|Gender=Masc|Number=Plur
# Хокинг хокинг PROPN PROPN nsubj proper noun proper noun Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# занял занять VERB VERB ROOT verb verb Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# 25-е 25-е ADJ ADJ amod adjective adjective Animacy=Inan|Case=Acc|Degree=Pos|Gender=Neut|Number=Sing
# место место NOUN NOUN obj noun noun Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing
# . . PUNCT PUNCT punct punctuation punctuation
# Учёный учёный VERB VERB nsubj verb verb Aspect=Perf|Case=Nom|Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass
# был был AUX AUX cop auxiliary auxiliary Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# Лукасовским лукасовским ADJ ADJ amod adjective adjective Case=Ins|Degree=Pos|Gender=Masc|Number=Sing
# профессором профессор NOUN NOUN ROOT noun noun Animacy=Anim|Case=Ins|Gender=Masc|Number=Sing
# математики математика NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# Кембриджского кембриджский ADJ ADJ amod adjective adjective Case=Gen|Degree=Pos|Gender=Masc|Number=Sing
# университета университет NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# в в ADP ADP case adposition adposition
# 1979—2009 1979—2009 ADJ ADJ amod adjective adjective
# годах год NOUN NOUN nmod noun noun Animacy=Inan|Case=Loc|Gender=Masc|Number=Plur
# , , PUNCT PUNCT punct punctuation punctuation
# добился добиться VERB VERB conj verb verb Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Mid
# коммерческого коммерческий ADJ ADJ amod adjective adjective Case=Gen|Degree=Pos|Gender=Masc|Number=Sing
# успеха успех NOUN NOUN obj noun noun Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# благодаря благодаря ADP ADP case adposition adposition
# научно научно ADJ ADJ amod adjective adjective Case=Dat|Degree=Pos|Number=Plur
# - - ADJ ADJ amod adjective adjective Case=Dat|Degree=Pos|Number=Plur
# популярным популярный ADJ ADJ amod adjective adjective Case=Dat|Degree=Pos|Number=Plur
# произведениям произведение NOUN NOUN obl noun noun Animacy=Inan|Case=Dat|Gender=Neut|Number=Plur
# , , PUNCT PUNCT punct punctuation punctuation
# в в ADP ADP case adposition adposition
# которых которых PRON PRON obl pronoun pronoun Case=Loc|Number=Plur
# он он PRON PRON nsubj pronoun pronoun Case=Nom|Gender=Masc|Number=Sing|Person=Third
# рассуждает рассуждать VERB VERB acl:relcl verb verb Aspect=Imp|Mood=Ind|Number=Sing|Person=Third|Tense=Pres|VerbForm=Fin|Voice=Act
# о о ADP ADP case adposition adposition
# собственных собственный ADJ ADJ amod adjective adjective Case=Loc|Degree=Pos|Number=Plur
# теориях теория NOUN NOUN obl noun noun Animacy=Inan|Case=Loc|Gender=Fem|Number=Plur
# и и CCONJ CCONJ cc coordinating conjunction coordinating conjunction
# космологии космология NOUN NOUN conj noun noun Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing
# в в ADP ADP case adposition adposition
# целом целое NOUN NOUN nmod noun noun Animacy=Inan|Case=Loc|Gender=Neut|Number=Sing
# . . PUNCT PUNCT punct punctuation punctuation
# Книга книга NOUN NOUN nsubj noun noun Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing
# Хокинга хокинг PROPN PROPN nmod proper noun proper noun Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing
# « " PUNCT PUNCT punct punctuation punctuation
# Краткая краткий ADJ ADJ amod adjective adjective Case=Nom|Degree=Pos|Gender=Fem|Number=Sing
# история история NOUN NOUN appos noun noun Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing
# времени время NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing
# » " PUNCT PUNCT punct punctuation punctuation
# входила входить VERB VERB ROOT verb verb Aspect=Imp|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# в в ADP ADP case adposition adposition
# список список NOUN NOUN obl noun noun Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
# бестселлеров бестселлер NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur
# британского британский ADJ ADJ amod adjective adjective Case=Gen|Degree=Pos|Gender=Neut|Number=Sing
# издания издание NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing
# The the X X appos other other Foreign=Yes
# Sunday sunday X X flat:foreign other other Foreign=Yes
# Times times X X flat:foreign other other Foreign=Yes
# на на ADP ADP case adposition adposition
# протяжении протяжение NOUN NOUN obl noun noun Animacy=Inan|Case=Loc|Gender=Neut|Number=Sing
# рекордных рекордный ADJ ADJ amod adjective adjective Case=Gen|Degree=Pos|Number=Plur
# 237 237 NUM NUM nummod numeral numeral
# недель неделя NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Plur
# . . PUNCT PUNCT punct punctuation punctuation
#
#
#
#
#  SPACE SPACE nummod space space
# У у ADP ADP case adposition adposition
# Хокинга хокинг PROPN PROPN obl proper noun proper noun Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing
# была быть VERB VERB ROOT verb verb Aspect=Imp|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# редкая редкий ADJ ADJ amod adjective adjective Case=Nom|Degree=Pos|Gender=Fem|Number=Sing
# медленно медленно ADV ADV advmod adverb adverb Degree=Pos
# развивающаяся развиваться VERB VERB acl verb verb Aspect=Imp|Case=Nom|Gender=Fem|Number=Sing|Tense=Pres|VerbForm=Part|Voice=Act
# форма форма NOUN NOUN nsubj noun noun Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing
# болезни болезнь NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# моторных моторный ADJ ADJ amod adjective adjective Case=Gen|Degree=Pos|Number=Plur
# нейронов нейрон NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur
# ( ( PUNCT PUNCT punct punctuation punctuation
# также также ADV ADV advmod adverb adverb Degree=Pos
# известна известный ADJ ADJ parataxis adjective adjective Degree=Pos|Gender=Fem|Number=Sing|StyleVariant=Short
# как как SCONJ SCONJ case subordinating conjunction subordinating conjunction
# боковой боковой ADJ ADJ amod adjective adjective Case=Nom|Degree=Pos|Gender=Masc|Number=Sing
# амиотрофический амиотрофический ADJ ADJ amod adjective adjective Case=Nom|Degree=Pos|Gender=Masc|Number=Sing
# склероз склероз NOUN NOUN obl noun noun Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# или или CCONJ CCONJ cc coordinating conjunction coordinating conjunction
# болезнь болезнь NOUN NOUN conj noun noun Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing
# Лу лу PROPN PROPN nmod proper noun proper noun Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing
# Герига герига PROPN PROPN flat:name proper noun proper noun Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing
# ) ) PUNCT PUNCT punct punctuation punctuation
# , , PUNCT PUNCT punct punctuation punctuation
# которая которая PRON PRON nsubj pronoun pronoun Case=Nom|Gender=Fem|Number=Sing
# постепенно постепенно ADV ADV advmod adverb adverb Degree=Pos
# на на ADP ADP case adposition adposition
# протяжении протяжение NOUN NOUN obl noun noun Animacy=Inan|Case=Loc|Gender=Neut|Number=Sing
# десятилетий десятилетие NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur
# парализовала парализовать VERB VERB acl:relcl verb verb Aspect=Imp|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# его его PRON PRON obj pronoun pronoun Case=Acc|Gender=Masc|Number=Sing|Person=Third
# . . PUNCT PUNCT punct punctuation punctuation
# После после ADP ADP case adposition adposition
# потери потеря NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# речи речь NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# Хокинг хокинг PROPN PROPN nsubj proper noun proper noun Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# был был AUX AUX cop auxiliary auxiliary Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# в в ADP ADP case adposition adposition
# состоянии состояние NOUN NOUN ROOT noun noun Animacy=Inan|Case=Loc|Gender=Neut|Number=Sing
# общаться общаться VERB VERB nmod verb verb Aspect=Imp|VerbForm=Inf|Voice=Mid
# посредством посредством ADP ADP case adposition adposition
# синтезатора синтезатор NOUN NOUN obl noun noun Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# речи речь NOUN NOUN obj noun noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# , , PUNCT PUNCT punct punctuation punctuation
# изначально изначально ADV ADV advmod adverb adverb Degree=Pos
# с с ADP ADP case adposition adposition
# помощью помощь NOUN NOUN fixed noun noun Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing
# ручного ручной ADJ ADJ amod adjective adjective Case=Gen|Degree=Pos|Gender=Masc|Number=Sing
# переключателя переключатель NOUN NOUN conj noun noun Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# , , PUNCT PUNCT punct punctuation punctuation
# впоследствии впоследствии ADV ADV advmod adverb adverb Degree=Pos
# — — PUNCT PUNCT punct punctuation punctuation
# используя использовать VERB VERB advcl verb verb Aspect=Imp|Tense=Pres|VerbForm=Conv|Voice=Act
# мышцу мышцу NOUN NOUN obj noun noun Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
# щеки щека NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# . . PUNCT PUNCT punct punctuation punctuation
# 14 14 ADJ ADJ obl adjective adjective
# марта март NOUN NOUN flat noun noun Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# 2018 2018 ADJ ADJ amod adjective adjective
# года год NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# Стивен стивен PROPN PROPN nsubj proper noun proper noun Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# Хокинг хокинг PROPN PROPN flat:name proper noun proper noun Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# умер умереть VERB VERB ROOT verb verb Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# в в ADP ADP case adposition adposition
# возрасте возраст NOUN NOUN obl noun noun Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing
# 76 76 NUM NUM nummod numeral numeral
# лет год NOUN NOUN nmod noun noun Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur
# . . PUNCT PUNCT punct punctuation punctuation

# %%
for token in docFR:
    print(token, token.dep_, token.head.text) #Head = gouvernor 

[token.dep_ for token in docFR]
# Out:
# Stephen ROOT Stephen
# William nmod Stephen
# Hawking flat:name Stephen
# ( punct Stephen
# prononcé appos Stephen
# [ punct Stephen
# ˈstiːvən ROOT ˈstiːvən
# ˈhɔːkɪŋ amod ˈstiːvən
# ] punct ˈstiːvən
# ) punct né
# , punct né
# né ROOT né
# le det 8
# 8 obl:mod né
# janvier nmod 8
# 1942 nmod janvier
# à case Oxford
# Oxford obl:arg né
# et cc mort
# mort conj né
# le det 14
# 14 obl:mod né
# mars nmod 14
# 2018 nmod mars
# à case Cambridge
# Cambridge obl:arg né
# , punct physicien
# est cop physicien
# un det physicien
# physicien conj Cambridge
# théoricien amod physicien
# et cc cosmologiste
# cosmologiste conj Cambridge
# britannique xcomp cosmologiste
# . punct né
# Ses det livres
# livres nsubj fait
# et cc apparitions
# ses det apparitions
# apparitions conj livres
# publiques amod apparitions
# ont aux:tense fait
# fait ROOT fait
# de case théoricien
# ce det théoricien
# théoricien obl:arg fait
# de case renommée
# renommée nmod théoricien
# mondiale amod renommée
# une det célébrité
# célébrité obj fait
# . punct fait
#
#
#  cc souffre
# Depuis case âge
# l' det âge
# âge obl:mod souffre
# d' case vingtaine
# une det vingtaine
# vingtaine nmod âge
# d' case années
# années nmod vingtaine
# , punct souffre
# Hawking nsubj souffre
# souffre ROOT souffre
# d' case forme
# une det forme
# forme obl:arg souffre
# rare amod forme
# — ROOT —
# de case début
# début nmod —
# précoce amod début
# et cc évolution
# d' case évolution
# évolution conj début
# lente amod —
# — punct ;
# de case sclérose
# sclérose nmod —
# latérale amod sclérose
# amyotrophique amod sclérose
# ( punct —
# SLA appos —
# ) punct —
# ; punct paralysé
# sa det maladie
# maladie nsubj paralysé
# progresse amod maladie
# au case fil
# fil nmod maladie
# des case ans
# ans nmod fil
# au case point
# point nmod fil
# de mark laisser
# le obj laisser
# laisser aux:tense paralysé
# presque advmod paralysé
# complètement advmod paralysé
# paralysé ROOT paralysé
# . punct paralysé
# Pourtant advmod professeur
# , punct professeur
# il expl:subj professeur
# est cop professeur
# professeur ROOT professeur
# de case mathématiques
# mathématiques nmod professeur
# à case université
# l' det université
# université obl:mod professeur
# de case Cambridge
# Cambridge nmod université
# de case 1980
# 1980 nmod université
# à case 20091
# 20091 nmod 1980
# , punct membre
# membre conj professeur
# du case Gonville
# Gonville nmod membre
# and dep membre
# Caius flat:name and
# College flat:name professeur
# et cc chercheur
# chercheur conj College
# distingué amod chercheur
# du case Perimeter
# Perimeter nmod chercheur
# Institute flat:name Perimeter
# for case Theoretical
# Theoretical nmod chercheur
# Physics flat:name Theoretical
# . punct professeur
# Il nsubj:pass connu
# est aux:pass connu
# connu ROOT connu
# pour case contributions
# ses det contributions
# contributions obl:mod connu
# dans case domaines
# les det domaines
# domaines nmod contributions
# de case cosmologie
# la det cosmologie
# cosmologie nmod domaines
# et cc gravité
# la det gravité
# gravité conj cosmologie
# quantique mark cadre
# , punct cadre
# en advmod cadre
# particulier fixed en
# dans case cadre
# le det cadre
# cadre obl:mod connu
# des case trous
# trous nmod cadre
# noirs amod trous
# . punct connu
# Son det succès
# succès nsubj:pass lié
# est aux:pass lié
# également advmod lié
# lié ROOT lié
# à case ouvrages
# ses det ouvrages
# ouvrages obl:arg lié
# de case vulgarisation
# vulgarisation nmod ouvrages
# scientifique amod vulgarisation
# dans case lesquels
# lesquels obl:mod discute
# il nsubj discute
# discute acl:relcl ouvrages
# de case théories
# ses det théories
# théories obl:arg discute
# et cc cosmologie
# de case cosmologie
# la det cosmologie
# cosmologie conj théories
# en case général
# général nmod cosmologie
# , punct cosmologie
# en dep discute
# particulier fixed en
# Une det histoire
# brève amod histoire
# histoire obj discute
# du case temps
# temps nmod histoire
# . punct lié
#
#
#  nsubj:pass fondée
# La det clé
# clé nsubj:pass fondée
# des case travaux
# principaux amod travaux
# travaux nmod clé
# scientifiques amod travaux
# de case Stephen
# Stephen nmod travaux
# Hawking flat:name Stephen
# est aux:pass fondée
# fondée ROOT fondée
# , punct fondée
# en case collaboration
# collaboration obl:mod fondée
# avec case Roger
# Roger nmod collaboration
# Penrose flat:name Roger
# , punct fondée
# sur case élaboration
# l' det élaboration
# élaboration obl:mod fondée
# des case théorèmes
# théorèmes nmod élaboration
# sur case singularités
# les det singularités
# singularités nmod théorèmes
# dans case cadre
# le det cadre
# cadre obl:mod fondée
# de case relativité
# la det relativité
# relativité nmod cadre
# générale amod relativité
# , punct relativité
# et cc prédiction
# la det prédiction
# prédiction nsubj théorique
# théorique advcl fondée
# que mark devraient
# les det trous
# trous nsubj devraient
# noirs amod trous
# devraient ccomp théorique
# émettre xcomp devraient
# ce obj émettre
# qui nsubj:pass connu
# est aux:pass connu
# aujourd'hui advmod connu
# connu acl:relcl ce
# sous case nom
# le det nom
# nom obl:mod connu
# de case rayonnement
# rayonnement nmod nom
# de case Hawking
# Hawking nmod rayonnement
# . punct fondée
# ['ROOT',
#  'nmod',
#  'flat:name',
#  'punct',
#  'appos',
#  'punct',
#  'ROOT',
#  'amod',
#  'punct',
#  'punct',
#  'punct',
#  'ROOT',
#  'det',
#  'obl:mod',
#  'nmod',
#  'nmod',
#  'case',
#  'obl:arg',
#  'cc',
#  'conj',
#  'det',
#  'obl:mod',
#  'nmod',
#  'nmod',
#  'case',
#  'obl:arg',
#  'punct',
#  'cop',
#  'det',
#  'conj',
#  'amod',
#  'cc',
#  'conj',
#  'xcomp',
#  'punct',
#  'det',
#  'nsubj',
#  'cc',
#  'det',
#  'conj',
#  'amod',
#  'aux:tense',
#  'ROOT',
#  'case',
#  'det',
#  'obl:arg',
#  'case',
#  'nmod',
#  'amod',
#  'det',
#  'obj',
#  'punct',
#  'cc',
#  'case',
#  'det',
#  'obl:mod',
#  'case',
#  'det',
#  'nmod',
#  'case',
#  'nmod',
#  'punct',
#  'nsubj',
#  'ROOT',
#  'case',
#  'det',
#  'obl:arg',
#  'amod',
#  'ROOT',
#  'case',
#  'nmod',
#  'amod',
#  'cc',
#  'case',
#  'conj',
#  'amod',
#  'punct',
#  'case',
#  'nmod',
#  'amod',
#  'amod',
#  'punct',
#  'appos',
#  'punct',
#  'punct',
#  'det',
#  'nsubj',
#  'amod',
#  'case',
#  'nmod',
#  'case',
#  'nmod',
#  'case',
#  'nmod',
#  'mark',
#  'obj',
#  'aux:tense',
#  'advmod',
#  'advmod',
#  'ROOT',
#  'punct',
#  'advmod',
#  'punct',
#  'expl:subj',
#  'cop',
#  'ROOT',
#  'case',
#  'nmod',
#  'case',
#  'det',
#  'obl:mod',
#  'case',
#  'nmod',
#  'case',
#  'nmod',
#  'case',
#  'nmod',
#  'punct',
#  'conj',
#  'case',
#  'nmod',
#  'dep',
#  'flat:name',
#  'flat:name',
#  'cc',
#  'conj',
#  'amod',
#  'case',
#  'nmod',
#  'flat:name',
#  'case',
#  'nmod',
#  'flat:name',
#  'punct',
#  'nsubj:pass',
#  'aux:pass',
#  'ROOT',
#  'case',
#  'det',
#  'obl:mod',
#  'case',
#  'det',
#  'nmod',
#  'case',
#  'det',
#  'nmod',
#  'cc',
#  'det',
#  'conj',
#  'mark',
#  'punct',
#  'advmod',
#  'fixed',
#  'case',
#  'det',
#  'obl:mod',
#  'case',
#  'nmod',
#  'amod',
#  'punct',
#  'det',
#  'nsubj:pass',
#  'aux:pass',
#  'advmod',
#  'ROOT',
#  'case',
#  'det',
#  'obl:arg',
#  'case',
#  'nmod',
#  'amod',
#  'case',
#  'obl:mod',
#  'nsubj',
#  'acl:relcl',
#  'case',
#  'det',
#  'obl:arg',
#  'cc',
#  'case',
#  'det',
#  'conj',
#  'case',
#  'nmod',
#  'punct',
#  'dep',
#  'fixed',
#  'det',
#  'amod',
#  'obj',
#  'case',
#  'nmod',
#  'punct',
#  'nsubj:pass',
#  'det',
#  'nsubj:pass',
#  'case',
#  'amod',
#  'nmod',
#  'amod',
#  'case',
#  'nmod',
#  'flat:name',
#  'aux:pass',
#  'ROOT',
#  'punct',
#  'case',
#  'obl:mod',
#  'case',
#  'nmod',
#  'flat:name',
#  'punct',
#  'case',
#  'det',
#  'obl:mod',
#  'case',
#  'nmod',
#  'case',
#  'det',
#  'nmod',
#  'case',
#  'det',
#  'obl:mod',
#  'case',
#  'det',
#  'nmod',
#  'amod',
#  'punct',
#  'cc',
#  'det',
#  'nsubj',
#  'advcl',
#  'mark',
#  'det',
#  'nsubj',
#  'amod',
#  'ccomp',
#  'xcomp',
#  'obj',
#  'nsubj:pass',
#  'aux:pass',
#  'advmod',
#  'acl:relcl',
#  'case',
#  'det',
#  'obl:mod',
#  'case',
#  'nmod',
#  'case',
#  'nmod',
#  'punct']

# %%
from spacy import displacy

start_time = time.time()
displacy.render(docFR, style="dep")
print("--- %s secondes ---" % (time.time() - start_time))
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="4dbf9c2f26564a6a8fd1db4d5c1bfd44-0" class="displacy" width="39425" height="1799.5" direction="ltr" style="max-width: none; height: 1799.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Stephen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">William</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Hawking (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">prononcé [</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">ˈstiːvən</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">ˈhɔːkɪŋ]),</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">né</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">le</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">8</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">janvier</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">1942</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">à</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Oxford</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">et</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">mort</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">le</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">14</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">mars</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">2018</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">à</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">Cambridge,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">est</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">un</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">physicien</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">théoricien</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">et</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">cosmologiste</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">britannique.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">Ses</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">livres</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">et</tspan>
#     <tspan
# --- 0.010912656784057617 secondes ---

# %% [markdown]
# Toutes les possibilités de patterns sont disponibles ici :
#     https://spacy.io/usage/rule-based-matching

# %%
from spacy.matcher import Matcher

matcher = Matcher(nlp_fr.vocab)
pattern=[{"POS":"NUM"}, {"POS":"NOUN"}, {"POS":"NUM"}]

matcher.add("Date", [pattern])

matches=matcher(docFR)

for match_id, start, end in matches:
    string_id = nlp_fr.vocab.strings[match_id]  # Get string representation
    span = docFR[start:end]  # The matched span
    print("Match ID : {} -- String ID : {} -- Début : {} -- Fin : {} \n-- Texte match : {}".format(match_id, string_id, start, end, span.text))
# Out:
# Match ID : 6257230598435404803 -- String ID : Date -- Début : 13 -- Fin : 16
# -- Texte match : 8 janvier 1942
# Match ID : 6257230598435404803 -- String ID : Date -- Début : 21 -- Fin : 24
# -- Texte match : 14 mars 2018

# %%
matcher = Matcher(nlp.vocab)
pattern=[{"POS":"NUM"}, {"POS":"PROPN"}, {"POS":"NUM"}]

matcher.add("Date", [pattern])

matches=matcher(docEN)

for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]  # Get string representation
    span = docEN[start:end]  # The matched span
    print("Match ID : {} -- String ID : {} -- Début : {} -- Fin : {} \n-- Texte match : {}".format(match_id, string_id, start, end, span.text))
# Out:
# Match ID : 6257230598435404803 -- String ID : Date -- Début : 8 -- Fin : 11
# -- Texte match : 8 January 1942
# Match ID : 6257230598435404803 -- String ID : Date -- Début : 12 -- Fin : 15
# -- Texte match : 14 March 2018
# Match ID : 6257230598435404803 -- String ID : Date -- Début : 423 -- Fin : 426
# -- Texte match : 14 March 2018

# %%
matcher = Matcher(nlp_ru.vocab)
pattern=[{"POS":"ADJ"}, {"POS":"NOUN"}, {"POS":"ADJ"}]

matcher.add("Date", [pattern])

matches=matcher(docRU)

for match_id, start, end in matches:
    string_id = nlp_ru.vocab.strings[match_id]  
    span = docRU[start:end]  
    print("Match ID : {} -- String ID : {} -- Début : {} -- Fin : {} \n-- Texte match : {}".format(match_id, string_id, start, end, span.text))
# Out:
# Match ID : 6257230598435404803 -- String ID : Date -- Début : 10 -- Fin : 13
# -- Texte match : 8 января 1942
# Match ID : 6257230598435404803 -- String ID : Date -- Début : 18 -- Fin : 21
# -- Texte match : 14 марта 2018
# Match ID : 6257230598435404803 -- String ID : Date -- Début : 43 -- Fin : 46
# -- Texte match : теоретической космологии Кембриджского
# Match ID : 6257230598435404803 -- String ID : Date -- Début : 104 -- Fin : 107
# -- Texte match : многомировую интерпретацию квантовой
# Match ID : 6257230598435404803 -- String ID : Date -- Début : 112 -- Fin : 115
# -- Texte match : почётным членом Королевского
# Match ID : 6257230598435404803 -- String ID : Date -- Début : 118 -- Fin : 121
# -- Texte match : пожизненным членом Папской
# Match ID : 6257230598435404803 -- String ID : Date -- Début : 271 -- Fin : 274
# -- Texte match : 14 марта 2018

# %%
start_time = time.time()
displacy.render(docFR, style="ent")
print("--- %s secondes ---" % (time.time() - start_time))
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stephen William Hawking
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (prononcé [ˈstiːvən ˈhɔːkɪŋ]), né le 8 janvier 1942 à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Oxford
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  et mort le 14 mars 2018 à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cambridge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , est un physicien théoricien et cosmologiste britannique. Ses livres et ses apparitions publiques ont fait de ce théoricien de renommée mondiale une célébrité.</br></br>Depuis l'âge d'une vingtaine d'années,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hawking
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  souffre d'une forme rare — de début précoce et d'évolution lente — de sclérose latérale amyotrophique (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SLA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) ; sa maladie progresse au fil des ans au point de le laisser presque complètement paralysé. Pourtant, il est professeur de mathématiques à l'
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     université de Cambridge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  de 1980 à 20091, membre du
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gonville and Caius College
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  et chercheur distingué du
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Perimeter Institute for Theoretical Physics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Il est connu pour ses contributions dans les domaines de la cosmologie et la gravité quantique, en particulier dans le cadre des trous noirs. Son succès est également lié à ses ouvrages de vulgarisation scientifique dans lesquels il discute de ses théories et de la cosmologie en général, en particulier
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Une brève histoire du temps
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .</br></br>La clé des principaux travaux scientifiques de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stephen Hawking
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  est fondée, en collaboration avec
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Roger Penrose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , sur l'élaboration des théorèmes sur les singularités dans le cadre de la relativité générale, et la prédiction théorique que les trous noirs devraient émettre ce qui est aujourd'hui connu sous le nom de rayonnement de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hawking
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .</div></span>
# --- 0.00991964340209961 secondes ---

# %%
start_time = time.time()
displacy.render(docEN, style="ent")
print("--- %s secondes ---" % (time.time() - start_time))
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stephen William Hawking CH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CBE FRS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  FRSA (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8 January 1942
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  –
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14 March 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ) was an
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     English
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LANGUAGE</span>
# </mark>
#  theoretical physicist, cosmologist, and author who was director of research at
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Centre for Theoretical Cosmology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the University of Cambridge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  at the time of his death. He was the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lucasian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  Professor of Mathematics at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the University of Cambridge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     between 1979 and 2009
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br></br>Hawking was born in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Oxford
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  into a family of doctors. He began his university education at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     University College
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Oxford
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     October 1959
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the age of 17
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , where he received a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -class
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (Hons.) degree in physics. He began his graduate work at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trinity Hall
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cambridge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     October 1962
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , where he obtained his
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PhD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  degree in applied mathematics and theoretical physics, specialising in general relativity and cosmology in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 1966
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1963
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , Hawking was diagnosed with an early-onset slow-progressing form of motor neurone disease that gradually paralysed him over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the decades
#     <span style="font-size: 0.8em; fo
# --- 0.04662346839904785 secondes ---

# %%
text = "Orange, Free, Bouygues Telecom et SFR sont des acteurs majeurs de la téléphonie en France. Orange Mécanique est un un film de Stanley Kubrick. De quelle couleur est cette carte ? Orange."
doc = nlp_fr(text)

start_time = time.time()
displacy.render(doc, style="ent")
print("--- %s secondes ---" % (time.time() - start_time))
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Orange
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Free
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bouygues Telecom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  et
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SFR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sont des acteurs majeurs de la téléphonie en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . Orange Mécanique est un un film de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stanley Kubrick
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . De quelle couleur est cette carte ?
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Orange
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div></span>
# --- 0.03670454025268555 secondes ---

# %%
[chunk.text for chunk in docEN.noun_chunks]
#On extraie les groupes nominaux
# Out:
# ['Stephen William Hawking CH CBE FRS FRSA',
#  '14 March',
#  'an English theoretical physicist',
#  'cosmologist',
#  'author',
#  'who',
#  'director',
#  'research',
#  'the Centre',
#  'Theoretical Cosmology',
#  'the University',
#  'Cambridge',
#  'the time',
#  'his death',
#  'He',
#  'the Lucasian Professor',
#  'Mathematics',
#  'the University',
#  'Cambridge',
#  'Oxford',
#  'a family',
#  'doctors',
#  'He',
#  'his university education',
#  'University College',
#  'Oxford',
#  'October',
#  'the age',
#  'he',
#  '(Hons',
#  'physics',
#  'He',
#  'his graduate work',
#  'Trinity Hall',
#  'October',
#  'he',
#  'his PhD degree',
#  'applied mathematics',
#  'theoretical physics',
#  'general relativity',
#  'cosmology',
#  'March',
#  'an early-onset slow-progressing form',
#  'motor neurone disease',
#  'him',
#  'the decades',
#  'the loss',
#  'his speech',
#  'he',
#  'a speech-generating device',
#  'use',
#  'a handheld switch',
#  'a single cheek muscle',
#  "Hawking's scientific works",
#  'a collaboration',
#  'Roger Penrose',
#  'gravitational singularity theorems',
#  'the framework',
#  'general relativity',
#  'the theoretical prediction',
#  'black holes',
#  'radiation',
#  'radiation',
#  'radiation',
#  'the late 1970s',
#  'the publication',
#  'further research',
#  'the discovery',
#  'a significant breakthrough',
#  'theoretical physics',
#  'a theory',
#  'cosmology',
#  'a union',
#  'the general theory',
#  'relativity',
#  'quantum mechanics',
#  'He',
#  'a vigorous supporter',
#  'the many-worlds interpretation',
#  'quantum mechanics',
#  'commercial success',
#  'several works',
#  'popular science',
#  'he',
#  'his theories',
#  'cosmology',
#  'His book',
#  'A Brief History',
#  'Time',
#  'the Sunday Times bestseller list',
#  'a record-breaking 237 weeks',
#  'a Fellow',
#  'the Royal Society',
#  'a lifetime member',
#  'the Pontifical Academy',
#  'Sciences',
#  'a recipient',
#  'the Presidential Medal',
#  'Freedom',
#  'the highest civilian award',
#  'the United States',
#  'Hawking',
#  'number',
#  "the BBC's poll",
#  'the 100 Greatest Britons',
#  'He',
#  '14 March',
#  'the age',
#  'motor neurone disease',
#  'more than 50 years']

# %%
exEnt = (nlp_fr("Fb est un réseau social fondé par Mark Zuckerberg (âgé de 20 ans alors) avec ses camarades de l'université de Harvard (États-Unis). Il est accessible à tous depuis septembre 2006."))

print("Token  --  indexDeb  --  IndexFin  --  Etiq.")
print("--"*30)
for e in exEnt.ents: 
    print("{} --  {}  --  {}  --  {}".format(e.text, e.start_char, e.end_char, e.label_, spacy.explain(e.label_)))
    
displacy.render(exEnt, style="ent")
# Out:
# Token  --  indexDeb  --  IndexFin  --  Etiq.
# ------------------------------------------------------------
# Mark Zuckerberg --  34  --  49  --  PER
# université de Harvard --  96  --  117  --  ORG
# États-Unis --  119  --  129  --  LOC
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Fb est un réseau social fondé par
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mark Zuckerberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (âgé de 20 ans alors) avec ses camarades de l'
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     université de Harvard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     États-Unis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ). Il est accessible à tous depuis septembre 2006.</div></span>

# %%
from spacy.tokens import Span

Fb_entite = Span(exEnt, 0, 1, label="ORG")
sept_entite = Span(exEnt,33,36, label="DATE")
exEnt.ents = list(exEnt.ents)+[Fb_entite]+[sept_entite]

print("Token  --  indexDeb  --  IndexFin  --  Etiq.")
print("--"*30)
for e in exEnt.ents: 
    print("{} --  {}  --  {}  --  {}".format(e.text, e.start_char, e.end_char, e.label_, spacy.explain(e.label_)))
    
displacy.render(exEnt, style="ent")
# Out:
# Token  --  indexDeb  --  IndexFin  --  Etiq.
# ------------------------------------------------------------
# Fb --  0  --  2  --  ORG
# Mark Zuckerberg --  34  --  49  --  PER
# université de Harvard --  95  --  116  --  ORG
# États-Unis --  118  --  128  --  LOC
# septembre 2006. --  163  --  178  --  DATE
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  est un réseau social fondé par
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mark Zuckerberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (âgé de 20ans alors) avec ses camarades de l'
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     université de Harvard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     États-Unis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ). Il est accessible à tous depuis
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     septembre 2006.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </div></span>

# %% [markdown]
# ### Similarités entre vecteurs.
#
# Attention cependant, tous les modèles ne sont pas adaptés à cette manipulation et les résultats pourraient ne pas être pertinents. Préférez les modèles lg (large) pour ça

# %%
nlp_vec = spacy.load("en_core_web_lg")

ex01 = nlp_vec("A nice appartment")
ex02 = nlp_vec("A beautiful house")

ex01.similarity(ex02)
# Out:
# 0.7952007053483752

# %%
ex03 = nlp_vec("I was born in France")
ex04 = nlp_vec("Her name is Francesca")

ex03.similarity(ex04)
# Out:
# 0.599905303989377
